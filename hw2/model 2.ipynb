# %% [markdown]
# # **Homework 2-1 Phoneme Classification**

# %% [markdown]
# ## The DARPA TIMIT Acoustic-Phonetic Continuous Speech Corpus (TIMIT)
# The TIMIT corpus of reading speech has been designed to provide speech data for the acquisition of acoustic-phonetic knowledge and for the development and evaluation of automatic speech recognition systems.
#
# This homework is a multiclass classification task,
# we are going to train a deep neural network classifier to predict the phonemes for each frame from the speech corpus TIMIT.
#
# link: https://academictorrents.com/details/34e2b78745138186976cbc27939b1b34d18bd5b3

# %% [markdown]
# ## Download Data
# Download data from google drive, then unzip it.
#
# You should have `timit_11/train_11.npy`, `timit_11/train_label_11.npy`, and `timit_11/test_11.npy` after running this block.<br><br>
# `timit_11/`
# - `train_11.npy`: training data<br>
# - `train_label_11.npy`: training label<br>
# - `test_11.npy`:  testing data<br><br>
#
# **notes: if the google drive link is dead, you can download the data directly from Kaggle and upload it to the workspace**

# %%
#!gdown --id '1HPkcmQmFGu-3OknddKIa5dNDsR05lIQR' --output data.zip
#!unzip data.zip
#!ls

# %% [markdown]
# ## Preparing Data
# Load the training and testing data from the `.npy` file (NumPy array).

# %%
import numpy as np

print('Loading data ...')

data_root='./timit_11/'
train = np.load(data_root + 'train_11.npy')
train_label = np.load(data_root + 'train_label_11.npy')
test = np.load(data_root + 'test_11.npy')

train = train.reshape(1229932, 11, 39)
test = test.reshape(451552, 11, 39)

#feats = [0,2,3,4,5,6,7,8,10]
#train = train[:,feats,:]
#test = test[:,feats,:]

train = train.reshape(1229932, -1)
test = test.reshape(451552, -1)

print('Size of training data: {}'.format(train.shape))
print('Size of testing data: {}'.format(test.shape))
# Out:
# Loading data ...
# Size of training data: (1229932, 429)
# Size of testing data: (451552, 429)

# %%
#from scipy import spatial.distance.cosine
# 0,1: 0.8406975890047381
# 1,2: 0.8408058577925639
# 0,2: 0.5890390591353316
# 看來0,1 有點重疊->刪掉1
# 2,3: 0.8408435099576054
# 3,4: 0.8408087361471327
# 2,4: 0.5891934447436348
# 看來2,3 有點重疊->刪掉3
# 4,5: 0.8407781385646762
# 5,6: 0.8408703774927714
# 4,6: 0.5893461401252141
# 看來4,5 有點重疊
# 6,7: 0.8408710386399266
# 7,8: 0.8408018768428297
# 6,8: 0.5896318464957054
# 看來6,7 有點重疊->刪掉7
# 8,9: 0.8407466205531563
# 9,10: 0.840738934407591
# 8,10: 0.5898820477117614
# 看來8,9 有點重疊->刪掉9
# 用0,2,4,5,6,8,10共7個frame

# %% [markdown]
# ## Create Dataset

# %%
import torch
from torch.utils.data import Dataset

class TIMITDataset(Dataset):
    def __init__(self, X, y=None):
        self.data = torch.from_numpy(X).float()
        if y is not None:
            y = y.astype(np.int)
            self.label = torch.LongTensor(y)
        else:
            self.label = None

    def __getitem__(self, idx):
        if self.label is not None:
            return self.data[idx], self.label[idx]
        else:
            return self.data[idx]

    def __len__(self):
        return len(self.data)

# %% [markdown]
# Split the labeled data into a training set and a validation set, you can modify the variable `VAL_RATIO` to change the ratio of validation data.

# %%
VAL_RATIO = 0

percent = int(train.shape[0] * (1 - VAL_RATIO))
train_x, train_y, val_x, val_y = train[:percent], train_label[:percent], train[percent:], train_label[percent:]
print('Size of training set: {}'.format(train_x.shape))
print('Size of validation set: {}'.format(val_x.shape))
# Out:
# Size of training set: (1229932, 429)
# Size of validation set: (0, 429)

# %% [markdown]
# Create a data loader from the dataset, feel free to tweak the variable `BATCH_SIZE` here.

# %%
BATCH_SIZE = 4096

from torch.utils.data import DataLoader

train_set = TIMITDataset(train_x, train_y)
val_set = TIMITDataset(val_x, val_y)
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True) #only shuffle the training data
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Cleanup the unneeded variables to save memory.<br>
#
# **notes: if you need to use these variables later, then you may remove this block or clean up unneeded variables later<br>the data size is quite huge, so be aware of memory usage in colab**

# %%
import gc

del train, train_label, train_x, train_y, val_x, val_y
gc.collect()
# Out:
# 40

# %% [markdown]
# ## Create Model

# %% [markdown]
# Define model architecture, you are encouraged to change and experiment with the model architecture.

# %%
import torch
import torch.nn as nn

class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(429, 2048), # 1
            nn.LeakyReLU(),
            #nn.ReLU(),
            nn.BatchNorm1d(2048),
            nn.Dropout(0.5),
            nn.Linear(2048, 2048), # 2
            nn.LeakyReLU(),
            #nn.ReLU(),
            nn.BatchNorm1d(2048),
            nn.Dropout(0.5),
            nn.Linear(2048,1024), # 3
            nn.LeakyReLU(),
            #nn.ReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.5),
            nn.Linear(1024, 512), # 4
            #nn.ReLU(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.5),
            nn.Linear(512, 128), # 5
            #nn.ReLU(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.5),
            nn.Linear(128, 39)
        )

    def forward(self, x):
        x = self.net(x)
        return x

# %% [markdown]
# ## Training

# %%
#check device
def get_device():
    return 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# Fix random seeds for reproducibility.

# %%
# fix random seed
def same_seeds(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  
    np.random.seed(seed)  
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# Feel free to change the training parameters here.

# %%
# fix random seed for reproducibility
same_seeds(0)

# get device 
device = get_device()
print(f'DEVICE: {device}')

# training parameters
num_epoch = 300              # number of training epoch
learning_rate = 1e-4       # learning rate
l2 = 1e-3
# the path where checkpoint saved
model_path = './model2dnn.ckpt'

# create model, define a loss function, and optimizer
model = Classifier().to(device)
criterion = nn.CrossEntropyLoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=l2)
# Out:
# DEVICE: cuda

# %%
# start training
best_acc = 0.0
epoch = 0
    
for epoch in range(num_epoch):
    train_acc = 0.0
    train_loss = 0.0
    val_acc = 0.0
    val_loss = 0.0

    # training
    model.train() # set the model to training mode
    for i, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad() 
        outputs = model(inputs) 
        batch_loss = criterion(outputs, labels)
        _, train_pred = torch.max(outputs, 1) # get the index of the class with the highest probability
        batch_loss.backward() 
        optimizer.step() 

        train_acc += (train_pred.cpu() == labels.cpu()).sum().item()
        train_loss += batch_loss.item()

    # validation
    if len(val_set) > 0:
        model.eval() # set the model to evaluation mode
        with torch.no_grad():
            for i, data in enumerate(val_loader):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                batch_loss = criterion(outputs, labels) 
                _, val_pred = torch.max(outputs, 1) 
            
                val_acc += (val_pred.cpu() == labels.cpu()).sum().item() # get the index of the class with the highest probability
                val_loss += batch_loss.item()

            print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader), val_acc/len(val_set), val_loss/len(val_loader)
            ))

            # if the model improves, save a checkpoint at this epoch
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'train_acc': train_acc/len(train_set),
                    'train_loss': train_loss/len(train_loader),
                    'val_acc': best_acc/len(val_set),
                    'val_loss': val_loss/len(val_loader),
                }, model_path)
                #torch.save(model.state_dict(), model_path)
                print('saving model with acc {:.3f}'.format(best_acc/len(val_set)))

    else:
        print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
            epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader)
        ))
        epoch += 1

# if not validating, save the last epoch
if len(val_set) == 0:
    #torch.save(model.state_dict(), model_path)
    torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'train_acc': train_acc/len(train_set),
                    'train_loss': train_loss/len(train_loader),
                }, model_path)
    print('saving model at last epoch')
    
print('Finished training after {} epochs'.format(epoch))
# Out:
# [001/300] Train Acc: 0.387516 Loss: 2.318095
# [002/300] Train Acc: 0.522996 Loss: 1.683480
# [003/300] Train Acc: 0.569180 Loss: 1.493301
# [004/300] Train Acc: 0.596703 Loss: 1.384131
# [005/300] Train Acc: 0.614618 Loss: 1.313169
# [006/300] Train Acc: 0.628923 Loss: 1.259490
# [007/300] Train Acc: 0.640187 Loss: 1.217058
# [008/300] Train Acc: 0.649010 Loss: 1.182186
# [009/300] Train Acc: 0.657712 Loss: 1.151694
# [010/300] Train Acc: 0.663449 Loss: 1.128226
# [011/300] Train Acc: 0.669684 Loss: 1.105447
# [012/300] Train Acc: 0.674982 Loss: 1.085353
# [013/300] Train Acc: 0.679652 Loss: 1.067213
# [014/300] Train Acc: 0.683893 Loss: 1.051700
# [015/300] Train Acc: 0.688370 Loss: 1.034933
# [016/300] Train Acc: 0.692159 Loss: 1.021500
# [017/300] Train Acc: 0.696225 Loss: 1.008175
# [018/300] Train Acc: 0.700069 Loss: 0.994167
# [019/300] Train Acc: 0.703098 Loss: 0.981687
# [020/300] Train Acc: 0.705458 Loss: 0.971647
# [021/300] Train Acc: 0.708955 Loss: 0.960487
# [022/300] Train Acc: 0.711342 Loss: 0.950439
# [023/300] Train Acc: 0.714152 Loss: 0.940893
# [024/300] Train Acc: 0.715944 Loss: 0.933258
# [025/300] Train Acc: 0.718443 Loss: 0.925441
# [026/300] Train Acc: 0.720349 Loss: 0.917251
# [027/300] Train Acc: 0.723272 Loss: 0.907732
# [028/300] Train Acc: 0.724368 Loss: 0.902672
# [029/300] Train Acc: 0.726113 Loss: 0.896054
# [030/300] Train Acc: 0.727791 Loss: 0.889956
# [031/300] Train Acc: 0.729287 Loss: 0.883832
# [032/300] Train Acc: 0.730661 Loss: 0.878867
# [033/300] Train Acc: 0.732622 Loss: 0.872918
# [034/300] Train Acc: 0.733517 Loss: 0.869098
# [035/300] Train Acc: 0.734577 Loss: 0.864515
# [036/300] Train Acc: 0.735585 Loss: 0.859309
# [037/300] Train Acc: 0.736389 Loss: 0.856196
# [038/300] Train Acc: 0.737551 Loss: 0.852023
# [039/300] Train Acc: 0.738938 Loss: 0.848447
# [040/300] Train Acc: 0.739758 Loss: 0.845303
# [041/300] Train Acc: 0.740644 Loss: 0.840928
# [042/300] Train Acc: 0.741384 Loss: 0.838690
# [043/300] Train Acc: 0.742356 Loss: 0.835407
# [044/300] Train Acc: 0.742508 Loss: 0.832613
# [045/300] Train Acc: 0.744199 Loss: 0.828920
# [046/300] Train Acc: 0.744679 Loss: 0.826243
# [047/300] Train Acc: 0.745810 Loss: 0.822183
# [048/300] Train Acc: 0.746175 Loss: 0.821204
# [049/300] Train Acc: 0.746149 Loss: 0.819832
# [050/300] Train Acc: 0.747480 Loss: 0.815941
# [051/300] Train Acc: 0.747438 Loss: 0.814837
# [052/300] Train Acc: 0.748971 Loss: 0.813674
# [053/300] Train Acc: 0.749094 Loss: 0.809878
# [054/300] Train Acc: 0.749941 Loss: 0.807050
# [055/300] Train Acc: 0.750222 Loss: 0.806276
# [056/300] Train Acc: 0.750564 Loss: 0.804172
# [057/300] Train Acc: 0.750763 Loss: 0.803093
# [058/300] Train Acc: 0.751263 Loss: 0.801621
# [059/300] Train Acc: 0.752464 Loss: 0.798460
# [060/300] Train Acc: 0.752344 Loss: 0.798052
# [061/300] Train Acc: 0.753495 Loss: 0.794394
# [062/300] Train Acc: 0.753763 Loss: 0.793001
# [063/300] Train Acc: 0.753630 Loss: 0.792490
# [064/300] Train Acc: 0.754277 Loss: 0.791406
# [065/300] Train Acc: 0.754285 Loss: 0.789316
# [066/300] Train Acc: 0.754896 Loss: 0.788241
# [067/300] Train Acc: 0.755609 Loss: 0.786625
# [068/300] Train Acc: 0.755679 Loss: 0.785066
# [069/300] Train Acc: 0.756574 Loss: 0.782939
# [070/300] Train Acc: 0.756470 Loss: 0.782290
# [071/300] Train Acc: 0.756827 Loss: 0.781542
# [072/300] Train Acc: 0.757204 Loss: 0.779350
# [073/300] Train Acc: 0.757529 Loss: 0.779408
# [074/300] Train Acc: 0.757411 Loss: 0.778169
# [075/300] Train Acc: 0.758705 Loss: 0.775460
# [076/300] Train Acc: 0.758619 Loss: 0.775258
# [077/300] Train Acc: 0.758476 Loss: 0.774117
# [078/300] Train Acc: 0.758406 Loss: 0.773155
# [079/300] Train Acc: 0.759891 Loss: 0.771005
# [080/300] Train Acc: 0.759583 Loss: 0.770403
# [081/300] Train Acc: 0.760298 Loss: 0.768797
# [082/300] Train Acc: 0.760201 Loss: 0.768737
# [083/300] Train Acc: 0.760389 Loss: 0.767593
# [084/300] Train Acc: 0.760467 Loss: 0.767607
# [085/300] Train Acc: 0.760863 Loss: 0.765980
# [086/300] Train Acc: 0.761237 Loss: 0.764346
# [087/300] Train Acc: 0.761358 Loss: 0.763930
# [088/300] Train Acc: 0.761992 Loss: 0.762612
# [089/300] Train Acc: 0.761708 Loss: 0.762909
# [090/300] Train Acc: 0.762206 Loss: 0.761793
# [091/300] Train Acc: 0.763177 Loss: 0.759020
# [092/300] Train Acc: 0.762547 Loss: 0.760380
# [093/300] Train Acc: 0.763598 Loss: 0.757436
# [094/300] Train Acc: 0.763137 Loss: 0.758830
# [095/300] Train Acc: 0.763638 Loss: 0.757193
# [096/300] Train Acc: 0.763403 Loss: 0.757121
# [097/300] Train Acc: 0.763795 Loss: 0.755480
# [098/300] Train Acc: 0.764189 Loss: 0.755420
# [099/300] Train Acc: 0.764268 Loss: 0.754288
# [100/300] Train Acc: 0.764470 Loss: 0.752656
# [101/300] Train Acc: 0.764258 Loss: 0.753186
# [102/300] Train Acc: 0.764482 Loss: 0.753219
# [103/300] Train Acc: 0.765352 Loss: 0.750869
# [104/300] Train Acc: 0.765752 Loss: 0.750199
# [105/300] Train Acc: 0.765646 Loss: 0.748820
# [106/300] Train Acc: 0.765946 Loss: 0.749458
# [107/300] Train Acc: 0.765707 Loss: 0.748634
# [108/300] Train Acc: 0.766047 Loss: 0.749210
# [109/300] Train Acc: 0.766057 Loss: 0.748392
# [110/300] Train Acc: 0.766323 Loss: 0.746568
# [111/300] Train Acc: 0.766850 Loss: 0.746610
# [112/300] Train Acc: 0.766577 Loss: 0.746267
# [113/300] Train Acc: 0.766848 Loss: 0.745661
# [114/300] Train Acc: 0.766527 Loss: 0.744950
# [115/300] Train Acc: 0.767246 Loss: 0.744413
# [116/300] Train Acc: 0.766970 Loss: 0.743890
# [117/300] Train Acc: 0.767396 Loss: 0.744100
# [118/300] Train Acc: 0.767234 Loss: 0.743862
# [119/300] Train Acc: 0.767836 Loss: 0.742545
# [120/300] Train Acc: 0.767880 Loss: 0.742559
# [121/300] Train Acc: 0.767981 Loss: 0.741486
# [122/300] Train Acc: 0.768232 Loss: 0.740564
# [123/300] Train Acc: 0.768208 Loss: 0.740798
# [124/300] Train Acc: 0.768356 Loss: 0.740851
# [125/300] Train Acc: 0.768555 Loss: 0.739371
# [126/300] Train Acc: 0.768613 Loss: 0.738985
# [127/300] Train Acc: 0.768512 Loss: 0.739487
# [128/300] Train Acc: 0.769304 Loss: 0.738312
# [129/300] Train Acc: 0.768612 Loss: 0.737721
# [130/300] Train Acc: 0.769147 Loss: 0.736838
# [131/300] Train Acc: 0.768762 Loss: 0.736962
# [132/300] Train Acc: 0.768940 Loss: 0.737413
# [133/300] Train Acc: 0.769212 Loss: 0.736948
# [134/300] Train Acc: 0.769885 Loss: 0.735933
# [135/300] Train Acc: 0.768999 Loss: 0.736510
# [136/300] Train Acc: 0.769578 Loss: 0.734438
# [137/300] Train Acc: 0.769965 Loss: 0.734301
# [138/300] Train Acc: 0.769686 Loss: 0.734948
# [139/300] Train Acc: 0.769921 Loss: 0.734285
# [140/300] Train Acc: 0.769843 Loss: 0.734022
# [141/300] Train Acc: 0.769789 Loss: 0.734153
# [142/300] Train Acc: 0.770126 Loss: 0.732647
# [143/300] Train Acc: 0.770507 Loss: 0.732824
# [144/300] Train Acc: 0.770608 Loss: 0.731991
# [145/300] Train Acc: 0.770094 Loss: 0.732808
# [146/300] Train Acc: 0.770770 Loss: 0.731918
# [147/300] Train Acc: 0.770217 Loss: 0.733197
# [148/300] Train Acc: 0.770786 Loss: 0.732255
# [149/300] Train Acc: 0.770476 Loss: 0.730918
# [150/300] Train Acc: 0.771547 Loss: 0.729685
# [151/300] Train Acc: 0.771036 Loss: 0.730488
# [152/300] Train Acc: 0.771063 Loss: 0.730877
# [153/300] Train Acc: 0.771381 Loss: 0.729566
# [154/300] Train Acc: 0.771721 Loss: 0.728053
# [155/300] Train Acc: 0.771743 Loss: 0.728795
# [156/300] Train Acc: 0.771158 Loss: 0.729055
# [157/300] Train Acc: 0.770914 Loss: 0.729316
# [158/300] Train Acc: 0.771999 Loss: 0.727432
# [159/300] Train Acc: 0.771682 Loss: 0.728107
# [160/300] Train Acc: 0.771667 Loss: 0.727646
# [161/300] Train Acc: 0.771985 Loss: 0.727671
# [162/300] Train Acc: 0.772263 Loss: 0.726128
# [163/300] Train Acc: 0.772120 Loss: 0.725700
# [164/300] Train Acc: 0.772248 Loss: 0.725260
# [165/300] Train Acc: 0.771965 Loss: 0.726727
# [166/300] Train Acc: 0.771787 Loss: 0.726981
# [167/300] Train Acc: 0.772436 Loss: 0.725942
# [168/300] Train Acc: 0.772030 Loss: 0.726498
# [169/300] Train Acc: 0.772319 Loss: 0.725659
# [170/300] Train Acc: 0.772276 Loss: 0.725442
# [171/300] Train Acc: 0.772204 Loss: 0.725560
# [172/300] Train Acc: 0.772887 Loss: 0.724669
# [173/300] Train Acc: 0.772832 Loss: 0.724101
# [174/300] Train Acc: 0.772282 Loss: 0.724278
# [175/300] Train Acc: 0.773000 Loss: 0.723950
# [176/300] Train Acc: 0.772581 Loss: 0.723380
# [177/300] Train Acc: 0.772893 Loss: 0.723790
# [178/300] Train Acc: 0.773109 Loss: 0.722495
# [179/300] Train Acc: 0.772507 Loss: 0.723971
# [180/300] Train Acc: 0.773240 Loss: 0.723359
# [181/300] Train Acc: 0.773605 Loss: 0.721875
# [182/300] Train Acc: 0.773085 Loss: 0.722833
# [183/300] Train Acc: 0.773320 Loss: 0.722817
# [184/300] Train Acc: 0.773379 Loss: 0.721872
# [185/300] Train Acc: 0.773342 Loss: 0.722066
# [186/300] Train Acc: 0.773423 Loss: 0.721727
# [187/300] Train Acc: 0.773614 Loss: 0.721206
# [188/300] Train Acc: 0.773619 Loss: 0.721417
# [189/300] Train Acc: 0.773170 Loss: 0.721683
# [190/300] Train Acc: 0.773955 Loss: 0.720974
# [191/300] Train Acc: 0.774311 Loss: 0.719481
# [192/300] Train Acc: 0.774030 Loss: 0.720515
# [193/300] Train Acc: 0.774314 Loss: 0.720165
# [194/300] Train Acc: 0.774181 Loss: 0.719997
# [195/300] Train Acc: 0.773959 Loss: 0.720416
# [196/300] Train Acc: 0.773886 Loss: 0.720678
# [197/300] Train Acc: 0.773935 Loss: 0.719441
# [198/300] Train Acc: 0.774170 Loss: 0.718513
# [199/300] Train Acc: 0.773592 Loss: 0.720020
# [200/300] Train Acc: 0.774125 Loss: 0.719049
# [201/300] Train Acc: 0.774237 Loss: 0.719388
# [202/300] Train Acc: 0.774370 Loss: 0.718556
# [203/300] Train Acc: 0.773951 Loss: 0.719551
# [204/300] Train Acc: 0.774587 Loss: 0.717950
# [205/300] Train Acc: 0.774654 Loss: 0.718572
# [206/300] Train Acc: 0.774357 Loss: 0.717792
# [207/300] Train Acc: 0.774033 Loss: 0.718788
# [208/300] Train Acc: 0.774750 Loss: 0.717794
# [209/300] Train Acc: 0.774574 Loss: 0.718118
# [210/300] Train Acc: 0.774488 Loss: 0.718025
# [211/300] Train Acc: 0.774548 Loss: 0.717992
# [212/300] Train Acc: 0.774233 Loss: 0.718828
# [213/300] Train Acc: 0.775018 Loss: 0.717428
# [214/300] Train Acc: 0.774627 Loss: 0.717837
# [215/300] Train Acc: 0.774559 Loss: 0.716908
# [216/300] Train Acc: 0.774695 Loss: 0.716979
# [217/300] Train Acc: 0.775275 Loss: 0.716185
# [218/300] Train Acc: 0.774659 Loss: 0.716347
# [219/300] Train Acc: 0.774906 Loss: 0.715488
# [220/300] Train Acc: 0.775029 Loss: 0.715904
# [221/300] Train Acc: 0.774835 Loss: 0.716510
# [222/300] Train Acc: 0.775070 Loss: 0.715017
# [223/300] Train Acc: 0.775115 Loss: 0.715993
# [224/300] Train Acc: 0.775230 Loss: 0.716205
# [225/300] Train Acc: 0.775223 Loss: 0.715977
# [226/300] Train Acc: 0.774960 Loss: 0.716185
# [227/300] Train Acc: 0.775065 Loss: 0.715109
# [228/300] Train Acc: 0.774912 Loss: 0.714869
# [229/300] Train Acc: 0.775385 Loss: 0.714632
# [230/300] Train Acc: 0.774956 Loss: 0.716565
# [231/300] Train Acc: 0.775563 Loss: 0.714503
# [232/300] Train Acc: 0.775453 Loss: 0.714550
# [233/300] Train Acc: 0.775985 Loss: 0.713778
# [234/300] Train Acc: 0.775566 Loss: 0.714683
# [235/300] Train Acc: 0.775640 Loss: 0.713630
# [236/300] Train Acc: 0.775492 Loss: 0.713575
# [237/300] Train Acc: 0.775915 Loss: 0.712592
# [238/300] Train Acc: 0.775815 Loss: 0.713395
# [239/300] Train Acc: 0.775809 Loss: 0.713919
# [240/300] Train Acc: 0.776215 Loss: 0.713069
# [241/300] Train Acc: 0.775535 Loss: 0.713153
# [242/300] Train Acc: 0.775985 Loss: 0.713360
# [243/300] Train Acc: 0.776032 Loss: 0.712869
# [244/300] Train Acc: 0.775648 Loss: 0.713375
# [245/300] Train Acc: 0.775967 Loss: 0.712567
# [246/300] Train Acc: 0.776523 Loss: 0.712104
# [247/300] Train Acc: 0.776389 Loss: 0.712212
# [248/300] Train Acc: 0.775964 Loss: 0.712898
# [249/300] Train Acc: 0.776227 Loss: 0.712778
# [250/300] Train Acc: 0.775776 Loss: 0.712483
# [251/300] Train Acc: 0.775688 Loss: 0.712187
# [252/300] Train Acc: 0.776243 Loss: 0.711381
# [253/300] Train Acc: 0.776060 Loss: 0.712096
# [254/300] Train Acc: 0.776687 Loss: 0.710881
# [255/300] Train Acc: 0.776166 Loss: 0.711218
# [256/300] Train Acc: 0.776326 Loss: 0.711079
# [257/300] Train Acc: 0.776754 Loss: 0.710592
# [258/300] Train Acc: 0.776474 Loss: 0.711320
# [259/300] Train Acc: 0.776780 Loss: 0.710827
# [260/300] Train Acc: 0.776191 Loss: 0.711383
# [261/300] Train Acc: 0.776131 Loss: 0.711695
# [262/300] Train Acc: 0.776414 Loss: 0.710745
# [263/300] Train Acc: 0.777170 Loss: 0.709591
# [264/300] Train Acc: 0.776507 Loss: 0.711084
# [265/300] Train Acc: 0.776875 Loss: 0.710077
# [266/300] Train Acc: 0.776338 Loss: 0.710934
# [267/300] Train Acc: 0.776614 Loss: 0.710466
# [268/300] Train Acc: 0.776594 Loss: 0.710122
# [269/300] Train Acc: 0.776671 Loss: 0.709859
# [270/300] Train Acc: 0.776316 Loss: 0.708986
# [271/300] Train Acc: 0.776707 Loss: 0.709655
# [272/300] Train Acc: 0.777565 Loss: 0.709239
# [273/300] Train Acc: 0.776772 Loss: 0.710055
# [274/300] Train Acc: 0.776793 Loss: 0.709301
# [275/300] Train Acc: 0.776870 Loss: 0.709145
# [276/300] Train Acc: 0.776974 Loss: 0.708761
# [277/300] Train Acc: 0.777158 Loss: 0.708673
# [278/300] Train Acc: 0.777216 Loss: 0.708615
# [279/300] Train Acc: 0.777038 Loss: 0.707962
# [280/300] Train Acc: 0.777699 Loss: 0.707684
# [281/300] Train Acc: 0.777731 Loss: 0.707233
# [282/300] Train Acc: 0.776654 Loss: 0.708907
# [283/300] Train Acc: 0.777049 Loss: 0.708153
# [284/300] Train Acc: 0.777544 Loss: 0.706682
# [285/300] Train Acc: 0.777101 Loss: 0.708582
# [286/300] Train Acc: 0.777582 Loss: 0.707702
# [287/300] Train Acc: 0.777106 Loss: 0.707616
# [288/300] Train Acc: 0.777296 Loss: 0.707668
# [289/300] Train Acc: 0.777299 Loss: 0.707265
# [290/300] Train Acc: 0.777858 Loss: 0.706992
# [291/300] Train Acc: 0.777254 Loss: 0.707714
# [292/300] Train Acc: 0.777676 Loss: 0.707896
# [293/300] Train Acc: 0.778057 Loss: 0.706357
# [294/300] Train Acc: 0.777615 Loss: 0.707205
# [295/300] Train Acc: 0.777710 Loss: 0.706572
# [296/300] Train Acc: 0.777215 Loss: 0.707229
# [297/300] Train Acc: 0.777793 Loss: 0.707164
# [298/300] Train Acc: 0.777695 Loss: 0.706440
# [299/300] Train Acc: 0.777114 Loss: 0.708144
# [300/300] Train Acc: 0.777302 Loss: 0.708116
# saving model at last epoch
# Finished training after 300 epochs

# %%
def retrain(model_path, num_epoch):
    checkpoint = torch.load(model_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    n_epoch = checkpoint['epoch']
    train_acc = checkpoint['train_acc']
    train_loss = checkpoint['train_loss']
    print('Retrain %d epochs'% num_epoch)
    if len(val_set) > 0:
        val_acc = checkpoint['val_acc']
        val_loss = checkpoint['val_loss']
        print('Resume from epoch {:03d} Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                n_epoch , train_acc, train_loss, val_acc, val_loss
            ))
    else:
        print('Resume from epoch {:03d} Train Acc: {:3.6f} Loss: {:3.6f}'.format(
                n_epoch, train_acc, train_loss
            ))

    
    # start training
    best_acc = 0.0
    epoch = 0
    num_epoch+=n_epoch
    for epoch in range(n_epoch, num_epoch):
        train_acc = 0.0
        train_loss = 0.0
        val_acc = 0.0
        val_loss = 0.0

        # training
        model.train() # set the model to training mode
        for i, data in enumerate(train_loader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad() 
            outputs = model(inputs) 
            batch_loss = criterion(outputs, labels)
            _, train_pred = torch.max(outputs, 1) # get the index of the class with the highest probability
            batch_loss.backward() 
            optimizer.step() 

            train_acc += (train_pred.cpu() == labels.cpu()).sum().item()
            train_loss += batch_loss.item()

        # validation
        if len(val_set) > 0:
            model.eval() # set the model to evaluation mode
            with torch.no_grad():
                for i, data in enumerate(val_loader):
                    inputs, labels = data
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = model(inputs)
                    batch_loss = criterion(outputs, labels) 
                    _, val_pred = torch.max(outputs, 1) 

                    val_acc += (val_pred.cpu() == labels.cpu()).sum().item() # get the index of the class with the highest probability
                    val_loss += batch_loss.item()

                print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                    epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader), val_acc/len(val_set), val_loss/len(val_loader)
                ))

                # if the model improves, save a checkpoint at this epoch
                if val_acc > best_acc:
                    best_acc = val_acc
                    torch.save({
                        'epoch': epoch,
                        'model_state_dict': model.state_dict(),
                        'optimizer_state_dict': optimizer.state_dict(),
                        'train_acc': train_acc/len(train_set),
                        'train_loss': train_loss/len(train_loader),
                        'val_acc': best_acc/len(val_set),
                        'val_loss': val_loss/len(val_loader),
                    }, model_path)
                    #torch.save(model.state_dict(), model_path)
                    print('saving model with acc {:.3f}'.format(best_acc/len(val_set)))

        else:
            print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
                epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader)
            ))
            epoch += 1

    # if not validating, save the last epoch
    if len(val_set) == 0:
        #torch.save(model.state_dict(), model_path)
        torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'train_acc': train_acc/len(train_set),
                    'train_loss': train_loss/len(train_loader),
                }, model_path)
        print('saving model at last epoch')

    print('Finished training after {} epochs'.format(epoch))

# %%
#retrain(model_path, num_epoch=40)

# %% [markdown]
# ## Testing

# %% [markdown]
# Create a testing dataset, and load model from the saved checkpoint.

# %%
# create testing dataset
test_set = TIMITDataset(test, None)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

# create model and load weights from checkpoint
model = Classifier().to(device)
#model.load_state_dict(torch.load(model_path))
model.load_state_dict(torch.load(model_path)['model_state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# Make prediction.

# %%
predict = []
model.eval() # set the model to evaluation mode
with torch.no_grad():
    for i, data in enumerate(test_loader):
        inputs = data
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

        for y in test_pred.cpu().numpy():
            predict.append(y)

# %% [markdown]
# Write prediction to a CSV file.
#
# After finish running this block, download the file `prediction.csv` from the files section on the left-hand side and submit it to Kaggle.

# %%
count = 0
for i in range(1, len(predict)-1):
    previous_ = predict[i-1]
    next_ = predict[i+1]
    current_ = predict[i]
    if (previous_ != current_) and (next_ != current_) and (previous_ == next_):
        print('idx',i,'correct', current_, 'to', previous_)
        predict[i] = previous_
        count +=1

print('total number of correction %d, correction percent %.2f'% (count, count/len(predict)))
# Out:
# idx 563 correct 11 to 3
# idx 597 correct 3 to 11
# idx 604 correct 7 to 3
# idx 669 correct 0 to 1
# idx 753 correct 2 to 1
# idx 968 correct 11 to 3
# idx 1046 correct 19 to 1
# idx 1187 correct 38 to 33
# idx 1266 correct 4 to 12
# idx 1287 correct 7 to 4
# idx 1378 correct 38 to 33
# idx 1446 correct 13 to 12
# idx 1998 correct 14 to 17
# idx 2105 correct 21 to 36
# idx 2367 correct 4 to 12
# idx 2454 correct 4 to 12
# idx 2540 correct 20 to 19
# idx 2794 correct 0 to 5
# idx 2825 correct 25 to 38
# idx 2995 correct 12 to 5
# idx 3049 correct 38 to 19
# idx 3273 correct 13 to 7
# idx 3305 correct 1 to 0
# idx 3337 correct 13 to 12
# idx 3472 correct 2 to 1
# idx 3636 correct 3 to 9
# idx 3706 correct 37 to 0
# idx 3740 correct 19 to 20
# idx 3754 correct 8 to 3
# idx 4001 correct 8 to 3
# idx 4080 correct 33 to 28
# idx 4127 correct 38 to 37
# idx 4131 correct 33 to 37
# idx 4349 correct 8 to 0
# idx 4375 correct 37 to 38
# idx 4710 correct 0 to 8
# idx 4810 correct 32 to 38
# idx 5245 correct 17 to 1
# idx 5355 correct 14 to 17
# idx 5769 correct 18 to 19
# idx 5842 correct 36 to 21
# idx 5977 correct 18 to 14
# idx 6138 correct 24 to 16
# idx 6442 correct 11 to 3
# idx 6595 correct 19 to 18
# idx 6610 correct 35 to 31
# idx 6673 correct 35 to 33
# idx 6680 correct 38 to 35
# idx 6722 correct 9 to 7
# idx 6880 correct 29 to 38
# idx 7496 correct 31 to 35
# idx 8061 correct 11 to 2
# idx 8795 correct 14 to 7
# idx 9004 correct 19 to 18
# idx 9007 correct 19 to 18
# idx 9205 correct 36 to 35
# idx 9442 correct 1 to 3
# idx 9599 correct 32 to 38
# idx 9700 correct 9 to 8
# idx 10644 correct 4 to 1
# idx 10776 correct 9 to 7
# idx 10892 correct 1 to 4
# idx 10906 correct 4 to 7
# idx 10924 correct 11 to 13
# idx 11091 correct 10 to 8
# idx 11129 correct 16 to 13
# idx 11228 correct 9 to 7
# idx 11330 correct 2 to 1
# idx 11358 correct 18 to 19
# idx 11677 correct 17 to 5
# idx 11816 correct 29 to 38
# idx 11841 correct 26 to 23
# idx 11885 correct 15 to 1
# idx 11956 correct 35 to 33
# idx 12015 correct 36 to 31
# idx 12104 correct 18 to 19
# idx 12293 correct 25 to 38
# idx 12385 correct 11 to 7
# idx 12388 correct 3 to 7
# idx 12821 correct 7 to 4
# idx 12839 correct 35 to 33
# idx 13510 correct 27 to 38
# idx 13720 correct 33 to 38
# idx 13937 correct 8 to 0
# idx 13965 correct 4 to 9
# idx 14385 correct 13 to 12
# idx 14578 correct 33 to 32
# idx 14929 correct 8 to 9
# idx 14933 correct 8 to 9
# idx 15029 correct 38 to 34
# idx 15067 correct 12 to 13
# idx 15098 correct 1 to 0
# idx 15103 correct 2 to 3
# idx 15192 correct 12 to 13
# idx 16143 correct 35 to 31
# idx 16446 correct 13 to 4
# idx 16526 correct 13 to 12
# idx 16747 correct 11 to 7
# idx 16974 correct 12 to 13
# idx 16988 correct 14 to 17
# idx 17319 correct 1 to 17
# idx 17634 correct 31 to 22
# idx 17733 correct 9 to 7
# idx 18598 correct 36 to 21
# idx 18680 correct 37 to 36
# idx 18685 correct 37 to 36
# idx 18818 correct 4 to 1
# idx 18875 correct 33 to 34
# idx 19145 correct 12 to 13
# idx 19246 correct 16 to 5
# idx 19816 correct 17 to 14
# idx 19871 correct 31 to 38
# idx 20013 correct 29 to 38
# idx 20129 correct 1 to 8
# idx 20142 correct 29 to 33
# idx 20739 correct 7 to 10
# idx 20858 correct 16 to 13
# idx 20872 correct 1 to 2
# idx 20914 correct 1 to 8
# idx 21151 correct 0 to 1
# idx 21573 correct 7 to 4
# idx 21684 correct 9 to 7
# idx 21749 correct 1 to 4
# idx 21782 correct 38 to 33
# idx 21847 correct 33 to 35
# idx 21889 correct 6 to 1
# idx 21966 correct 34 to 38
# idx 21996 correct 0 to 5
# idx 22207 correct 3 to 2
# idx 22209 correct 3 to 2
# idx 22240 correct 12 to 7
# idx 22474 correct 1 to 19
# idx 22508 correct 29 to 22
# idx 23086 correct 5 to 1
# idx 23151 correct 2 to 3
# idx 23279 correct 2 to 1
# idx 23305 correct 1 to 4
# idx 23494 correct 31 to 35
# idx 23608 correct 13 to 4
# idx 23768 correct 26 to 1
# idx 23795 correct 2 to 3
# idx 23806 correct 10 to 7
# idx 23919 correct 10 to 7
# idx 23977 correct 7 to 4
# idx 24075 correct 38 to 7
# idx 24110 correct 7 to 9
# idx 24156 correct 1 to 17
# idx 24173 correct 4 to 1
# idx 24217 correct 38 to 19
# idx 24447 correct 38 to 3
# idx 24450 correct 38 to 3
# idx 24453 correct 9 to 3
# idx 24804 correct 9 to 7
# idx 24898 correct 34 to 38
# idx 25182 correct 33 to 38
# idx 25533 correct 7 to 4
# idx 25621 correct 2 to 3
# idx 25632 correct 20 to 19
# idx 26088 correct 0 to 1
# idx 26091 correct 26 to 1
# idx 26304 correct 32 to 33
# idx 26333 correct 7 to 10
# idx 26406 correct 4 to 1
# idx 26572 correct 9 to 4
# idx 26829 correct 13 to 12
# idx 27115 correct 33 to 38
# idx 27142 correct 38 to 34
# idx 27202 correct 19 to 20
# idx 27332 correct 20 to 19
# idx 27530 correct 4 to 12
# idx 27808 correct 1 to 4
# idx 28022 correct 18 to 32
# idx 28040 correct 18 to 38
# idx 28167 correct 4 to 7
# idx 28194 correct 19 to 4
# idx 28249 correct 12 to 4
# idx 28690 correct 4 to 2
# idx 28744 correct 2 to 4
# idx 28845 correct 10 to 7
# idx 29239 correct 5 to 0
# idx 29268 correct 5 to 1
# idx 29394 correct 7 to 9
# idx 29804 correct 37 to 30
# idx 29867 correct 23 to 26
# idx 30279 correct 27 to 38
# idx 30429 correct 23 to 15
# idx 31041 correct 9 to 7
# idx 31079 correct 2 to 1
# idx 31154 correct 18 to 19
# idx 31297 correct 32 to 13
# idx 31423 correct 0 to 8
# idx 31557 correct 29 to 38
# idx 31566 correct 8 to 1
# idx 31726 correct 19 to 18
# idx 32531 correct 1 to 0
# idx 32674 correct 3 to 7
# idx 32784 correct 1 to 4
# idx 33441 correct 25 to 29
# idx 34343 correct 33 to 38
# idx 34414 correct 9 to 3
# idx 34516 correct 0 to 1
# idx 34732 correct 38 to 34
# idx 35009 correct 10 to 12
# idx 35327 correct 21 to 29
# idx 35488 correct 19 to 20
# idx 35570 correct 17 to 7
# idx 35599 correct 26 to 32
# idx 35743 correct 1 to 19
# idx 35859 correct 38 to 17
# idx 36239 correct 3 to 2
# idx 36242 correct 3 to 2
# idx 36412 correct 2 to 4
# idx 36774 correct 31 to 35
# idx 37103 correct 32 to 38
# idx 37315 correct 14 to 17
# idx 37518 correct 8 to 0
# idx 37640 correct 13 to 4
# idx 37816 correct 2 to 1
# idx 38957 correct 1 to 2
# idx 39414 correct 2 to 1
# idx 39752 correct 36 to 22
# idx 39960 correct 29 to 30
# idx 40237 correct 34 to 38
# idx 40264 correct 7 to 17
# idx 40599 correct 11 to 7
# idx 40828 correct 36 to 35
# idx 40964 correct 7 to 4
# idx 41249 correct 20 to 19
# idx 41430 correct 3 to 4
# idx 41698 correct 35 to 31
# idx 41854 correct 31 to 35
# idx 42019 correct 33 to 38
# idx 42205 correct 20 to 19
# idx 42218 correct 5 to 1
# idx 42380 correct 7 to 9
# idx 42400 correct 29 to 38
# idx 42573 correct 35 to 31
# idx 42752 correct 13 to 7
# idx 42994 correct 37 to 30
# idx 43069 correct 3 to 2
# idx 43161 correct 31 to 35
# idx 43310 correct 19 to 20
# idx 44344 correct 4 to 1
# idx 44433 correct 16 to 13
# idx 44436 correct 12 to 13
# idx 44538 correct 26 to 1
# idx 44767 correct 7 to 9
# idx 44981 correct 1 to 17
# idx 44986 correct 38 to 19
# idx 45236 correct 6 to 1
# idx 45326 correct 31 to 35
# idx 45467 correct 32 to 38
# idx 45643 correct 17 to 1
# idx 45686 correct 14 to 17
# idx 45811 correct 7 to 9
# idx 45945 correct 21 to 22
# idx 45977 correct 31 to 35
# idx 46758 correct 34 to 33
# idx 46804 correct 34 to 33
# idx 46868 correct 0 to 1
# idx 46993 correct 17 to 2
# idx 46996 correct 17 to 2
# idx 47005 correct 31 to 35
# idx 47175 correct 18 to 19
# idx 47184 correct 32 to 28
# idx 47237 correct 12 to 7
# idx 47293 correct 9 to 3
# idx 47390 correct 21 to 29
# idx 47443 correct 38 to 9
# idx 47650 correct 31 to 35
# idx 47799 correct 19 to 18
# idx 47959 correct 37 to 28
# idx 48067 correct 2 to 3
# idx 48139 correct 31 to 35
# idx 48228 correct 1 to 2
# idx 48489 correct 6 to 12
# idx 48758 correct 35 to 31
# idx 48973 correct 23 to 38
# idx 48999 correct 14 to 17
# idx 49021 correct 19 to 18
# idx 49720 correct 26 to 38
# idx 49889 correct 8 to 9
# idx 49989 correct 2 to 1
# idx 50213 correct 38 to 13
# idx 50383 correct 29 to 30
# idx 50449 correct 36 to 29
# idx 50728 correct 2 to 12
# idx 50888 correct 38 to 34
# idx 50892 correct 38 to 34
# idx 51122 correct 19 to 38
# idx 51223 correct 14 to 13
# idx 51240 correct 9 to 3
# idx 51323 correct 28 to 38
# idx 51327 correct 23 to 28
# idx 51357 correct 13 to 5
# idx 51367 correct 9 to 7
# idx 51612 correct 3 to 7
# idx 51705 correct 2 to 8
# idx 52456 correct 3 to 9
# idx 52465 correct 35 to 36
# idx 52505 correct 13 to 12
# idx 52589 correct 7 to 9
# idx 52812 correct 11 to 7
# idx 53087 correct 29 to 38
# idx 53224 correct 9 to 8
# idx 53555 correct 5 to 12
# idx 54240 correct 35 to 36
# idx 54372 correct 38 to 19
# idx 54640 correct 1 to 2
# idx 54789 correct 38 to 29
# idx 54930 correct 37 to 38
# idx 54953 correct 7 to 3
# idx 55130 correct 4 to 3
# idx 55160 correct 31 to 35
# idx 55194 correct 23 to 13
# idx 55197 correct 31 to 23
# idx 55321 correct 1 to 2
# idx 55436 correct 17 to 14
# idx 55526 correct 35 to 31
# idx 55576 correct 7 to 12
# idx 55647 correct 4 to 13
# idx 55901 correct 12 to 7
# idx 55930 correct 35 to 31
# idx 55984 correct 28 to 33
# idx 56240 correct 18 to 19
# idx 56824 correct 14 to 7
# idx 57656 correct 4 to 7
# idx 58225 correct 14 to 17
# idx 58474 correct 13 to 5
# idx 58615 correct 18 to 19
# idx 58772 correct 13 to 38
# idx 58862 correct 25 to 38
# idx 58944 correct 0 to 1
# idx 59065 correct 4 to 1
# idx 59101 correct 18 to 16
# idx 59207 correct 20 to 19
# idx 59224 correct 35 to 31
# idx 59230 correct 2 to 3
# idx 59232 correct 2 to 3
# idx 59310 correct 29 to 28
# idx 59410 correct 4 to 5
# idx 59965 correct 3 to 9
# idx 59975 correct 9 to 3
# idx 59977 correct 9 to 3
# idx 60101 correct 34 to 38
# idx 60429 correct 10 to 7
# idx 60707 correct 1 to 5
# idx 60960 correct 14 to 17
# idx 60996 correct 38 to 33
# idx 61201 correct 3 to 8
# idx 61381 correct 38 to 33
# idx 61687 correct 2 to 1
# idx 61855 correct 33 to 38
# idx 61992 correct 0 to 1
# idx 62042 correct 38 to 33
# idx 62338 correct 16 to 7
# idx 62534 correct 33 to 38
# idx 62570 correct 3 to 9
# idx 62753 correct 17 to 2
# idx 62969 correct 32 to 13
# idx 63053 correct 6 to 7
# idx 63983 correct 31 to 35
# idx 64193 correct 13 to 12
# idx 64709 correct 1 to 8
# idx 64864 correct 23 to 38
# idx 64895 correct 1 to 2
# idx 64923 correct 38 to 23
# idx 64940 correct 17 to 1
# idx 64983 correct 4 to 13
# idx 65024 correct 16 to 7
# idx 65042 correct 12 to 13
# idx 65047 correct 13 to 4
# idx 65083 correct 12 to 13
# idx 65306 correct 13 to 12
# idx 65706 correct 12 to 13
# idx 65731 correct 7 to 4
# idx 65864 correct 37 to 28
# idx 65902 correct 0 to 8
# idx 65983 correct 19 to 20
# idx 66002 correct 3 to 2
# idx 66255 correct 29 to 38
# idx 66882 correct 8 to 2
# idx 66988 correct 17 to 2
# idx 67074 correct 5 to 1
# idx 67333 correct 13 to 11
# idx 67526 correct 38 to 32
# idx 67579 correct 33 to 38
# idx 67588 correct 9 to 4
# idx 67680 correct 12 to 16
# idx 67689 correct 4 to 7
# idx 67732 correct 18 to 19
# idx 67745 correct 19 to 38
# idx 67792 correct 8 to 0
# idx 68141 correct 36 to 35
# idx 68552 correct 8 to 9
# idx 68556 correct 19 to 20
# idx 68584 correct 9 to 8
# idx 68619 correct 1 to 2
# idx 68857 correct 33 to 29
# idx 69184 correct 3 to 2
# idx 69777 correct 38 to 33
# idx 69784 correct 38 to 33
# idx 69869 correct 4 to 7
# idx 70486 correct 7 to 11
# idx 70580 correct 36 to 35
# idx 70964 correct 8 to 10
# idx 71204 correct 11 to 3
# idx 71407 correct 4 to 5
# idx 71497 correct 37 to 38
# idx 71544 correct 35 to 31
# idx 72193 correct 7 to 9
# idx 72240 correct 17 to 14
# idx 72245 correct 17 to 14
# idx 72340 correct 3 to 2
# idx 72844 correct 4 to 12
# idx 72888 correct 9 to 8
# idx 73120 correct 1 to 3
# idx 73337 correct 31 to 32
# idx 73410 correct 8 to 14
# idx 73645 correct 38 to 8
# idx 73854 correct 22 to 31
# idx 74363 correct 4 to 2
# idx 74534 correct 4 to 2
# idx 75161 correct 0 to 1
# idx 75355 correct 25 to 38
# idx 75369 correct 3 to 9
# idx 75505 correct 34 to 38
# idx 75526 correct 29 to 30
# idx 75978 correct 23 to 29
# idx 75996 correct 5 to 1
# idx 76086 correct 14 to 17
# idx 76160 correct 35 to 31
# idx 76162 correct 35 to 31
# idx 76613 correct 13 to 10
# idx 76794 correct 4 to 1
# idx 77017 correct 0 to 1
# idx 77725 correct 0 to 1
# idx 77824 correct 33 to 38
# idx 77834 correct 29 to 38
# idx 78352 correct 31 to 35
# idx 78485 correct 5 to 1
# idx 78759 correct 11 to 12
# idx 78780 correct 38 to 33
# idx 79090 correct 2 to 11
# idx 79173 correct 0 to 1
# idx 79312 correct 38 to 35
# idx 79868 correct 27 to 38
# idx 79964 correct 35 to 31
# idx 80029 correct 0 to 1
# idx 80134 correct 2 to 1
# idx 80152 correct 29 to 38
# idx 80266 correct 18 to 19
# idx 80284 correct 13 to 11
# idx 80286 correct 13 to 11
# idx 80602 correct 10 to 7
# idx 80918 correct 5 to 1
# idx 81034 correct 33 to 38
# idx 81038 correct 19 to 4
# idx 81111 correct 2 to 4
# idx 81277 correct 34 to 33
# idx 81458 correct 4 to 7
# idx 81460 correct 3 to 7
# idx 81492 correct 7 to 4
# idx 81498 correct 13 to 4
# idx 81610 correct 3 to 2
# idx 82328 correct 1 to 38
# idx 82505 correct 11 to 7
# idx 82730 correct 4 to 7
# idx 82976 correct 12 to 2
# idx 82983 correct 12 to 13
# idx 82990 correct 18 to 37
# idx 83104 correct 7 to 12
# idx 83164 correct 32 to 38
# idx 83292 correct 0 to 5
# idx 83342 correct 4 to 1
# idx 83968 correct 10 to 7
# idx 84166 correct 4 to 17
# idx 84551 correct 1 to 4
# idx 84611 correct 1 to 17
# idx 85421 correct 30 to 38
# idx 85602 correct 12 to 7
# idx 85624 correct 19 to 20
# idx 85770 correct 31 to 35
# idx 85924 correct 11 to 7
# idx 86098 correct 2 to 1
# idx 86357 correct 31 to 35
# idx 86575 correct 29 to 25
# idx 86677 correct 2 to 3
# idx 86754 correct 2 to 4
# idx 87042 correct 35 to 31
# idx 87139 correct 11 to 3
# idx 87189 correct 7 to 3
# idx 87224 correct 1 to 38
# idx 88103 correct 11 to 3
# idx 88510 correct 12 to 2
# idx 88532 correct 29 to 33
# idx 88543 correct 33 to 38
# idx 88747 correct 33 to 36
# idx 89108 correct 29 to 21
# idx 89386 correct 31 to 35
# idx 89639 correct 23 to 32
# idx 89792 correct 1 to 4
# idx 90797 correct 19 to 18
# idx 91054 correct 6 to 1
# idx 91075 correct 2 to 1
# idx 91148 correct 1 to 0
# idx 91547 correct 31 to 35
# idx 91713 correct 18 to 38
# idx 91870 correct 30 to 38
# idx 92127 correct 33 to 32
# idx 92439 correct 21 to 22
# idx 92624 correct 13 to 16
# idx 92660 correct 1 to 17
# idx 94098 correct 36 to 21
# idx 94256 correct 12 to 13
# idx 94382 correct 7 to 17
# idx 94426 correct 19 to 20
# idx 94545 correct 36 to 22
# idx 94640 correct 30 to 38
# idx 95107 correct 38 to 35
# idx 95235 correct 31 to 35
# idx 96000 correct 8 to 2
# idx 96028 correct 18 to 19
# idx 96165 correct 26 to 7
# idx 96530 correct 37 to 33
# idx 96658 correct 2 to 1
# idx 96713 correct 14 to 7
# idx 96967 correct 38 to 26
# idx 97235 correct 15 to 0
# idx 97245 correct 2 to 3
# idx 97437 correct 22 to 36
# idx 97574 correct 33 to 35
# idx 97989 correct 36 to 35
# idx 98505 correct 7 to 9
# idx 98525 correct 38 to 1
# idx 98631 correct 19 to 18
# idx 98967 correct 7 to 4
# idx 99000 correct 18 to 19
# idx 99167 correct 4 to 16
# idx 99472 correct 7 to 10
# idx 99803 correct 31 to 35
# idx 99946 correct 17 to 14
# idx 100298 correct 4 to 7
# idx 101164 correct 21 to 36
# idx 101166 correct 21 to 36
# idx 101196 correct 1 to 5
# idx 101504 correct 11 to 3
# idx 101569 correct 25 to 23
# idx 101618 correct 13 to 4
# idx 101620 correct 7 to 4
# idx 101661 correct 4 to 2
# idx 101827 correct 2 to 17
# idx 101892 correct 5 to 17
# idx 101952 correct 33 to 38
# idx 102002 correct 17 to 1
# idx 102014 correct 31 to 35
# idx 102052 correct 1 to 12
# idx 102056 correct 13 to 12
# idx 102296 correct 8 to 3
# idx 102440 correct 2 to 1
# idx 102499 correct 7 to 10
# idx 102824 correct 33 to 38
# idx 102851 correct 22 to 21
# idx 103026 correct 2 to 1
# idx 103582 correct 38 to 28
# idx 103890 correct 35 to 31
# idx 103949 correct 2 to 1
# idx 104079 correct 33 to 34
# idx 104187 correct 34 to 38
# idx 104253 correct 12 to 5
# idx 104512 correct 5 to 1
# idx 104570 correct 8 to 2
# idx 104573 correct 7 to 11
# idx 105075 correct 4 to 13
# idx 105201 correct 31 to 35
# idx 105308 correct 4 to 30
# idx 105323 correct 1 to 8
# idx 105518 correct 9 to 7
# idx 105663 correct 1 to 8
# idx 105796 correct 30 to 38
# idx 106503 correct 14 to 17
# idx 106541 correct 21 to 22
# idx 106646 correct 31 to 35
# idx 106652 correct 38 to 33
# idx 106688 correct 34 to 38
# idx 106792 correct 2 to 4
# idx 106892 correct 19 to 38
# idx 106962 correct 12 to 4
# idx 106964 correct 11 to 4
# idx 107888 correct 0 to 15
# idx 108412 correct 9 to 7
# idx 108921 correct 28 to 38
# idx 108963 correct 7 to 9
# idx 108966 correct 3 to 9
# idx 108998 correct 0 to 1
# idx 109225 correct 16 to 4
# idx 109286 correct 5 to 1
# idx 109339 correct 19 to 1
# idx 109485 correct 36 to 21
# idx 109498 correct 3 to 2
# idx 109591 correct 8 to 1
# idx 110273 correct 33 to 38
# idx 110275 correct 34 to 38
# idx 110424 correct 38 to 30
# idx 110572 correct 12 to 7
# idx 110640 correct 8 to 3
# idx 110643 correct 2 to 3
# idx 110688 correct 30 to 38
# idx 110690 correct 30 to 38
# idx 111217 correct 4 to 12
# idx 111243 correct 31 to 35
# idx 111621 correct 8 to 2
# idx 111674 correct 17 to 14
# idx 112435 correct 14 to 17
# idx 112820 correct 7 to 9
# idx 112853 correct 7 to 9
# idx 113018 correct 30 to 29
# idx 113981 correct 1 to 0
# idx 114122 correct 17 to 2
# idx 114271 correct 21 to 35
# idx 114767 correct 5 to 12
# idx 114967 correct 1 to 2
# idx 115023 correct 36 to 21
# idx 115177 correct 31 to 36
# idx 115602 correct 12 to 13
# idx 115670 correct 3 to 11
# idx 115868 correct 34 to 33
# idx 115925 correct 31 to 35
# idx 116059 correct 28 to 38
# idx 116287 correct 2 to 17
# idx 116538 correct 1 to 2
# idx 116675 correct 30 to 38
# idx 117157 correct 38 to 30
# idx 117236 correct 22 to 30
# idx 117266 correct 11 to 3
# idx 117515 correct 25 to 38
# idx 117732 correct 11 to 7
# idx 117907 correct 30 to 38
# idx 118103 correct 35 to 31
# idx 118128 correct 19 to 18
# idx 119252 correct 4 to 17
# idx 119554 correct 9 to 7
# idx 119568 correct 29 to 21
# idx 119583 correct 9 to 7
# idx 119589 correct 9 to 7
# idx 119771 correct 17 to 1
# idx 120076 correct 2 to 1
# idx 120091 correct 38 to 13
# idx 120132 correct 35 to 34
# idx 120379 correct 21 to 29
# idx 120389 correct 17 to 1
# idx 120400 correct 22 to 36
# idx 120482 correct 38 to 30
# idx 121168 correct 1 to 0
# idx 121356 correct 12 to 4
# idx 121474 correct 4 to 1
# idx 121682 correct 34 to 33
# idx 121732 correct 5 to 1
# idx 121766 correct 2 to 1
# idx 122110 correct 11 to 7
# idx 122439 correct 9 to 7
# idx 122657 correct 9 to 4
# idx 122684 correct 23 to 34
# idx 123106 correct 32 to 33
# idx 123138 correct 19 to 38
# idx 123554 correct 19 to 38
# idx 123927 correct 4 to 13
# idx 123929 correct 4 to 13
# idx 124158 correct 26 to 1
# idx 124427 correct 1 to 0
# idx 124611 correct 4 to 9
# idx 124796 correct 28 to 38
# idx 124845 correct 14 to 17
# idx 125008 correct 13 to 16
# idx 125019 correct 35 to 31
# idx 125063 correct 0 to 1
# idx 125147 correct 35 to 36
# idx 125465 correct 19 to 38
# idx 125512 correct 38 to 7
# idx 126738 correct 5 to 0
# idx 126746 correct 36 to 33
# idx 126749 correct 35 to 33
# idx 126994 correct 31 to 35
# idx 127064 correct 21 to 33
# idx 127292 correct 11 to 7
# idx 127314 correct 8 to 1
# idx 127588 correct 7 to 12
# idx 127825 correct 8 to 2
# idx 128068 correct 3 to 9
# idx 128213 correct 21 to 36
# idx 128389 correct 25 to 22
# idx 128462 correct 29 to 38
# idx 129041 correct 17 to 1
# idx 129191 correct 38 to 33
# idx 129981 correct 29 to 38
# idx 130067 correct 8 to 5
# idx 130454 correct 33 to 35
# idx 130555 correct 0 to 1
# idx 130614 correct 20 to 19
# idx 130896 correct 19 to 1
# idx 132200 correct 1 to 2
# idx 132687 correct 2 to 12
# idx 132733 correct 1 to 4
# idx 132828 correct 12 to 13
# idx 132878 correct 0 to 1
# idx 133434 correct 4 to 9
# idx 133450 correct 8 to 1
# idx 133466 correct 30 to 28
# idx 133521 correct 14 to 17
# idx 133683 correct 12 to 4
# idx 133846 correct 19 to 7
# idx 133888 correct 1 to 4
# idx 133960 correct 13 to 8
# idx 134126 correct 20 to 19
# idx 134471 correct 30 to 38
# idx 134535 correct 7 to 4
# idx 134803 correct 4 to 7
# idx 134823 correct 35 to 29
# idx 134826 correct 31 to 29
# idx 134962 correct 3 to 9
# idx 135060 correct 16 to 38
# idx 135073 correct 31 to 35
# idx 135150 correct 38 to 37
# idx 135490 correct 7 to 17
# idx 135672 correct 9 to 8
# idx 135704 correct 2 to 8
# idx 135832 correct 7 to 4
# idx 135836 correct 3 to 4
# idx 135868 correct 20 to 19
# idx 136102 correct 38 to 34
# idx 136109 correct 34 to 35
# idx 136450 correct 36 to 31
# idx 136581 correct 35 to 31
# idx 136723 correct 37 to 38
# idx 136736 correct 20 to 19
# idx 137171 correct 34 to 23
# idx 137472 correct 13 to 5
# idx 137619 correct 35 to 31
# idx 137699 correct 29 to 38
# idx 137778 correct 38 to 32
# idx 137935 correct 38 to 33
# idx 137938 correct 38 to 33
# idx 138211 correct 2 to 1
# idx 138288 correct 35 to 33
# idx 138398 correct 4 to 7
# idx 138449 correct 5 to 1
# idx 138740 correct 18 to 38
# idx 139109 correct 13 to 7
# idx 139315 correct 10 to 14
# idx 139401 correct 37 to 38
# idx 140062 correct 34 to 33
# idx 140247 correct 2 to 1
# idx 140390 correct 13 to 5
# idx 140392 correct 13 to 5
# idx 140438 correct 7 to 4
# idx 140950 correct 27 to 30
# idx 140993 correct 1 to 8
# idx 141375 correct 21 to 29
# idx 141450 correct 14 to 13
# idx 141628 correct 4 to 2
# idx 142290 correct 25 to 33
# idx 142767 correct 1 to 19
# idx 142879 correct 2 to 1
# idx 142926 correct 31 to 35
# idx 143016 correct 32 to 38
# idx 143096 correct 36 to 21
# idx 143210 correct 33 to 38
# idx 143218 correct 30 to 38
# idx 143227 correct 8 to 3
# idx 143495 correct 31 to 35
# idx 143504 correct 38 to 33
# idx 143544 correct 27 to 38
# idx 143734 correct 4 to 12
# idx 144076 correct 9 to 3
# idx 144184 correct 31 to 35
# idx 144214 correct 34 to 38
# idx 144218 correct 25 to 38
# idx 144407 correct 35 to 31
# idx 144538 correct 3 to 2
# idx 145064 correct 9 to 3
# idx 145072 correct 3 to 9
# idx 145077 correct 11 to 3
# idx 145102 correct 1 to 17
# idx 145406 correct 38 to 23
# idx 145707 correct 1 to 5
# idx 146152 correct 4 to 2
# idx 146340 correct 18 to 14
# idx 146521 correct 7 to 4
# idx 146605 correct 33 to 38
# idx 146743 correct 8 to 0
# idx 146751 correct 38 to 33
# idx 146753 correct 38 to 33
# idx 146758 correct 28 to 33
# idx 146793 correct 21 to 29
# idx 146979 correct 7 to 9
# idx 147362 correct 19 to 20
# idx 148106 correct 13 to 12
# idx 148124 correct 7 to 9
# idx 148270 correct 36 to 35
# idx 148285 correct 5 to 1
# idx 148325 correct 26 to 38
# idx 148617 correct 35 to 31
# idx 148621 correct 31 to 35
# idx 148754 correct 18 to 5
# idx 148986 correct 2 to 1
# idx 149000 correct 31 to 35
# idx 149151 correct 14 to 10
# idx 149407 correct 1 to 0
# idx 149680 correct 12 to 4
# idx 149682 correct 1 to 4
# idx 149787 correct 33 to 38
# idx 149890 correct 1 to 0
# idx 149968 correct 33 to 38
# idx 150225 correct 8 to 0
# idx 150287 correct 1 to 17
# idx 150946 correct 29 to 37
# idx 151473 correct 35 to 31
# idx 151475 correct 35 to 31
# idx 152039 correct 3 to 2
# idx 152201 correct 21 to 22
# idx 152401 correct 14 to 17
# idx 152727 correct 18 to 19
# idx 152816 correct 22 to 36
# idx 152980 correct 4 to 17
# idx 152989 correct 1 to 4
# idx 153012 correct 3 to 11
# idx 153047 correct 21 to 29
# idx 154049 correct 33 to 38
# idx 154524 correct 13 to 7
# idx 154761 correct 31 to 35
# idx 154796 correct 2 to 8
# idx 155001 correct 4 to 13
# idx 155261 correct 38 to 32
# idx 155280 correct 23 to 38
# idx 155364 correct 12 to 5
# idx 155725 correct 38 to 35
# idx 156458 correct 2 to 12
# idx 156494 correct 31 to 35
# idx 156671 correct 32 to 33
# idx 157014 correct 38 to 33
# idx 157026 correct 5 to 1
# idx 157115 correct 7 to 9
# idx 157237 correct 0 to 8
# idx 157307 correct 5 to 1
# idx 157322 correct 19 to 12
# idx 157378 correct 12 to 13
# idx 157383 correct 7 to 12
# idx 157485 correct 1 to 0
# idx 158064 correct 34 to 35
# idx 158077 correct 18 to 19
# idx 158089 correct 29 to 33
# idx 158712 correct 17 to 14
# idx 158789 correct 9 to 3
# idx 158817 correct 30 to 38
# idx 158859 correct 3 to 1
# idx 159137 correct 36 to 21
# idx 159245 correct 0 to 5
# idx 159527 correct 31 to 35
# idx 159792 correct 2 to 1
# idx 159809 correct 23 to 38
# idx 159852 correct 33 to 38
# idx 159933 correct 13 to 16
# idx 160094 correct 2 to 4
# idx 160372 correct 32 to 38
# idx 160469 correct 2 to 17
# idx 160602 correct 11 to 3
# idx 160605 correct 4 to 3
# idx 160830 correct 2 to 7
# idx 160892 correct 32 to 38
# idx 161454 correct 27 to 38
# idx 161741 correct 1 to 2
# idx 162259 correct 4 to 10
# idx 162337 correct 19 to 38
# idx 162454 correct 3 to 2
# idx 162651 correct 35 to 31
# idx 162818 correct 15 to 1
# idx 163210 correct 33 to 34
# idx 163232 correct 17 to 14
# idx 163733 correct 32 to 38
# idx 164191 correct 38 to 3
# idx 164217 correct 30 to 38
# idx 164332 correct 9 to 3
# idx 164335 correct 9 to 3
# idx 164448 correct 3 to 9
# idx 164629 correct 9 to 7
# idx 165198 correct 1 to 4
# idx 165247 correct 23 to 34
# idx 165738 correct 10 to 12
# idx 166034 correct 33 to 32
# idx 166080 correct 19 to 0
# idx 166086 correct 22 to 36
# idx 166350 correct 13 to 12
# idx 166993 correct 38 to 32
# idx 167138 correct 11 to 3
# idx 167197 correct 18 to 4
# idx 167207 correct 38 to 33
# idx 167358 correct 28 to 38
# idx 167427 correct 1 to 0
# idx 167498 correct 7 to 3
# idx 167510 correct 4 to 13
# idx 167527 correct 26 to 9
# idx 167980 correct 38 to 19
# idx 167988 correct 9 to 13
# idx 168021 correct 1 to 0
# idx 168092 correct 31 to 36
# idx 168103 correct 14 to 17
# idx 168263 correct 4 to 2
# idx 168334 correct 38 to 33
# idx 168336 correct 38 to 33
# idx 168641 correct 35 to 31
# idx 168680 correct 1 to 0
# idx 168727 correct 38 to 33
# idx 168882 correct 29 to 30
# idx 169387 correct 10 to 38
# idx 169574 correct 7 to 12
# idx 170324 correct 1 to 2
# idx 170328 correct 3 to 2
# idx 170418 correct 31 to 35
# idx 170637 correct 2 to 1
# idx 171065 correct 5 to 1
# idx 171690 correct 1 to 8
# idx 171940 correct 9 to 7
# idx 172308 correct 38 to 23
# idx 172344 correct 3 to 2
# idx 172446 correct 32 to 38
# idx 172520 correct 31 to 35
# idx 172910 correct 7 to 3
# idx 172956 correct 38 to 33
# idx 173169 correct 28 to 30
# idx 173520 correct 13 to 4
# idx 173542 correct 10 to 14
# idx 173978 correct 18 to 13
# idx 174010 correct 9 to 7
# idx 174557 correct 0 to 1
# idx 174727 correct 7 to 10
# idx 174736 correct 10 to 7
# idx 174927 correct 32 to 38
# idx 174960 correct 29 to 38
# idx 175154 correct 18 to 19
# idx 175169 correct 3 to 11
# idx 175206 correct 33 to 38
# idx 175210 correct 38 to 33
# idx 175244 correct 33 to 32
# idx 175301 correct 35 to 31
# idx 175309 correct 4 to 7
# idx 175312 correct 4 to 7
# idx 175832 correct 19 to 11
# idx 175915 correct 35 to 31
# idx 175932 correct 2 to 17
# idx 175990 correct 0 to 1
# idx 176194 correct 19 to 13
# idx 176594 correct 33 to 38
# idx 176612 correct 13 to 11
# idx 176719 correct 12 to 4
# idx 176776 correct 13 to 4
# idx 176809 correct 4 to 1
# idx 176964 correct 1 to 19
# idx 177197 correct 0 to 1
# idx 177449 correct 1 to 0
# idx 177647 correct 25 to 29
# idx 177787 correct 32 to 16
# idx 177798 correct 38 to 31
# idx 177812 correct 7 to 9
# idx 177845 correct 7 to 3
# idx 178217 correct 36 to 21
# idx 178271 correct 20 to 19
# idx 178561 correct 35 to 31
# idx 178683 correct 29 to 38
# idx 178714 correct 31 to 13
# idx 178719 correct 6 to 4
# idx 178810 correct 31 to 35
# idx 178844 correct 7 to 4
# idx 178995 correct 36 to 35
# idx 179029 correct 7 to 9
# idx 179034 correct 14 to 9
# idx 179089 correct 10 to 8
# idx 179190 correct 1 to 8
# idx 179218 correct 31 to 22
# idx 179424 correct 2 to 3
# idx 179609 correct 29 to 38
# idx 179701 correct 9 to 7
# idx 179904 correct 23 to 38
# idx 180448 correct 14 to 8
# idx 180488 correct 12 to 13
# idx 180557 correct 23 to 38
# idx 180607 correct 35 to 31
# idx 180779 correct 25 to 23
# idx 180786 correct 0 to 1
# idx 181246 correct 33 to 38
# idx 181477 correct 4 to 1
# idx 181569 correct 23 to 13
# idx 181756 correct 4 to 3
# idx 181782 correct 30 to 37
# idx 181960 correct 7 to 12
# idx 182004 correct 7 to 9
# idx 182156 correct 30 to 38
# idx 182488 correct 1 to 0
# idx 182677 correct 31 to 35
# idx 182704 correct 4 to 7
# idx 182756 correct 17 to 4
# idx 182760 correct 18 to 19
# idx 182780 correct 29 to 30
# idx 183499 correct 30 to 38
# idx 183575 correct 4 to 2
# idx 183758 correct 11 to 12
# idx 183869 correct 23 to 38
# idx 183933 correct 5 to 19
# idx 183944 correct 31 to 35
# idx 184275 correct 21 to 22
# idx 184550 correct 4 to 7
# idx 184570 correct 17 to 1
# idx 184867 correct 0 to 1
# idx 184893 correct 18 to 19
# idx 184901 correct 9 to 14
# idx 184907 correct 2 to 3
# idx 185217 correct 1 to 8
# idx 185319 correct 32 to 23
# idx 185445 correct 38 to 31
# idx 185471 correct 26 to 32
# idx 185560 correct 38 to 13
# idx 185586 correct 31 to 35
# idx 185692 correct 13 to 7
# idx 185866 correct 7 to 9
# idx 186248 correct 30 to 27
# idx 186575 correct 4 to 38
# idx 186582 correct 7 to 10
# idx 186915 correct 35 to 36
# idx 186940 correct 1 to 0
# idx 187034 correct 1 to 2
# idx 187097 correct 37 to 30
# idx 187107 correct 34 to 38
# idx 187218 correct 11 to 12
# idx 187220 correct 13 to 12
# idx 187255 correct 11 to 3
# idx 187431 correct 3 to 1
# idx 187742 correct 4 to 1
# idx 187847 correct 4 to 13
# idx 187924 correct 37 to 38
# idx 188116 correct 38 to 18
# idx 188177 correct 8 to 9
# idx 188293 correct 38 to 31
# idx 188497 correct 3 to 2
# idx 189024 correct 20 to 19
# idx 189337 correct 9 to 7
# idx 189425 correct 12 to 7
# idx 189551 correct 2 to 3
# idx 189905 correct 3 to 36
# idx 189956 correct 29 to 38
# idx 190048 correct 38 to 13
# idx 190067 correct 7 to 9
# idx 190090 correct 8 to 2
# idx 190127 correct 31 to 35
# idx 190350 correct 8 to 1
# idx 190715 correct 21 to 22
# idx 190756 correct 2 to 1
# idx 190935 correct 14 to 17
# idx 191403 correct 28 to 30
# idx 191610 correct 21 to 29
# idx 191630 correct 0 to 8
# idx 191991 correct 9 to 7
# idx 192085 correct 3 to 11
# idx 192230 correct 31 to 35
# idx 192878 correct 1 to 4
# idx 193009 correct 2 to 12
# idx 193274 correct 13 to 16
# idx 193362 correct 0 to 1
# idx 193460 correct 1 to 0
# idx 193495 correct 8 to 2
# idx 193498 correct 3 to 2
# idx 193509 correct 27 to 30
# idx 193657 correct 29 to 28
# idx 193781 correct 35 to 38
# idx 193788 correct 21 to 36
# idx 193821 correct 14 to 9
# idx 194539 correct 18 to 19
# idx 194563 correct 4 to 7
# idx 194570 correct 18 to 38
# idx 194584 correct 23 to 38
# idx 194978 correct 2 to 3
# idx 195318 correct 1 to 17
# idx 195388 correct 1 to 4
# idx 195391 correct 23 to 31
# idx 195396 correct 2 to 1
# idx 195423 correct 25 to 38
# idx 195468 correct 7 to 17
# idx 195557 correct 36 to 33
# idx 195607 correct 2 to 3
# idx 195665 correct 8 to 0
# idx 196003 correct 14 to 17
# idx 196136 correct 3 to 17
# idx 196174 correct 13 to 7
# idx 196292 correct 19 to 18
# idx 196365 correct 17 to 14
# idx 196466 correct 18 to 19
# idx 196700 correct 28 to 29
# idx 196784 correct 1 to 17
# idx 196786 correct 1 to 17
# idx 196825 correct 1 to 17
# idx 197095 correct 19 to 18
# idx 197190 correct 19 to 1
# idx 197228 correct 23 to 38
# idx 197769 correct 2 to 3
# idx 197771 correct 2 to 3
# idx 197954 correct 2 to 3
# idx 198156 correct 36 to 35
# idx 198231 correct 19 to 1
# idx 198255 correct 4 to 1
# idx 198303 correct 9 to 3
# idx 198312 correct 2 to 12
# idx 198994 correct 1 to 2
# idx 199004 correct 18 to 38
# idx 199062 correct 7 to 10
# idx 199134 correct 22 to 29
# idx 199410 correct 15 to 38
# idx 199869 correct 29 to 38
# idx 199887 correct 38 to 19
# idx 200274 correct 9 to 3
# idx 200475 correct 35 to 31
# idx 200930 correct 30 to 38
# idx 200935 correct 2 to 1
# idx 201048 correct 3 to 2
# idx 201305 correct 1 to 0
# idx 201401 correct 3 to 7
# idx 201447 correct 31 to 35
# idx 201572 correct 29 to 35
# idx 201588 correct 32 to 38
# idx 201662 correct 12 to 7
# idx 201758 correct 13 to 12
# idx 202004 correct 18 to 19
# idx 202484 correct 1 to 38
# idx 202822 correct 35 to 31
# idx 202873 correct 35 to 31
# idx 202898 correct 3 to 2
# idx 203011 correct 38 to 32
# idx 203158 correct 4 to 12
# idx 203241 correct 1 to 8
# idx 203355 correct 36 to 35
# idx 203375 correct 2 to 3
# idx 203524 correct 22 to 36
# idx 203628 correct 11 to 12
# idx 203695 correct 18 to 19
# idx 203757 correct 2 to 8
# idx 203853 correct 0 to 15
# idx 203964 correct 2 to 4
# idx 203977 correct 21 to 29
# idx 204053 correct 35 to 29
# idx 204198 correct 35 to 33
# idx 204216 correct 7 to 9
# idx 204218 correct 7 to 9
# idx 204248 correct 17 to 7
# idx 204321 correct 1 to 8
# idx 204901 correct 0 to 5
# idx 205164 correct 38 to 10
# idx 205302 correct 23 to 38
# idx 205312 correct 38 to 33
# idx 205352 correct 3 to 2
# idx 205367 correct 37 to 28
# idx 205727 correct 2 to 1
# idx 205832 correct 8 to 1
# idx 205847 correct 29 to 30
# idx 205916 correct 9 to 8
# idx 205930 correct 4 to 13
# idx 206189 correct 33 to 38
# idx 206257 correct 12 to 11
# idx 206312 correct 38 to 13
# idx 206320 correct 31 to 35
# idx 206347 correct 7 to 11
# idx 206455 correct 29 to 36
# idx 206488 correct 8 to 0
# idx 206631 correct 22 to 30
# idx 206729 correct 28 to 33
# idx 206922 correct 1 to 17
# idx 206997 correct 35 to 21
# idx 207204 correct 1 to 0
# idx 207697 correct 5 to 1
# idx 207910 correct 4 to 1
# idx 208015 correct 1 to 9
# idx 208026 correct 31 to 35
# idx 208465 correct 3 to 11
# idx 208477 correct 11 to 7
# idx 208521 correct 2 to 3
# idx 208732 correct 7 to 13
# idx 208747 correct 38 to 35
# idx 208788 correct 2 to 4
# idx 209053 correct 14 to 17
# idx 209307 correct 25 to 38
# idx 209452 correct 4 to 3
# idx 209493 correct 1 to 2
# idx 209759 correct 37 to 38
# idx 209955 correct 36 to 35
# idx 210076 correct 14 to 9
# idx 210427 correct 3 to 13
# idx 210791 correct 1 to 0
# idx 210854 correct 7 to 13
# idx 211032 correct 33 to 38
# idx 211156 correct 8 to 2
# idx 211159 correct 3 to 2
# idx 211162 correct 3 to 2
# idx 211168 correct 26 to 38
# idx 211299 correct 2 to 9
# idx 211329 correct 35 to 36
# idx 211380 correct 38 to 33
# idx 211453 correct 37 to 15
# idx 211599 correct 2 to 3
# idx 211611 correct 38 to 36
# idx 211642 correct 7 to 9
# idx 211793 correct 7 to 9
# idx 211795 correct 7 to 9
# idx 211840 correct 7 to 17
# idx 211984 correct 11 to 4
# idx 212205 correct 27 to 30
# idx 212579 correct 1 to 2
# idx 212583 correct 4 to 2
# idx 212646 correct 23 to 38
# idx 212838 correct 35 to 29
# idx 213065 correct 4 to 2
# idx 213154 correct 2 to 8
# idx 213194 correct 35 to 31
# idx 213844 correct 8 to 0
# idx 213933 correct 31 to 35
# idx 213948 correct 21 to 30
# idx 214178 correct 2 to 4
# idx 214424 correct 1 to 17
# idx 214511 correct 3 to 2
# idx 215049 correct 31 to 35
# idx 215138 correct 9 to 7
# idx 215140 correct 9 to 7
# idx 215157 correct 27 to 38
# idx 215242 correct 2 to 1
# idx 215444 correct 38 to 19
# idx 216278 correct 3 to 29
# idx 216354 correct 26 to 19
# idx 216738 correct 13 to 7
# idx 216860 correct 26 to 1
# idx 216952 correct 5 to 1
# idx 217059 correct 21 to 29
# idx 217150 correct 38 to 35
# idx 217237 correct 38 to 13
# idx 217434 correct 19 to 18
# idx 217599 correct 8 to 0
# idx 217706 correct 27 to 30
# idx 217766 correct 21 to 36
# idx 218261 correct 10 to 12
# idx 218594 correct 2 to 8
# idx 218783 correct 22 to 21
# idx 218924 correct 2 to 4
# idx 219010 correct 9 to 3
# idx 219134 correct 12 to 4
# idx 219181 correct 38 to 37
# idx 219772 correct 7 to 9
# idx 220053 correct 4 to 1
# idx 220124 correct 0 to 8
# idx 220336 correct 12 to 4
# idx 220338 correct 12 to 4
# idx 220524 correct 14 to 17
# idx 220728 correct 13 to 4
# idx 220813 correct 33 to 38
# idx 221041 correct 2 to 1
# idx 221145 correct 13 to 16
# idx 221489 correct 31 to 35
# idx 221728 correct 8 to 0
# idx 221818 correct 5 to 1
# idx 221837 correct 14 to 7
# idx 221949 correct 10 to 13
# idx 222098 correct 8 to 3
# idx 222189 correct 38 to 19
# idx 222228 correct 25 to 38
# idx 222241 correct 26 to 0
# idx 222485 correct 29 to 30
# idx 222583 correct 13 to 4
# idx 222731 correct 14 to 32
# idx 222981 correct 7 to 17
# idx 223043 correct 1 to 5
# idx 223306 correct 19 to 1
# idx 223323 correct 31 to 35
# idx 223518 correct 2 to 8
# idx 223574 correct 38 to 33
# idx 223688 correct 38 to 33
# idx 223743 correct 36 to 35
# idx 223747 correct 36 to 35
# idx 223770 correct 3 to 8
# idx 223772 correct 3 to 8
# idx 223812 correct 37 to 38
# idx 224056 correct 5 to 1
# idx 224080 correct 17 to 1
# idx 224438 correct 31 to 35
# idx 224851 correct 38 to 19
# idx 224893 correct 19 to 1
# idx 225060 correct 28 to 38
# idx 226106 correct 35 to 36
# idx 226194 correct 30 to 38
# idx 226212 correct 6 to 1
# idx 226362 correct 2 to 3
# idx 226386 correct 5 to 1
# idx 226853 correct 16 to 13
# idx 226941 correct 9 to 7
# idx 226987 correct 22 to 29
# idx 227258 correct 21 to 29
# idx 227292 correct 28 to 38
# idx 227373 correct 18 to 38
# idx 227433 correct 33 to 38
# idx 227591 correct 38 to 23
# idx 227869 correct 19 to 38
# idx 227871 correct 19 to 38
# idx 228174 correct 12 to 10
# idx 228522 correct 7 to 14
# idx 228524 correct 10 to 14
# idx 228538 correct 8 to 1
# idx 228640 correct 32 to 38
# idx 228664 correct 4 to 7
# idx 228823 correct 25 to 8
# idx 229023 correct 14 to 17
# idx 229190 correct 14 to 17
# idx 229480 correct 11 to 13
# idx 229572 correct 38 to 9
# idx 229694 correct 15 to 0
# idx 229792 correct 16 to 38
# idx 229910 correct 5 to 1
# idx 229954 correct 10 to 8
# idx 230182 correct 2 to 3
# idx 230185 correct 11 to 3
# idx 230253 correct 1 to 4
# idx 230265 correct 1 to 2
# idx 230406 correct 25 to 22
# idx 231031 correct 19 to 20
# idx 231081 correct 35 to 31
# idx 231226 correct 33 to 38
# idx 231239 correct 4 to 8
# idx 231241 correct 9 to 8
# idx 231359 correct 0 to 1
# idx 231428 correct 33 to 38
# idx 231544 correct 1 to 5
# idx 231827 correct 38 to 30
# idx 231902 correct 9 to 8
# idx 232030 correct 33 to 34
# idx 232055 correct 1 to 4
# idx 232080 correct 9 to 7
# idx 232284 correct 9 to 10
# idx 232432 correct 7 to 12
# idx 232593 correct 38 to 17
# idx 232610 correct 11 to 7
# idx 232614 correct 7 to 11
# idx 232637 correct 8 to 9
# idx 232650 correct 11 to 7
# idx 232707 correct 2 to 3
# idx 232821 correct 17 to 2
# idx 232969 correct 35 to 36
# idx 233165 correct 31 to 38
# idx 233295 correct 10 to 13
# idx 233297 correct 10 to 13
# idx 233329 correct 33 to 38
# idx 233479 correct 19 to 20
# idx 233761 correct 7 to 12
# idx 233854 correct 4 to 3
# idx 233916 correct 35 to 31
# idx 234211 correct 13 to 16
# idx 234417 correct 14 to 10
# idx 234516 correct 26 to 19
# idx 234679 correct 16 to 13
# idx 234744 correct 13 to 12
# idx 234794 correct 19 to 38
# idx 234913 correct 4 to 1
# idx 235270 correct 17 to 2
# idx 235327 correct 14 to 17
# idx 235331 correct 0 to 1
# idx 235488 correct 29 to 22
# idx 235552 correct 19 to 20
# idx 235602 correct 4 to 1
# idx 236648 correct 8 to 5
# idx 236823 correct 36 to 35
# idx 236870 correct 4 to 9
# idx 237045 correct 13 to 5
# idx 237223 correct 4 to 2
# idx 237367 correct 9 to 7
# idx 237745 correct 6 to 4
# idx 237823 correct 34 to 33
# idx 237950 correct 4 to 12
# idx 238056 correct 38 to 33
# idx 238145 correct 12 to 14
# idx 238341 correct 14 to 17
# idx 238390 correct 2 to 1
# idx 238394 correct 2 to 1
# idx 238615 correct 0 to 38
# idx 238626 correct 35 to 31
# idx 238629 correct 35 to 31
# idx 239395 correct 38 to 4
# idx 239518 correct 7 to 10
# idx 239541 correct 17 to 1
# idx 239747 correct 7 to 12
# idx 240056 correct 0 to 1
# idx 240075 correct 28 to 38
# idx 240087 correct 28 to 38
# idx 240245 correct 27 to 38
# idx 240436 correct 8 to 3
# idx 240654 correct 2 to 3
# idx 240738 correct 7 to 11
# idx 240847 correct 1 to 19
# idx 240964 correct 21 to 22
# idx 241075 correct 6 to 1
# idx 241300 correct 33 to 38
# idx 241614 correct 1 to 2
# idx 242533 correct 31 to 35
# idx 243030 correct 31 to 38
# idx 243042 correct 38 to 35
# idx 243125 correct 25 to 38
# idx 243402 correct 7 to 4
# idx 243688 correct 19 to 18
# idx 243759 correct 31 to 35
# idx 244890 correct 34 to 33
# idx 245076 correct 31 to 35
# idx 245127 correct 8 to 3
# idx 245171 correct 12 to 7
# idx 245343 correct 18 to 19
# idx 245353 correct 33 to 38
# idx 245485 correct 34 to 35
# idx 245588 correct 38 to 33
# idx 245822 correct 0 to 1
# idx 245954 correct 36 to 35
# idx 246673 correct 8 to 3
# idx 247250 correct 30 to 38
# idx 247358 correct 17 to 38
# idx 247518 correct 1 to 0
# idx 247679 correct 29 to 30
# idx 247687 correct 4 to 7
# idx 247695 correct 35 to 33
# idx 247914 correct 13 to 38
# idx 247974 correct 30 to 29
# idx 248050 correct 12 to 1
# idx 248061 correct 1 to 4
# idx 248283 correct 19 to 38
# idx 248452 correct 14 to 17
# idx 248508 correct 12 to 13
# idx 248690 correct 1 to 2
# idx 248814 correct 32 to 14
# idx 248940 correct 31 to 35
# idx 248966 correct 33 to 38
# idx 248995 correct 5 to 0
# idx 249033 correct 38 to 32
# idx 249124 correct 2 to 8
# idx 249131 correct 17 to 3
# idx 249406 correct 4 to 7
# idx 249449 correct 35 to 31
# idx 249451 correct 35 to 31
# idx 249495 correct 32 to 38
# idx 249683 correct 0 to 5
# idx 249685 correct 0 to 5
# idx 249728 correct 20 to 19
# idx 250117 correct 30 to 38
# idx 250152 correct 0 to 1
# idx 250240 correct 29 to 30
# idx 250398 correct 3 to 2
# idx 250507 correct 5 to 16
# idx 250865 correct 8 to 2
# idx 251034 correct 1 to 2
# idx 251375 correct 28 to 38
# idx 251447 correct 14 to 0
# idx 251533 correct 19 to 18
# idx 251543 correct 34 to 35
# idx 251587 correct 35 to 33
# idx 251618 correct 19 to 38
# idx 251777 correct 7 to 9
# idx 251921 correct 36 to 35
# idx 252043 correct 38 to 33
# idx 252269 correct 2 to 17
# idx 253034 correct 31 to 35
# idx 253228 correct 35 to 31
# idx 253280 correct 1 to 0
# idx 253315 correct 0 to 15
# idx 253326 correct 4 to 1
# idx 253589 correct 34 to 33
# idx 253616 correct 31 to 35
# idx 253993 correct 28 to 38
# idx 254025 correct 31 to 35
# idx 254101 correct 7 to 16
# idx 254411 correct 16 to 7
# idx 254650 correct 33 to 38
# idx 254656 correct 28 to 33
# idx 254687 correct 5 to 1
# idx 254749 correct 4 to 2
# idx 254931 correct 4 to 2
# idx 255001 correct 22 to 21
# idx 255533 correct 4 to 1
# idx 255857 correct 17 to 4
# idx 256054 correct 3 to 11
# idx 256204 correct 14 to 7
# idx 256307 correct 17 to 2
# idx 256309 correct 3 to 2
# idx 256506 correct 38 to 33
# idx 256724 correct 38 to 33
# idx 256832 correct 2 to 1
# idx 256878 correct 0 to 8
# idx 256920 correct 12 to 4
# idx 257062 correct 8 to 2
# idx 257419 correct 14 to 16
# idx 257439 correct 18 to 13
# idx 257514 correct 32 to 38
# idx 257554 correct 13 to 7
# idx 257559 correct 4 to 7
# idx 257568 correct 7 to 13
# idx 257675 correct 33 to 29
# idx 257739 correct 30 to 29
# idx 257801 correct 22 to 21
# idx 258071 correct 0 to 1
# idx 258093 correct 19 to 38
# idx 258128 correct 37 to 38
# idx 258616 correct 19 to 38
# idx 259399 correct 9 to 11
# idx 259433 correct 19 to 18
# idx 259517 correct 2 to 1
# idx 259553 correct 18 to 19
# idx 259576 correct 38 to 35
# idx 259642 correct 20 to 18
# idx 259687 correct 28 to 37
# idx 259740 correct 31 to 35
# idx 260045 correct 14 to 17
# idx 260113 correct 4 to 10
# idx 260261 correct 18 to 19
# idx 260316 correct 35 to 31
# idx 260364 correct 4 to 1
# idx 260413 correct 2 to 4
# idx 260630 correct 13 to 12
# idx 261013 correct 18 to 4
# idx 261953 correct 38 to 19
# idx 261988 correct 8 to 3
# idx 262032 correct 29 to 35
# idx 262134 correct 11 to 7
# idx 262151 correct 38 to 35
# idx 262186 correct 3 to 8
# idx 262481 correct 4 to 7
# idx 262532 correct 32 to 33
# idx 262587 correct 2 to 3
# idx 262618 correct 35 to 31
# idx 262642 correct 31 to 35
# idx 262687 correct 2 to 1
# idx 262701 correct 32 to 33
# idx 262810 correct 1 to 2
# idx 262836 correct 4 to 13
# idx 263037 correct 3 to 9
# idx 263092 correct 20 to 19
# idx 263169 correct 2 to 1
# idx 263192 correct 33 to 38
# idx 263271 correct 4 to 7
# idx 263311 correct 7 to 9
# idx 263473 correct 31 to 35
# idx 263679 correct 1 to 4
# idx 263731 correct 2 to 1
# idx 264185 correct 1 to 2
# idx 264308 correct 4 to 3
# idx 264547 correct 5 to 13
# idx 264666 correct 23 to 37
# idx 264925 correct 7 to 3
# idx 264928 correct 11 to 3
# idx 264984 correct 11 to 12
# idx 265011 correct 1 to 4
# idx 265192 correct 3 to 11
# idx 265215 correct 2 to 1
# idx 265218 correct 2 to 1
# idx 265220 correct 19 to 1
# idx 265332 correct 11 to 3
# idx 265408 correct 18 to 19
# idx 265412 correct 33 to 38
# idx 265418 correct 33 to 28
# idx 265646 correct 12 to 4
# idx 266009 correct 17 to 1
# idx 266035 correct 7 to 4
# idx 266305 correct 1 to 8
# idx 266890 correct 9 to 7
# idx 266993 correct 1 to 0
# idx 267285 correct 29 to 38
# idx 267350 correct 35 to 31
# idx 267787 correct 17 to 1
# idx 267849 correct 26 to 23
# idx 267979 correct 13 to 7
# idx 267998 correct 38 to 23
# idx 268016 correct 8 to 3
# idx 268063 correct 7 to 16
# idx 268080 correct 11 to 7
# idx 268196 correct 11 to 3
# idx 268397 correct 31 to 35
# idx 268624 correct 18 to 19
# idx 268678 correct 8 to 0
# idx 268774 correct 37 to 3
# idx 268786 correct 7 to 11
# idx 268841 correct 19 to 18
# idx 268857 correct 3 to 2
# idx 269191 correct 7 to 9
# idx 269289 correct 7 to 11
# idx 269618 correct 1 to 0
# idx 269635 correct 9 to 7
# idx 269725 correct 8 to 1
# idx 269727 correct 8 to 1
# idx 269788 correct 33 to 35
# idx 269846 correct 31 to 35
# idx 269862 correct 2 to 17
# idx 269904 correct 21 to 22
# idx 269956 correct 26 to 38
# idx 270106 correct 21 to 29
# idx 270187 correct 1 to 38
# idx 270215 correct 1 to 4
# idx 270295 correct 29 to 21
# idx 270393 correct 7 to 9
# idx 270548 correct 2 to 12
# idx 270606 correct 4 to 2
# idx 270610 correct 4 to 2
# idx 270647 correct 11 to 2
# idx 270730 correct 3 to 2
# idx 270805 correct 32 to 38
# idx 271046 correct 4 to 12
# idx 271115 correct 7 to 9
# idx 271227 correct 18 to 19
# idx 271370 correct 11 to 3
# idx 271416 correct 9 to 7
# idx 271438 correct 3 to 4
# idx 271541 correct 19 to 13
# idx 271583 correct 7 to 17
# idx 271876 correct 1 to 0
# idx 272686 correct 1 to 8
# idx 273136 correct 5 to 1
# idx 273424 correct 1 to 0
# idx 273900 correct 33 to 38
# idx 273931 correct 36 to 21
# idx 274127 correct 14 to 17
# idx 274160 correct 1 to 4
# idx 274194 correct 3 to 11
# idx 274224 correct 30 to 28
# idx 274402 correct 38 to 37
# idx 274992 correct 15 to 0
# idx 275028 correct 14 to 7
# idx 275107 correct 20 to 19
# idx 275166 correct 17 to 2
# idx 275997 correct 11 to 12
# idx 276030 correct 1 to 0
# idx 276091 correct 38 to 34
# idx 276171 correct 3 to 9
# idx 276277 correct 18 to 13
# idx 276320 correct 38 to 34
# idx 276386 correct 31 to 35
# idx 276419 correct 34 to 38
# idx 276618 correct 36 to 35
# idx 276630 correct 2 to 8
# idx 276640 correct 0 to 1
# idx 276772 correct 19 to 18
# idx 276849 correct 20 to 19
# idx 276870 correct 11 to 3
# idx 276993 correct 4 to 12
# idx 277379 correct 11 to 12
# idx 277848 correct 13 to 19
# idx 278285 correct 29 to 35
# idx 278322 correct 11 to 9
# idx 278344 correct 23 to 34
# idx 278693 correct 15 to 0
# idx 278912 correct 11 to 4
# idx 278918 correct 11 to 7
# idx 278956 correct 28 to 37
# idx 279059 correct 2 to 3
# idx 279096 correct 28 to 29
# idx 279146 correct 17 to 1
# idx 279589 correct 3 to 2
# idx 279779 correct 1 to 5
# idx 280314 correct 26 to 19
# idx 280413 correct 2 to 4
# idx 280479 correct 9 to 4
# idx 280772 correct 7 to 9
# idx 280862 correct 4 to 12
# idx 281167 correct 33 to 35
# idx 281182 correct 1 to 2
# idx 281523 correct 32 to 38
# idx 281565 correct 9 to 7
# idx 281626 correct 2 to 4
# idx 281630 correct 2 to 4
# idx 281671 correct 4 to 3
# idx 281854 correct 4 to 2
# idx 281904 correct 12 to 14
# idx 281974 correct 35 to 29
# idx 282102 correct 1 to 2
# idx 282111 correct 9 to 7
# idx 282115 correct 9 to 7
# idx 282139 correct 38 to 32
# idx 282216 correct 0 to 8
# idx 282263 correct 2 to 3
# idx 282306 correct 17 to 38
# idx 283606 correct 7 to 9
# idx 283690 correct 4 to 2
# idx 283746 correct 34 to 29
# idx 283792 correct 1 to 17
# idx 283831 correct 1 to 0
# idx 283869 correct 30 to 38
# idx 283902 correct 31 to 35
# idx 283917 correct 3 to 8
# idx 284009 correct 33 to 38
# idx 284249 correct 5 to 0
# idx 284298 correct 38 to 18
# idx 284422 correct 8 to 1
# idx 284424 correct 2 to 1
# idx 284529 correct 1 to 4
# idx 284677 correct 10 to 7
# idx 284877 correct 29 to 38
# idx 285107 correct 11 to 3
# idx 285112 correct 3 to 9
# idx 285126 correct 18 to 19
# idx 285149 correct 12 to 17
# idx 285207 correct 7 to 12
# idx 285313 correct 31 to 35
# idx 285443 correct 31 to 35
# idx 285724 correct 1 to 15
# idx 285855 correct 5 to 1
# idx 286428 correct 35 to 33
# idx 286515 correct 14 to 7
# idx 286572 correct 35 to 33
# idx 286781 correct 32 to 13
# idx 286897 correct 35 to 36
# idx 286948 correct 38 to 19
# idx 287059 correct 36 to 35
# idx 287078 correct 0 to 1
# idx 287091 correct 0 to 5
# idx 287192 correct 26 to 13
# idx 287260 correct 5 to 1
# idx 287511 correct 1 to 0
# idx 287647 correct 2 to 3
# idx 287721 correct 3 to 9
# idx 287795 correct 9 to 7
# idx 287967 correct 1 to 17
# idx 288165 correct 28 to 38
# idx 288604 correct 4 to 7
# idx 288620 correct 18 to 38
# idx 288628 correct 4 to 1
# idx 288816 correct 12 to 13
# idx 289198 correct 4 to 7
# idx 289820 correct 9 to 7
# idx 289984 correct 14 to 17
# idx 290231 correct 29 to 35
# idx 290379 correct 17 to 2
# idx 290385 correct 17 to 14
# idx 290490 correct 4 to 7
# idx 290492 correct 4 to 7
# idx 290495 correct 4 to 7
# idx 290605 correct 33 to 38
# idx 290896 correct 3 to 11
# idx 290984 correct 14 to 17
# idx 291183 correct 3 to 2
# idx 291490 correct 35 to 30
# idx 292307 correct 0 to 1
# idx 292617 correct 7 to 3
# idx 292927 correct 16 to 38
# idx 293122 correct 32 to 5
# idx 293175 correct 2 to 3
# idx 293177 correct 1 to 3
# idx 293270 correct 12 to 4
# idx 293294 correct 17 to 1
# idx 293642 correct 4 to 7
# idx 294089 correct 36 to 35
# idx 294145 correct 1 to 4
# idx 294204 correct 23 to 29
# idx 294943 correct 1 to 0
# idx 295400 correct 31 to 35
# idx 295460 correct 12 to 7
# idx 295516 correct 37 to 30
# idx 295534 correct 4 to 13
# idx 295636 correct 0 to 1
# idx 295784 correct 36 to 35
# idx 295795 correct 0 to 5
# idx 295829 correct 1 to 17
# idx 295895 correct 1 to 2
# idx 296205 correct 1 to 19
# idx 296239 correct 15 to 1
# idx 296296 correct 17 to 14
# idx 296470 correct 2 to 11
# idx 296472 correct 4 to 11
# idx 296478 correct 23 to 4
# idx 296483 correct 3 to 4
# idx 296596 correct 19 to 13
# idx 296622 correct 33 to 38
# idx 297483 correct 10 to 13
# idx 297613 correct 13 to 9
# idx 297699 correct 28 to 38
# idx 297848 correct 1 to 4
# idx 297856 correct 19 to 12
# idx 298133 correct 4 to 9
# idx 298185 correct 1 to 19
# idx 298283 correct 5 to 0
# idx 298325 correct 3 to 2
# idx 298327 correct 3 to 2
# idx 298472 correct 2 to 3
# idx 298474 correct 2 to 3
# idx 298681 correct 12 to 13
# idx 298702 correct 21 to 36
# idx 299573 correct 19 to 13
# idx 300141 correct 13 to 16
# idx 300418 correct 11 to 9
# idx 300741 correct 19 to 23
# ...
# idx 360049 correct 38 to 33
# idx 360496 correct 2 to 4
# idx 360555 correct 25 to 32
# idx 360664 correct 0 to 1
# idx 360996 correct 28 to 33
# idx 361059 correct 21 to 22
# idx 361144 correct 7 to 2
# idx 361452 correct 17 to 1
# idx 361532 correct 2 to 3
# idx 361908 correct 31 to 35
# idx 362338 correct 26 to 38
# idx 362702 correct 6 to 1
# idx 362860 correct 5 to 0
# idx 362914 correct 11 to 7
# idx 362938 correct 31 to 35
# idx 362981 correct 23 to 38
# idx 363048 correct 31 to 35
# idx 363227 correct 3 to 7
# idx 363436 correct 29 to 30
# idx 363881 correct 2 to 3
# idx 363887 correct 2 to 3
# idx 363947 correct 17 to 1
# idx 363972 correct 31 to 35
# idx 364137 correct 4 to 1
# idx 364220 correct 23 to 38
# idx 364248 correct 4 to 1
# idx 364345 correct 4 to 12
# idx 364347 correct 4 to 12
# idx 365215 correct 34 to 25
# idx 365526 correct 11 to 4
# idx 365543 correct 9 to 4
# idx 365545 correct 7 to 4
# idx 365580 correct 1 to 4
# idx 365650 correct 5 to 1
# idx 365723 correct 17 to 2
# idx 365927 correct 19 to 18
# idx 365934 correct 29 to 31
# idx 366145 correct 15 to 0
# idx 366215 correct 16 to 10
# idx 366449 correct 32 to 38
# idx 366581 correct 19 to 38
# idx 366677 correct 32 to 18
# idx 366736 correct 0 to 8
# idx 366756 correct 20 to 19
# idx 366973 correct 4 to 2
# idx 366977 correct 3 to 2
# idx 367157 correct 8 to 5
# idx 367791 correct 8 to 10
# idx 367940 correct 4 to 12
# idx 368102 correct 35 to 31
# idx 368135 correct 25 to 38
# idx 368305 correct 6 to 1
# idx 368417 correct 1 to 17
# idx 368422 correct 35 to 33
# idx 368512 correct 21 to 22
# idx 368544 correct 34 to 33
# idx 368658 correct 19 to 20
# idx 368756 correct 3 to 2
# idx 368836 correct 0 to 1
# idx 369178 correct 0 to 1
# idx 369406 correct 32 to 1
# idx 369411 correct 33 to 35
# idx 369499 correct 0 to 15
# idx 369773 correct 5 to 1
# idx 369847 correct 35 to 31
# idx 369875 correct 17 to 14
# idx 369906 correct 15 to 1
# idx 369915 correct 13 to 16
# idx 370068 correct 4 to 1
# idx 370140 correct 3 to 8
# idx 370231 correct 32 to 38
# idx 370404 correct 0 to 5
# idx 370406 correct 0 to 5
# idx 370782 correct 38 to 23
# idx 370809 correct 3 to 2
# idx 371103 correct 32 to 38
# idx 371305 correct 35 to 31
# idx 371370 correct 0 to 1
# idx 371501 correct 14 to 17
# idx 371603 correct 9 to 8
# idx 371638 correct 21 to 36
# idx 371729 correct 2 to 9
# idx 372298 correct 3 to 4
# idx 372441 correct 3 to 9
# idx 372512 correct 23 to 32
# idx 372556 correct 38 to 32
# idx 372839 correct 5 to 18
# idx 373068 correct 20 to 19
# idx 373489 correct 9 to 7
# idx 373748 correct 17 to 4
# idx 373857 correct 19 to 1
# idx 374536 correct 21 to 29
# idx 374634 correct 1 to 8
# idx 374703 correct 4 to 1
# idx 374779 correct 3 to 9
# idx 375321 correct 34 to 38
# idx 375335 correct 25 to 38
# idx 375337 correct 2 to 38
# idx 375403 correct 2 to 3
# idx 375476 correct 8 to 1
# idx 376228 correct 16 to 13
# idx 376300 correct 13 to 16
# idx 376476 correct 38 to 32
# idx 376665 correct 1 to 4
# idx 376670 correct 19 to 18
# idx 376845 correct 37 to 38
# idx 377058 correct 1 to 17
# idx 377071 correct 38 to 4
# idx 377082 correct 23 to 38
# idx 377193 correct 9 to 7
# idx 377367 correct 14 to 17
# idx 377749 correct 1 to 2
# idx 377947 correct 2 to 3
# idx 378248 correct 21 to 29
# idx 378515 correct 38 to 18
# idx 378604 correct 29 to 21
# idx 379334 correct 31 to 19
# idx 379445 correct 0 to 1
# idx 379809 correct 7 to 9
# idx 379864 correct 20 to 19
# idx 379866 correct 20 to 19
# idx 380060 correct 0 to 15
# idx 380171 correct 1 to 17
# idx 380517 correct 18 to 32
# idx 380577 correct 12 to 4
# idx 380782 correct 29 to 21
# idx 380828 correct 36 to 21
# idx 380994 correct 19 to 20
# idx 381009 correct 0 to 8
# idx 381169 correct 31 to 33
# idx 381420 correct 18 to 19
# idx 381594 correct 35 to 31
# idx 381605 correct 8 to 1
# idx 382083 correct 8 to 3
# idx 382123 correct 33 to 34
# idx 382138 correct 19 to 3
# idx 382180 correct 7 to 9
# idx 382225 correct 3 to 2
# idx 382311 correct 4 to 1
# idx 382332 correct 38 to 35
# idx 382385 correct 31 to 35
# idx 382428 correct 10 to 14
# idx 382444 correct 8 to 1
# idx 382556 correct 21 to 36
# idx 383056 correct 8 to 2
# idx 383117 correct 13 to 7
# idx 383119 correct 13 to 7
# idx 383137 correct 31 to 35
# idx 383187 correct 13 to 12
# idx 383191 correct 13 to 12
# idx 383307 correct 3 to 2
# idx 383368 correct 33 to 34
# idx 383399 correct 1 to 8
# idx 383647 correct 10 to 7
# idx 384068 correct 9 to 7
# idx 384097 correct 1 to 0
# idx 384203 correct 4 to 1
# idx 384908 correct 13 to 16
# idx 385226 correct 1 to 4
# idx 385239 correct 2 to 3
# idx 385340 correct 35 to 31
# idx 385616 correct 3 to 11
# idx 385721 correct 32 to 38
# idx 385776 correct 14 to 17
# idx 386022 correct 35 to 31
# idx 386043 correct 19 to 20
# idx 386057 correct 35 to 33
# idx 386092 correct 31 to 38
# idx 386692 correct 17 to 2
# idx 387636 correct 35 to 31
# idx 387705 correct 35 to 36
# idx 387842 correct 1 to 6
# idx 387847 correct 19 to 26
# idx 387981 correct 31 to 35
# idx 388476 correct 13 to 12
# idx 388557 correct 35 to 31
# idx 388656 correct 36 to 35
# idx 388704 correct 10 to 7
# idx 388714 correct 9 to 10
# idx 388832 correct 12 to 4
# idx 389017 correct 19 to 18
# idx 389130 correct 13 to 12
# idx 389298 correct 30 to 29
# idx 389964 correct 37 to 30
# idx 390455 correct 4 to 2
# idx 390593 correct 37 to 38
# idx 390960 correct 9 to 3
# idx 390971 correct 19 to 18
# idx 391432 correct 17 to 0
# idx 391807 correct 11 to 3
# idx 391861 correct 18 to 38
# idx 391951 correct 29 to 28
# idx 392042 correct 12 to 4
# idx 392384 correct 29 to 37
# idx 392533 correct 29 to 38
# idx 393032 correct 38 to 29
# idx 393431 correct 14 to 17
# idx 393449 correct 0 to 8
# idx 393575 correct 1 to 20
# idx 393796 correct 32 to 38
# idx 393820 correct 1 to 2
# idx 393988 correct 17 to 14
# idx 394093 correct 31 to 35
# idx 394248 correct 3 to 38
# idx 394453 correct 1 to 17
# idx 394494 correct 7 to 12
# idx 394687 correct 7 to 9
# idx 394770 correct 38 to 37
# idx 394796 correct 14 to 17
# idx 394845 correct 7 to 12
# idx 394869 correct 1 to 4
# idx 394888 correct 11 to 3
# idx 395016 correct 2 to 3
# idx 395113 correct 1 to 17
# idx 395408 correct 14 to 17
# idx 395465 correct 38 to 0
# idx 395755 correct 38 to 13
# idx 395867 correct 7 to 12
# idx 395942 correct 8 to 3
# idx 396033 correct 17 to 7
# idx 396143 correct 1 to 0
# idx 396200 correct 9 to 7
# idx 396322 correct 30 to 38
# idx 396747 correct 32 to 38
# idx 396946 correct 20 to 19
# idx 397001 correct 0 to 1
# idx 397373 correct 31 to 35
# idx 397553 correct 31 to 35
# idx 397833 correct 8 to 3
# idx 397842 correct 8 to 3
# idx 397950 correct 13 to 12
# idx 398087 correct 1 to 3
# idx 398097 correct 33 to 38
# idx 398142 correct 5 to 1
# idx 398148 correct 5 to 1
# idx 398178 correct 38 to 30
# idx 398423 correct 9 to 7
# idx 398447 correct 38 to 33
# idx 398476 correct 31 to 35
# idx 398750 correct 29 to 38
# idx 399374 correct 18 to 13
# idx 399661 correct 4 to 2
# idx 399914 correct 1 to 4
# idx 399985 correct 11 to 7
# idx 400014 correct 31 to 35
# idx 400245 correct 19 to 18
# idx 400268 correct 28 to 33
# idx 400342 correct 1 to 4
# idx 400413 correct 35 to 31
# idx 400432 correct 3 to 11
# idx 400457 correct 30 to 29
# idx 400586 correct 19 to 18
# idx 400689 correct 5 to 12
# idx 400740 correct 17 to 1
# idx 400774 correct 0 to 1
# idx 400886 correct 29 to 38
# idx 401176 correct 17 to 14
# idx 401574 correct 11 to 3
# idx 401667 correct 4 to 1
# idx 401934 correct 1 to 0
# idx 401953 correct 1 to 38
# idx 401966 correct 37 to 30
# idx 401981 correct 37 to 19
# idx 401990 correct 19 to 4
# idx 402130 correct 25 to 27
# idx 402198 correct 16 to 13
# idx 402408 correct 34 to 38
# idx 402411 correct 29 to 34
# idx 402495 correct 13 to 12
# idx 402859 correct 9 to 7
# idx 402941 correct 12 to 13
# idx 402946 correct 38 to 0
# idx 402951 correct 5 to 0
# idx 403041 correct 9 to 7
# idx 403110 correct 37 to 38
# idx 403546 correct 31 to 35
# idx 403597 correct 30 to 33
# idx 403699 correct 3 to 8
# idx 403722 correct 13 to 7
# idx 403779 correct 35 to 36
# idx 404008 correct 2 to 4
# idx 404075 correct 4 to 7
# idx 404131 correct 29 to 38
# idx 404135 correct 18 to 19
# idx 404169 correct 9 to 3
# idx 404418 correct 4 to 7
# idx 405067 correct 23 to 30
# idx 405180 correct 7 to 9
# idx 405239 correct 7 to 9
# idx 405243 correct 7 to 9
# idx 405483 correct 21 to 22
# idx 405672 correct 4 to 7
# idx 405690 correct 36 to 21
# idx 405870 correct 9 to 7
# idx 405939 correct 38 to 33
# idx 405962 correct 19 to 18
# idx 406216 correct 4 to 12
# idx 406223 correct 5 to 12
# idx 406361 correct 26 to 38
# idx 406657 correct 23 to 32
# idx 406659 correct 23 to 32
# idx 406775 correct 19 to 13
# idx 406918 correct 15 to 38
# idx 407279 correct 14 to 17
# idx 407287 correct 33 to 38
# idx 407575 correct 33 to 38
# idx 407578 correct 33 to 38
# idx 407638 correct 38 to 14
# idx 407844 correct 31 to 35
# idx 407847 correct 31 to 35
# idx 408247 correct 8 to 0
# idx 408356 correct 0 to 8
# idx 408420 correct 4 to 2
# idx 408525 correct 20 to 0
# idx 408978 correct 7 to 16
# idx 409053 correct 6 to 4
# idx 409223 correct 37 to 29
# idx 409303 correct 13 to 11
# idx 409422 correct 38 to 35
# idx 409598 correct 8 to 9
# idx 409837 correct 37 to 38
# idx 409947 correct 38 to 33
# idx 409999 correct 37 to 38
# idx 410025 correct 38 to 33
# idx 410667 correct 31 to 38
# idx 410888 correct 25 to 38
# idx 410975 correct 0 to 8
# idx 411108 correct 34 to 31
# idx 411186 correct 2 to 3
# idx 411338 correct 9 to 1
# idx 411661 correct 7 to 9
# idx 411794 correct 4 to 1
# idx 412044 correct 26 to 32
# idx 412303 correct 17 to 14
# idx 413247 correct 1 to 3
# idx 413305 correct 1 to 8
# idx 413368 correct 33 to 28
# idx 413376 correct 19 to 18
# idx 413502 correct 30 to 29
# idx 413731 correct 38 to 16
# idx 413752 correct 30 to 38
# idx 413771 correct 19 to 18
# idx 413796 correct 1 to 10
# idx 413805 correct 38 to 14
# idx 414231 correct 8 to 1
# idx 414288 correct 29 to 38
# idx 414431 correct 38 to 37
# idx 414500 correct 8 to 1
# idx 414692 correct 4 to 19
# idx 414808 correct 28 to 33
# idx 415907 correct 18 to 38
# idx 416036 correct 2 to 1
# idx 416136 correct 1 to 19
# idx 416168 correct 3 to 2
# idx 416191 correct 32 to 23
# idx 416330 correct 11 to 3
# idx 416363 correct 1 to 4
# idx 416416 correct 31 to 35
# idx 416418 correct 31 to 35
# idx 416635 correct 31 to 35
# idx 416707 correct 13 to 4
# idx 416762 correct 29 to 28
# idx 416847 correct 16 to 32
# idx 417012 correct 22 to 21
# idx 417212 correct 29 to 23
# idx 417375 correct 8 to 0
# idx 417400 correct 17 to 1
# idx 417618 correct 17 to 1
# idx 417672 correct 19 to 5
# idx 418079 correct 2 to 4
# idx 418197 correct 35 to 36
# idx 418330 correct 7 to 3
# idx 418646 correct 4 to 7
# idx 418736 correct 37 to 38
# idx 418818 correct 13 to 12
# idx 418884 correct 22 to 21
# idx 419155 correct 11 to 7
# idx 419190 correct 38 to 29
# idx 419224 correct 31 to 32
# idx 419244 correct 36 to 35
# idx 419390 correct 2 to 1
# idx 419439 correct 33 to 32
# idx 419705 correct 27 to 30
# idx 419721 correct 7 to 9
# idx 419971 correct 37 to 9
# idx 420218 correct 35 to 36
# idx 420266 correct 38 to 23
# idx 420302 correct 30 to 28
# idx 420323 correct 4 to 13
# idx 420533 correct 25 to 38
# idx 421033 correct 9 to 10
# idx 421056 correct 38 to 7
# idx 421278 correct 19 to 1
# idx 421307 correct 1 to 0
# idx 421508 correct 4 to 7
# idx 421631 correct 34 to 35
# idx 421674 correct 4 to 1
# idx 421693 correct 1 to 0
# idx 421820 correct 28 to 29
# idx 422049 correct 31 to 35
# idx 422193 correct 8 to 0
# idx 422297 correct 35 to 33
# idx 422729 correct 13 to 7
# idx 422736 correct 10 to 1
# idx 422952 correct 1 to 0
# idx 423550 correct 23 to 38
# idx 423647 correct 28 to 38
# idx 423690 correct 18 to 19
# idx 423719 correct 2 to 3
# idx 423723 correct 2 to 3
# idx 423997 correct 35 to 36
# idx 424173 correct 17 to 1
# idx 424353 correct 15 to 0
# idx 424396 correct 31 to 35
# idx 424398 correct 31 to 35
# idx 424515 correct 19 to 18
# idx 424596 correct 5 to 0
# idx 424613 correct 12 to 13
# idx 424638 correct 1 to 2
# idx 424769 correct 33 to 35
# idx 424775 correct 35 to 33
# idx 424832 correct 18 to 19
# idx 424834 correct 20 to 19
# idx 424979 correct 2 to 1
# idx 425080 correct 1 to 0
# idx 425261 correct 13 to 4
# idx 425288 correct 0 to 1
# idx 425309 correct 30 to 38
# idx 425531 correct 4 to 13
# idx 425623 correct 18 to 19
# idx 425643 correct 3 to 8
# idx 426215 correct 38 to 7
# idx 426478 correct 19 to 0
# idx 426504 correct 35 to 31
# idx 426509 correct 3 to 2
# idx 426537 correct 33 to 38
# idx 426572 correct 3 to 0
# idx 426588 correct 34 to 38
# idx 427344 correct 3 to 2
# idx 427346 correct 1 to 2
# idx 427417 correct 1 to 12
# idx 427697 correct 33 to 38
# idx 427912 correct 14 to 17
# idx 428036 correct 1 to 19
# idx 428310 correct 1 to 0
# idx 428538 correct 13 to 12
# idx 428590 correct 1 to 2
# idx 428595 correct 38 to 18
# idx 428680 correct 14 to 17
# idx 429155 correct 33 to 38
# idx 429263 correct 29 to 28
# idx 429347 correct 4 to 1
# idx 429518 correct 17 to 14
# idx 429702 correct 10 to 7
# idx 429714 correct 19 to 18
# idx 429725 correct 0 to 8
# idx 429746 correct 8 to 10
# idx 429773 correct 31 to 35
# idx 429795 correct 28 to 38
# idx 429846 correct 38 to 17
# idx 429917 correct 7 to 4
# idx 430106 correct 2 to 1
# idx 430890 correct 18 to 13
# idx 431092 correct 2 to 1
# idx 431251 correct 21 to 22
# idx 431255 correct 31 to 22
# idx 431263 correct 36 to 35
# idx 431346 correct 4 to 1
# idx 431675 correct 3 to 2
# idx 431705 correct 19 to 18
# idx 431800 correct 3 to 7
# idx 431813 correct 4 to 13
# idx 432199 correct 26 to 38
# idx 432241 correct 4 to 8
# idx 432247 correct 8 to 1
# idx 432452 correct 12 to 4
# idx 432500 correct 7 to 9
# idx 432597 correct 1 to 8
# idx 433381 correct 33 to 23
# idx 433385 correct 29 to 3
# idx 433521 correct 35 to 31
# idx 433525 correct 38 to 35
# idx 433552 correct 14 to 17
# idx 433765 correct 2 to 3
# idx 433778 correct 36 to 22
# idx 433847 correct 19 to 18
# idx 434109 correct 4 to 7
# idx 434158 correct 31 to 35
# idx 434408 correct 4 to 2
# idx 434486 correct 38 to 19
# idx 434990 correct 0 to 8
# idx 435084 correct 35 to 34
# idx 435324 correct 4 to 12
# idx 435381 correct 3 to 2
# idx 435389 correct 25 to 22
# idx 436286 correct 31 to 35
# idx 436386 correct 38 to 33
# idx 436584 correct 38 to 20
# idx 436770 correct 2 to 3
# idx 437058 correct 29 to 31
# idx 437420 correct 4 to 12
# idx 437513 correct 33 to 38
# idx 437743 correct 4 to 7
# idx 437931 correct 1 to 4
# idx 438751 correct 13 to 7
# idx 438772 correct 33 to 38
# idx 438878 correct 8 to 2
# idx 438947 correct 14 to 17
# idx 439392 correct 13 to 38
# idx 439485 correct 15 to 17
# idx 439524 correct 1 to 4
# idx 439823 correct 35 to 38
# idx 439980 correct 38 to 18
# idx 439993 correct 31 to 35
# idx 440024 correct 0 to 5
# idx 440117 correct 33 to 38
# idx 440737 correct 14 to 17
# idx 440851 correct 33 to 38
# idx 440853 correct 33 to 38
# idx 440856 correct 33 to 38
# idx 441175 correct 21 to 22
# idx 441189 correct 22 to 21
# idx 442398 correct 1 to 2
# idx 442446 correct 38 to 32
# idx 442490 correct 4 to 3
# idx 442564 correct 4 to 13
# idx 442733 correct 38 to 18
# idx 442754 correct 8 to 9
# idx 442787 correct 33 to 38
# idx 442849 correct 4 to 7
# idx 442944 correct 18 to 19
# idx 443091 correct 4 to 12
# idx 443473 correct 38 to 13
# idx 443578 correct 26 to 19
# idx 443619 correct 1 to 4
# idx 443811 correct 36 to 35
# idx 443831 correct 38 to 26
# idx 443844 correct 20 to 19
# idx 444870 correct 38 to 32
# idx 445046 correct 4 to 7
# idx 445135 correct 18 to 13
# idx 445143 correct 6 to 1
# idx 445170 correct 35 to 31
# idx 445279 correct 31 to 35
# idx 445699 correct 19 to 1
# idx 446095 correct 31 to 35
# idx 446105 correct 15 to 0
# idx 446126 correct 3 to 11
# idx 446271 correct 13 to 4
# idx 446311 correct 31 to 35
# idx 446342 correct 5 to 1
# idx 446415 correct 21 to 22
# idx 446505 correct 29 to 38
# idx 446814 correct 12 to 10
# idx 447095 correct 1 to 19
# idx 447255 correct 33 to 38
# idx 447911 correct 3 to 2
# idx 448310 correct 1 to 2
# idx 448373 correct 5 to 4
# idx 448579 correct 27 to 38
# idx 448659 correct 38 to 0
# idx 448766 correct 2 to 3
# idx 448948 correct 31 to 35
# idx 448950 correct 31 to 35
# idx 448989 correct 35 to 31
# idx 449540 correct 11 to 3
# idx 449564 correct 30 to 38
# idx 449694 correct 27 to 30
# idx 449750 correct 33 to 38
# idx 449790 correct 25 to 38
# idx 449814 correct 32 to 33
# idx 449816 correct 32 to 33
# idx 450073 correct 33 to 32
# idx 450212 correct 35 to 31
# idx 450271 correct 3 to 2
# idx 450348 correct 4 to 19
# idx 450390 correct 9 to 2
# idx 450502 correct 27 to 30
# idx 450616 correct 1 to 0
# idx 450644 correct 7 to 3
# idx 450648 correct 7 to 3
# idx 450790 correct 28 to 30
# idx 451107 correct 30 to 38
# idx 451222 correct 33 to 38
# idx 451397 correct 1 to 17
# idx 451500 correct 2 to 1
# total number of correction 2743, correction percent 0.01

# %%
with open('prediction_dnn2.csv', 'w') as f:
    f.write('Id,Class\n')
    for i, y in enumerate(predict):
        f.write('{},{}\n'.format(i, y))

# %% [markdown]
# # Reference
# The code is modified from TA's sample code
