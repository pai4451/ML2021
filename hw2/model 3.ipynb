# %% [markdown]
# # **Homework 2-1 Phoneme Classification**

# %% [markdown]
# ## The DARPA TIMIT Acoustic-Phonetic Continuous Speech Corpus (TIMIT)
# The TIMIT corpus of reading speech has been designed to provide speech data for the acquisition of acoustic-phonetic knowledge and for the development and evaluation of automatic speech recognition systems.
#
# This homework is a multiclass classification task,
# we are going to train a deep neural network classifier to predict the phonemes for each frame from the speech corpus TIMIT.
#
# link: https://academictorrents.com/details/34e2b78745138186976cbc27939b1b34d18bd5b3

# %% [markdown]
# ## Download Data
# Download data from google drive, then unzip it.
#
# You should have `timit_11/train_11.npy`, `timit_11/train_label_11.npy`, and `timit_11/test_11.npy` after running this block.<br><br>
# `timit_11/`
# - `train_11.npy`: training data<br>
# - `train_label_11.npy`: training label<br>
# - `test_11.npy`:  testing data<br><br>
#
# **notes: if the google drive link is dead, you can download the data directly from Kaggle and upload it to the workspace**

# %%
#!gdown --id '1HPkcmQmFGu-3OknddKIa5dNDsR05lIQR' --output data.zip
#!unzip data.zip
#!ls

# %% [markdown]
# ## Preparing Data
# Load the training and testing data from the `.npy` file (NumPy array).

# %%
import numpy as np

print('Loading data ...')

data_root='./timit_11/'
train = np.load(data_root + 'train_11.npy')
train_label = np.load(data_root + 'train_label_11.npy')
test = np.load(data_root + 'test_11.npy')

train = train.reshape(1229932, 11, 39)
test = test.reshape(451552, 11, 39)

#feats = [0,2,3,4,5,6,7,8,10]
#train = train[:,feats,:]
#test = test[:,feats,:]

train = train.reshape(1229932, -1)
test = test.reshape(451552, -1)

print('Size of training data: {}'.format(train.shape))
print('Size of testing data: {}'.format(test.shape))
# Out:
# Loading data ...
# Size of training data: (1229932, 429)
# Size of testing data: (451552, 429)

# %%
#from scipy import spatial.distance.cosine
# 0,1: 0.8406975890047381
# 1,2: 0.8408058577925639
# 0,2: 0.5890390591353316
# 看來0,1 有點重疊->刪掉1
# 2,3: 0.8408435099576054
# 3,4: 0.8408087361471327
# 2,4: 0.5891934447436348
# 看來2,3 有點重疊->刪掉3
# 4,5: 0.8407781385646762
# 5,6: 0.8408703774927714
# 4,6: 0.5893461401252141
# 看來4,5 有點重疊
# 6,7: 0.8408710386399266
# 7,8: 0.8408018768428297
# 6,8: 0.5896318464957054
# 看來6,7 有點重疊->刪掉7
# 8,9: 0.8407466205531563
# 9,10: 0.840738934407591
# 8,10: 0.5898820477117614
# 看來8,9 有點重疊->刪掉9
# 用0,2,4,5,6,8,10共7個frame

# %% [markdown]
# ## Create Dataset

# %%
import torch
from torch.utils.data import Dataset

class TIMITDataset(Dataset):
    def __init__(self, X, y=None):
        self.data = torch.from_numpy(X).float()
        if y is not None:
            y = y.astype(np.int)
            self.label = torch.LongTensor(y)
        else:
            self.label = None

    def __getitem__(self, idx):
        if self.label is not None:
            return self.data[idx], self.label[idx]
        else:
            return self.data[idx]

    def __len__(self):
        return len(self.data)

# %% [markdown]
# Split the labeled data into a training set and a validation set, you can modify the variable `VAL_RATIO` to change the ratio of validation data.

# %%
VAL_RATIO = 0

percent = int(train.shape[0] * (1 - VAL_RATIO))
train_x, train_y, val_x, val_y = train[:percent], train_label[:percent], train[percent:], train_label[percent:]
print('Size of training set: {}'.format(train_x.shape))
print('Size of validation set: {}'.format(val_x.shape))
# Out:
# Size of training set: (1229932, 429)
# Size of validation set: (0, 429)

# %% [markdown]
# Create a data loader from the dataset, feel free to tweak the variable `BATCH_SIZE` here.

# %%
BATCH_SIZE = 1024

from torch.utils.data import DataLoader

train_set = TIMITDataset(train_x, train_y)
val_set = TIMITDataset(val_x, val_y)
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True) #only shuffle the training data
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# Cleanup the unneeded variables to save memory.<br>
#
# **notes: if you need to use these variables later, then you may remove this block or clean up unneeded variables later<br>the data size is quite huge, so be aware of memory usage in colab**

# %%
import gc

del train, train_label, train_x, train_y, val_x, val_y
gc.collect()
# Out:
# 40

# %% [markdown]
# ## Create Model

# %% [markdown]
# Define model architecture, you are encouraged to change and experiment with the model architecture.

# %%
import torch
import torch.nn as nn

class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(429, 2048), # 1
            #nn.LeakyReLU(),
            nn.ReLU(),
            nn.BatchNorm1d(2048),
            nn.Dropout(0.5),
            nn.Linear(2048, 2048), # 2
            #nn.LeakyReLU(),
            nn.ReLU(),
            nn.BatchNorm1d(2048),
            nn.Dropout(0.5),
            nn.Linear(2048,1024), # 3
            #nn.LeakyReLU(),
            nn.ReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.5),
            nn.Linear(1024, 1024), # 4
            nn.ReLU(),
            #nn.LeakyReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.5),
            nn.Linear(1024, 512), # 5
            nn.ReLU(),
            #nn.LeakyReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.5),
            nn.Linear(512, 128), # 6
            nn.ReLU(),
            #nn.LeakyReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.5),
            nn.Linear(128, 39)
        )

    def forward(self, x):
        x = self.net(x)
        return x

# %% [markdown]
# ## Training

# %%
#check device
def get_device():
    return 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# Fix random seeds for reproducibility.

# %%
# fix random seed
def same_seeds(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  
    np.random.seed(seed)  
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# Feel free to change the training parameters here.

# %%
# fix random seed for reproducibility
same_seeds(0)

# get device 
device = get_device()
print(f'DEVICE: {device}')

# training parameters
num_epoch = 400              # number of training epoch
learning_rate = 1e-4       # learning rate
l2 = 1e-4
# the path where checkpoint saved
model_path = './model3dnn.ckpt'

# create model, define a loss function, and optimizer
model = Classifier().to(device)
criterion = nn.CrossEntropyLoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=l2)
# Out:
# DEVICE: cuda

# %%
# start training
best_acc = 0.0
epoch = 0
    
for epoch in range(num_epoch):
    train_acc = 0.0
    train_loss = 0.0
    val_acc = 0.0
    val_loss = 0.0

    # training
    model.train() # set the model to training mode
    for i, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad() 
        outputs = model(inputs) 
        batch_loss = criterion(outputs, labels)
        _, train_pred = torch.max(outputs, 1) # get the index of the class with the highest probability
        batch_loss.backward() 
        optimizer.step() 

        train_acc += (train_pred.cpu() == labels.cpu()).sum().item()
        train_loss += batch_loss.item()

    # validation
    if len(val_set) > 0:
        model.eval() # set the model to evaluation mode
        with torch.no_grad():
            for i, data in enumerate(val_loader):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                batch_loss = criterion(outputs, labels) 
                _, val_pred = torch.max(outputs, 1) 
            
                val_acc += (val_pred.cpu() == labels.cpu()).sum().item() # get the index of the class with the highest probability
                val_loss += batch_loss.item()

            print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader), val_acc/len(val_set), val_loss/len(val_loader)
            ))

            # if the model improves, save a checkpoint at this epoch
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'train_acc': train_acc/len(train_set),
                    'train_loss': train_loss/len(train_loader),
                    'val_acc': best_acc/len(val_set),
                    'val_loss': val_loss/len(val_loader),
                }, model_path)
                #torch.save(model.state_dict(), model_path)
                print('saving model with acc {:.3f}'.format(best_acc/len(val_set)))

    else:
        print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
            epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader)
        ))
        epoch += 1

# if not validating, save the last epoch
if len(val_set) == 0:
    #torch.save(model.state_dict(), model_path)
    torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'train_acc': train_acc/len(train_set),
                    'train_loss': train_loss/len(train_loader),
                }, model_path)
    print('saving model at last epoch')
    
print('Finished training after {} epochs'.format(epoch))
# Out:
# [001/400] Train Acc: 0.421297 Loss: 2.099118
# [002/400] Train Acc: 0.556130 Loss: 1.524512
# [003/400] Train Acc: 0.597283 Loss: 1.369756
# [004/400] Train Acc: 0.619846 Loss: 1.284359
# [005/400] Train Acc: 0.635657 Loss: 1.224913
# [006/400] Train Acc: 0.647389 Loss: 1.180992
# [007/400] Train Acc: 0.656686 Loss: 1.146894
# [008/400] Train Acc: 0.664673 Loss: 1.117175
# [009/400] Train Acc: 0.671762 Loss: 1.092029
# [010/400] Train Acc: 0.678171 Loss: 1.068703
# [011/400] Train Acc: 0.682974 Loss: 1.047848
# [012/400] Train Acc: 0.688149 Loss: 1.030083
# [013/400] Train Acc: 0.693453 Loss: 1.012692
# [014/400] Train Acc: 0.697059 Loss: 0.997858
# [015/400] Train Acc: 0.701105 Loss: 0.983254
# [016/400] Train Acc: 0.705203 Loss: 0.969110
# [017/400] Train Acc: 0.708209 Loss: 0.956837
# [018/400] Train Acc: 0.710795 Loss: 0.946017
# [019/400] Train Acc: 0.714026 Loss: 0.936288
# [020/400] Train Acc: 0.716631 Loss: 0.925349
# [021/400] Train Acc: 0.718616 Loss: 0.917028
# [022/400] Train Acc: 0.721109 Loss: 0.908503
# [023/400] Train Acc: 0.722865 Loss: 0.900935
# [024/400] Train Acc: 0.725064 Loss: 0.892846
# [025/400] Train Acc: 0.727489 Loss: 0.884426
# [026/400] Train Acc: 0.728985 Loss: 0.877029
# [027/400] Train Acc: 0.730605 Loss: 0.871625
# [028/400] Train Acc: 0.731938 Loss: 0.865977
# [029/400] Train Acc: 0.733884 Loss: 0.859517
# [030/400] Train Acc: 0.734619 Loss: 0.854676
# [031/400] Train Acc: 0.736285 Loss: 0.851072
# [032/400] Train Acc: 0.737760 Loss: 0.844728
# [033/400] Train Acc: 0.739567 Loss: 0.838569
# [034/400] Train Acc: 0.740347 Loss: 0.835393
# [035/400] Train Acc: 0.740721 Loss: 0.831857
# [036/400] Train Acc: 0.742576 Loss: 0.826786
# [037/400] Train Acc: 0.742913 Loss: 0.823836
# [038/400] Train Acc: 0.744344 Loss: 0.820100
# [039/400] Train Acc: 0.745377 Loss: 0.816200
# [040/400] Train Acc: 0.745849 Loss: 0.813019
# [041/400] Train Acc: 0.747371 Loss: 0.808087
# [042/400] Train Acc: 0.747496 Loss: 0.806429
# [043/400] Train Acc: 0.749389 Loss: 0.802154
# [044/400] Train Acc: 0.749742 Loss: 0.798679
# [045/400] Train Acc: 0.750651 Loss: 0.797020
# [046/400] Train Acc: 0.751029 Loss: 0.793998
# [047/400] Train Acc: 0.751734 Loss: 0.791288
# [048/400] Train Acc: 0.752354 Loss: 0.788903
# [049/400] Train Acc: 0.753298 Loss: 0.786142
# [050/400] Train Acc: 0.753846 Loss: 0.782813
# [051/400] Train Acc: 0.754207 Loss: 0.783170
# [052/400] Train Acc: 0.755177 Loss: 0.779831
# [053/400] Train Acc: 0.755762 Loss: 0.776919
# [054/400] Train Acc: 0.756437 Loss: 0.774284
# [055/400] Train Acc: 0.756565 Loss: 0.773592
# [056/400] Train Acc: 0.756882 Loss: 0.771701
# [057/400] Train Acc: 0.757922 Loss: 0.769012
# [058/400] Train Acc: 0.758387 Loss: 0.766025
# [059/400] Train Acc: 0.758358 Loss: 0.766166
# [060/400] Train Acc: 0.759246 Loss: 0.763487
# [061/400] Train Acc: 0.759755 Loss: 0.761114
# [062/400] Train Acc: 0.760230 Loss: 0.759687
# [063/400] Train Acc: 0.760918 Loss: 0.756980
# [064/400] Train Acc: 0.761395 Loss: 0.755720
# [065/400] Train Acc: 0.761826 Loss: 0.754548
# [066/400] Train Acc: 0.761919 Loss: 0.753257
# [067/400] Train Acc: 0.761296 Loss: 0.752808
# [068/400] Train Acc: 0.763166 Loss: 0.749620
# [069/400] Train Acc: 0.763241 Loss: 0.748578
# [070/400] Train Acc: 0.763231 Loss: 0.747315
# [071/400] Train Acc: 0.763666 Loss: 0.746161
# [072/400] Train Acc: 0.764630 Loss: 0.743529
# [073/400] Train Acc: 0.765159 Loss: 0.742919
# [074/400] Train Acc: 0.764651 Loss: 0.743400
# [075/400] Train Acc: 0.765285 Loss: 0.740825
# [076/400] Train Acc: 0.764839 Loss: 0.740043
# [077/400] Train Acc: 0.766116 Loss: 0.737419
# [078/400] Train Acc: 0.766084 Loss: 0.736807
# [079/400] Train Acc: 0.766764 Loss: 0.735588
# [080/400] Train Acc: 0.766507 Loss: 0.735446
# [081/400] Train Acc: 0.767390 Loss: 0.733181
# [082/400] Train Acc: 0.767888 Loss: 0.732825
# [083/400] Train Acc: 0.768090 Loss: 0.730313
# [084/400] Train Acc: 0.768063 Loss: 0.729889
# [085/400] Train Acc: 0.768359 Loss: 0.729309
# [086/400] Train Acc: 0.767934 Loss: 0.729485
# [087/400] Train Acc: 0.769025 Loss: 0.726968
# [088/400] Train Acc: 0.769457 Loss: 0.725079
# [089/400] Train Acc: 0.769273 Loss: 0.725543
# [090/400] Train Acc: 0.769575 Loss: 0.724347
# [091/400] Train Acc: 0.769966 Loss: 0.723348
# [092/400] Train Acc: 0.770027 Loss: 0.721992
# [093/400] Train Acc: 0.770447 Loss: 0.721001
# [094/400] Train Acc: 0.770839 Loss: 0.719571
# [095/400] Train Acc: 0.770613 Loss: 0.720454
# [096/400] Train Acc: 0.771487 Loss: 0.718690
# [097/400] Train Acc: 0.771373 Loss: 0.718832
# [098/400] Train Acc: 0.772074 Loss: 0.716444
# [099/400] Train Acc: 0.771995 Loss: 0.715897
# [100/400] Train Acc: 0.771833 Loss: 0.716115
# [101/400] Train Acc: 0.771618 Loss: 0.715126
# [102/400] Train Acc: 0.772957 Loss: 0.713448
# [103/400] Train Acc: 0.772402 Loss: 0.714740
# [104/400] Train Acc: 0.773426 Loss: 0.710673
# [105/400] Train Acc: 0.772870 Loss: 0.711531
# [106/400] Train Acc: 0.773431 Loss: 0.709964
# [107/400] Train Acc: 0.773397 Loss: 0.709956
# [108/400] Train Acc: 0.773530 Loss: 0.710401
# [109/400] Train Acc: 0.773574 Loss: 0.708494
# [110/400] Train Acc: 0.773392 Loss: 0.709079
# [111/400] Train Acc: 0.774118 Loss: 0.708273
# [112/400] Train Acc: 0.774426 Loss: 0.705920
# [113/400] Train Acc: 0.774362 Loss: 0.706523
# [114/400] Train Acc: 0.775056 Loss: 0.704688
# [115/400] Train Acc: 0.775240 Loss: 0.704902
# [116/400] Train Acc: 0.775215 Loss: 0.704787
# [117/400] Train Acc: 0.775127 Loss: 0.703685
# [118/400] Train Acc: 0.775010 Loss: 0.703383
# [119/400] Train Acc: 0.775863 Loss: 0.702146
# [120/400] Train Acc: 0.775599 Loss: 0.701574
# [121/400] Train Acc: 0.775674 Loss: 0.701779
# [122/400] Train Acc: 0.776448 Loss: 0.700123
# [123/400] Train Acc: 0.776689 Loss: 0.699486
# [124/400] Train Acc: 0.777119 Loss: 0.698705
# [125/400] Train Acc: 0.776562 Loss: 0.699639
# [126/400] Train Acc: 0.777304 Loss: 0.696552
# [127/400] Train Acc: 0.776856 Loss: 0.697909
# [128/400] Train Acc: 0.776758 Loss: 0.697339
# [129/400] Train Acc: 0.777216 Loss: 0.695972
# [130/400] Train Acc: 0.776897 Loss: 0.696475
# [131/400] Train Acc: 0.777572 Loss: 0.695077
# [132/400] Train Acc: 0.777275 Loss: 0.695367
# [133/400] Train Acc: 0.777922 Loss: 0.694305
# [134/400] Train Acc: 0.778211 Loss: 0.692813
# [135/400] Train Acc: 0.778149 Loss: 0.693612
# [136/400] Train Acc: 0.778361 Loss: 0.692889
# [137/400] Train Acc: 0.778074 Loss: 0.693110
# [138/400] Train Acc: 0.778296 Loss: 0.692298
# [139/400] Train Acc: 0.779156 Loss: 0.690171
# [140/400] Train Acc: 0.779289 Loss: 0.689877
# [141/400] Train Acc: 0.778641 Loss: 0.690898
# [142/400] Train Acc: 0.779067 Loss: 0.689828
# [143/400] Train Acc: 0.778894 Loss: 0.690754
# [144/400] Train Acc: 0.779209 Loss: 0.689137
# [145/400] Train Acc: 0.779785 Loss: 0.688141
# [146/400] Train Acc: 0.779439 Loss: 0.688349
# [147/400] Train Acc: 0.780072 Loss: 0.687642
# [148/400] Train Acc: 0.780267 Loss: 0.687404
# [149/400] Train Acc: 0.780230 Loss: 0.686131
# [150/400] Train Acc: 0.780020 Loss: 0.686729
# [151/400] Train Acc: 0.780472 Loss: 0.685521
# [152/400] Train Acc: 0.780302 Loss: 0.685944
# [153/400] Train Acc: 0.780499 Loss: 0.685372
# [154/400] Train Acc: 0.780835 Loss: 0.684109
# [155/400] Train Acc: 0.780738 Loss: 0.684563
# [156/400] Train Acc: 0.781192 Loss: 0.683152
# [157/400] Train Acc: 0.780904 Loss: 0.682808
# [158/400] Train Acc: 0.780781 Loss: 0.683601
# [159/400] Train Acc: 0.781064 Loss: 0.682261
# [160/400] Train Acc: 0.781110 Loss: 0.681985
# [161/400] Train Acc: 0.781498 Loss: 0.681083
# [162/400] Train Acc: 0.781345 Loss: 0.682297
# [163/400] Train Acc: 0.782033 Loss: 0.680296
# [164/400] Train Acc: 0.781607 Loss: 0.680909
# [165/400] Train Acc: 0.781800 Loss: 0.679862
# [166/400] Train Acc: 0.781965 Loss: 0.679670
# [167/400] Train Acc: 0.781416 Loss: 0.679677
# [168/400] Train Acc: 0.782129 Loss: 0.678702
# [169/400] Train Acc: 0.782197 Loss: 0.678276
# [170/400] Train Acc: 0.782985 Loss: 0.677378
# [171/400] Train Acc: 0.782679 Loss: 0.677744
# [172/400] Train Acc: 0.782814 Loss: 0.677280
# [173/400] Train Acc: 0.782200 Loss: 0.677732
# [174/400] Train Acc: 0.782704 Loss: 0.675777
# [175/400] Train Acc: 0.783264 Loss: 0.675278
# [176/400] Train Acc: 0.782975 Loss: 0.675881
# [177/400] Train Acc: 0.782554 Loss: 0.676977
# [178/400] Train Acc: 0.782907 Loss: 0.677114
# [179/400] Train Acc: 0.783558 Loss: 0.674417
# [180/400] Train Acc: 0.782912 Loss: 0.675771
# [181/400] Train Acc: 0.783364 Loss: 0.673558
# [182/400] Train Acc: 0.783134 Loss: 0.675078
# [183/400] Train Acc: 0.783746 Loss: 0.673876
# [184/400] Train Acc: 0.783427 Loss: 0.673132
# [185/400] Train Acc: 0.783427 Loss: 0.673573
# [186/400] Train Acc: 0.783451 Loss: 0.672960
# [187/400] Train Acc: 0.783458 Loss: 0.673679
# [188/400] Train Acc: 0.783334 Loss: 0.672262
# [189/400] Train Acc: 0.783757 Loss: 0.671648
# [190/400] Train Acc: 0.784085 Loss: 0.671699
# [191/400] Train Acc: 0.784866 Loss: 0.669486
# [192/400] Train Acc: 0.784308 Loss: 0.671381
# [193/400] Train Acc: 0.784208 Loss: 0.670492
# [194/400] Train Acc: 0.784822 Loss: 0.669772
# [195/400] Train Acc: 0.784429 Loss: 0.670761
# [196/400] Train Acc: 0.784246 Loss: 0.670315
# [197/400] Train Acc: 0.784818 Loss: 0.668448
# [198/400] Train Acc: 0.784945 Loss: 0.668832
# [199/400] Train Acc: 0.784666 Loss: 0.668384
# [200/400] Train Acc: 0.785034 Loss: 0.668646
# [201/400] Train Acc: 0.784932 Loss: 0.668775
# [202/400] Train Acc: 0.785237 Loss: 0.667697
# [203/400] Train Acc: 0.785436 Loss: 0.667578
# [204/400] Train Acc: 0.785521 Loss: 0.667359
# [205/400] Train Acc: 0.785630 Loss: 0.666894
# [206/400] Train Acc: 0.785303 Loss: 0.667561
# [207/400] Train Acc: 0.785633 Loss: 0.666514
# [208/400] Train Acc: 0.785841 Loss: 0.666386
# [209/400] Train Acc: 0.785747 Loss: 0.665750
# [210/400] Train Acc: 0.786219 Loss: 0.665116
# [211/400] Train Acc: 0.785980 Loss: 0.665281
# [212/400] Train Acc: 0.786125 Loss: 0.664746
# [213/400] Train Acc: 0.785861 Loss: 0.664806
# [214/400] Train Acc: 0.786182 Loss: 0.665143
# [215/400] Train Acc: 0.785758 Loss: 0.664084
# [216/400] Train Acc: 0.786120 Loss: 0.664255
# [217/400] Train Acc: 0.786542 Loss: 0.662602
# [218/400] Train Acc: 0.786097 Loss: 0.664175
# [219/400] Train Acc: 0.786369 Loss: 0.663031
# [220/400] Train Acc: 0.786989 Loss: 0.661990
# [221/400] Train Acc: 0.787091 Loss: 0.663026
# [222/400] Train Acc: 0.786906 Loss: 0.662293
# [223/400] Train Acc: 0.786803 Loss: 0.661843
# [224/400] Train Acc: 0.787587 Loss: 0.660181
# [225/400] Train Acc: 0.786857 Loss: 0.661195
# [226/400] Train Acc: 0.786591 Loss: 0.661743
# [227/400] Train Acc: 0.787247 Loss: 0.661802
# [228/400] Train Acc: 0.786962 Loss: 0.661331
# [229/400] Train Acc: 0.786879 Loss: 0.661484
# [230/400] Train Acc: 0.787642 Loss: 0.659856
# [231/400] Train Acc: 0.787272 Loss: 0.660118
# [232/400] Train Acc: 0.787691 Loss: 0.660074
# [233/400] Train Acc: 0.787807 Loss: 0.659499
# [234/400] Train Acc: 0.787421 Loss: 0.659516
# [235/400] Train Acc: 0.787861 Loss: 0.658985
# [236/400] Train Acc: 0.787987 Loss: 0.658368
# [237/400] Train Acc: 0.788071 Loss: 0.658171
# [238/400] Train Acc: 0.787801 Loss: 0.658875
# [239/400] Train Acc: 0.787852 Loss: 0.658679
# [240/400] Train Acc: 0.788155 Loss: 0.658264
# [241/400] Train Acc: 0.787588 Loss: 0.658727
# [242/400] Train Acc: 0.787996 Loss: 0.657413
# [243/400] Train Acc: 0.788838 Loss: 0.655542
# [244/400] Train Acc: 0.788208 Loss: 0.658043
# [245/400] Train Acc: 0.788131 Loss: 0.657586
# [246/400] Train Acc: 0.787961 Loss: 0.656788
# [247/400] Train Acc: 0.788412 Loss: 0.656393
# [248/400] Train Acc: 0.788425 Loss: 0.657149
# [249/400] Train Acc: 0.788808 Loss: 0.655477
# [250/400] Train Acc: 0.788800 Loss: 0.655546
# [251/400] Train Acc: 0.788621 Loss: 0.655311
# [252/400] Train Acc: 0.788863 Loss: 0.655263
# [253/400] Train Acc: 0.788807 Loss: 0.655134
# [254/400] Train Acc: 0.788956 Loss: 0.654994
# [255/400] Train Acc: 0.789173 Loss: 0.654459
# [256/400] Train Acc: 0.789050 Loss: 0.654343
# [257/400] Train Acc: 0.789044 Loss: 0.654068
# [258/400] Train Acc: 0.789550 Loss: 0.654092
# [259/400] Train Acc: 0.789596 Loss: 0.654380
# [260/400] Train Acc: 0.789149 Loss: 0.653967
# [261/400] Train Acc: 0.788598 Loss: 0.654802
# [262/400] Train Acc: 0.789433 Loss: 0.652967
# [263/400] Train Acc: 0.789631 Loss: 0.652909
# [264/400] Train Acc: 0.789032 Loss: 0.653601
# [265/400] Train Acc: 0.789473 Loss: 0.652505
# [266/400] Train Acc: 0.789940 Loss: 0.651458
# [267/400] Train Acc: 0.790010 Loss: 0.651132
# [268/400] Train Acc: 0.788952 Loss: 0.653033
# [269/400] Train Acc: 0.790405 Loss: 0.650645
# [270/400] Train Acc: 0.789987 Loss: 0.650825
# [271/400] Train Acc: 0.789907 Loss: 0.651148
# [272/400] Train Acc: 0.789381 Loss: 0.652978
# [273/400] Train Acc: 0.790358 Loss: 0.649354
# [274/400] Train Acc: 0.790471 Loss: 0.649762
# [275/400] Train Acc: 0.790564 Loss: 0.649508
# [276/400] Train Acc: 0.790010 Loss: 0.650847
# [277/400] Train Acc: 0.790483 Loss: 0.650169
# [278/400] Train Acc: 0.790088 Loss: 0.650507
# [279/400] Train Acc: 0.790400 Loss: 0.650000
# [280/400] Train Acc: 0.790294 Loss: 0.649499
# [281/400] Train Acc: 0.790813 Loss: 0.649021
# [282/400] Train Acc: 0.790390 Loss: 0.648839
# [283/400] Train Acc: 0.790753 Loss: 0.647384
# [284/400] Train Acc: 0.790359 Loss: 0.648799
# [285/400] Train Acc: 0.790425 Loss: 0.649263
# [286/400] Train Acc: 0.790371 Loss: 0.649279
# [287/400] Train Acc: 0.790925 Loss: 0.648558
# [288/400] Train Acc: 0.790375 Loss: 0.648573
# [289/400] Train Acc: 0.790997 Loss: 0.648934
# [290/400] Train Acc: 0.791266 Loss: 0.646771
# [291/400] Train Acc: 0.790888 Loss: 0.648224
# [292/400] Train Acc: 0.791528 Loss: 0.646956
# [293/400] Train Acc: 0.790886 Loss: 0.647461
# [294/400] Train Acc: 0.791236 Loss: 0.647111
# [295/400] Train Acc: 0.791059 Loss: 0.647379
# [296/400] Train Acc: 0.791804 Loss: 0.647518
# [297/400] Train Acc: 0.791546 Loss: 0.646529
# [298/400] Train Acc: 0.791757 Loss: 0.645174
# [299/400] Train Acc: 0.791917 Loss: 0.645328
# [300/400] Train Acc: 0.791863 Loss: 0.645146
# [301/400] Train Acc: 0.791513 Loss: 0.645666
# [302/400] Train Acc: 0.791548 Loss: 0.644341
# [303/400] Train Acc: 0.791501 Loss: 0.644328
# [304/400] Train Acc: 0.791885 Loss: 0.644632
# [305/400] Train Acc: 0.792280 Loss: 0.644018
# [306/400] Train Acc: 0.792015 Loss: 0.643608
# [307/400] Train Acc: 0.792337 Loss: 0.643599
# [308/400] Train Acc: 0.792110 Loss: 0.643979
# [309/400] Train Acc: 0.791914 Loss: 0.644404
# [310/400] Train Acc: 0.792492 Loss: 0.643140
# [311/400] Train Acc: 0.791920 Loss: 0.644549
# [312/400] Train Acc: 0.792189 Loss: 0.642740
# [313/400] Train Acc: 0.792275 Loss: 0.643084
# [314/400] Train Acc: 0.791758 Loss: 0.644343
# [315/400] Train Acc: 0.792062 Loss: 0.642967
# [316/400] Train Acc: 0.792437 Loss: 0.642002
# [317/400] Train Acc: 0.792345 Loss: 0.642093
# [318/400] Train Acc: 0.792463 Loss: 0.643329
# [319/400] Train Acc: 0.791959 Loss: 0.642261
# [320/400] Train Acc: 0.792251 Loss: 0.642497
# [321/400] Train Acc: 0.792258 Loss: 0.641677
# [322/400] Train Acc: 0.792528 Loss: 0.642237
# [323/400] Train Acc: 0.793044 Loss: 0.641509
# [324/400] Train Acc: 0.792445 Loss: 0.642444
# [325/400] Train Acc: 0.792280 Loss: 0.642606
# [326/400] Train Acc: 0.792915 Loss: 0.640933
# [327/400] Train Acc: 0.793034 Loss: 0.641299
# [328/400] Train Acc: 0.792620 Loss: 0.641317
# [329/400] Train Acc: 0.792898 Loss: 0.640888
# [330/400] Train Acc: 0.793168 Loss: 0.639905
# [331/400] Train Acc: 0.792943 Loss: 0.641243
# [332/400] Train Acc: 0.793475 Loss: 0.639715
# [333/400] Train Acc: 0.793554 Loss: 0.640379
# [334/400] Train Acc: 0.793016 Loss: 0.641479
# [335/400] Train Acc: 0.793527 Loss: 0.639624
# [336/400] Train Acc: 0.793580 Loss: 0.639226
# [337/400] Train Acc: 0.793473 Loss: 0.640613
# [338/400] Train Acc: 0.793050 Loss: 0.639649
# [339/400] Train Acc: 0.793132 Loss: 0.641024
# [340/400] Train Acc: 0.793001 Loss: 0.639918
# [341/400] Train Acc: 0.793432 Loss: 0.639706
# [342/400] Train Acc: 0.793480 Loss: 0.639420
# [343/400] Train Acc: 0.793761 Loss: 0.639519
# [344/400] Train Acc: 0.793465 Loss: 0.639811
# [345/400] Train Acc: 0.793259 Loss: 0.639225
# [346/400] Train Acc: 0.793289 Loss: 0.639287
# [347/400] Train Acc: 0.793715 Loss: 0.638380
# [348/400] Train Acc: 0.793789 Loss: 0.637549
# [349/400] Train Acc: 0.793655 Loss: 0.638404
# [350/400] Train Acc: 0.793348 Loss: 0.638514
# [351/400] Train Acc: 0.793891 Loss: 0.637272
# [352/400] Train Acc: 0.793779 Loss: 0.637650
# [353/400] Train Acc: 0.794241 Loss: 0.637760
# [354/400] Train Acc: 0.794230 Loss: 0.637360
# [355/400] Train Acc: 0.793945 Loss: 0.637969
# [356/400] Train Acc: 0.793773 Loss: 0.638471
# [357/400] Train Acc: 0.794033 Loss: 0.637881
# [358/400] Train Acc: 0.794004 Loss: 0.637356
# [359/400] Train Acc: 0.793983 Loss: 0.638016
# [360/400] Train Acc: 0.794411 Loss: 0.636902
# [361/400] Train Acc: 0.794220 Loss: 0.637431
# [362/400] Train Acc: 0.793828 Loss: 0.638128
# [363/400] Train Acc: 0.794225 Loss: 0.636176
# [364/400] Train Acc: 0.793923 Loss: 0.637594
# [365/400] Train Acc: 0.794098 Loss: 0.637199
# [366/400] Train Acc: 0.794250 Loss: 0.636011
# [367/400] Train Acc: 0.794321 Loss: 0.636594
# [368/400] Train Acc: 0.794218 Loss: 0.635747
# [369/400] Train Acc: 0.794392 Loss: 0.636507
# [370/400] Train Acc: 0.794646 Loss: 0.635756
# [371/400] Train Acc: 0.794022 Loss: 0.636984
# [372/400] Train Acc: 0.794641 Loss: 0.634895
# [373/400] Train Acc: 0.794542 Loss: 0.636114
# [374/400] Train Acc: 0.794426 Loss: 0.635113
# [375/400] Train Acc: 0.794660 Loss: 0.635617
# [376/400] Train Acc: 0.794650 Loss: 0.636092
# [377/400] Train Acc: 0.794870 Loss: 0.634641
# [378/400] Train Acc: 0.794648 Loss: 0.635687
# [379/400] Train Acc: 0.794637 Loss: 0.634861
# [380/400] Train Acc: 0.794759 Loss: 0.636417
# [381/400] Train Acc: 0.795159 Loss: 0.633370
# [382/400] Train Acc: 0.794619 Loss: 0.635030
# [383/400] Train Acc: 0.794389 Loss: 0.635569
# [384/400] Train Acc: 0.794670 Loss: 0.635765
# [385/400] Train Acc: 0.794666 Loss: 0.635243
# [386/400] Train Acc: 0.794672 Loss: 0.635387
# [387/400] Train Acc: 0.794896 Loss: 0.632946
# [388/400] Train Acc: 0.794775 Loss: 0.635229
# [389/400] Train Acc: 0.794585 Loss: 0.634681
# [390/400] Train Acc: 0.794714 Loss: 0.634711
# [391/400] Train Acc: 0.794640 Loss: 0.634523
# [392/400] Train Acc: 0.794985 Loss: 0.634809
# [393/400] Train Acc: 0.794767 Loss: 0.633669
# [394/400] Train Acc: 0.795064 Loss: 0.634056
# [395/400] Train Acc: 0.794713 Loss: 0.634377
# [396/400] Train Acc: 0.795020 Loss: 0.632900
# [397/400] Train Acc: 0.794963 Loss: 0.634102
# [398/400] Train Acc: 0.794700 Loss: 0.634636
# [399/400] Train Acc: 0.794902 Loss: 0.633392
# [400/400] Train Acc: 0.795503 Loss: 0.632341
# saving model at last epoch
# Finished training after 400 epochs

# %%
def retrain(model_path, num_epoch):
    checkpoint = torch.load(model_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    n_epoch = checkpoint['epoch']
    train_acc = checkpoint['train_acc']
    train_loss = checkpoint['train_loss']
    print('Retrain %d epochs'% num_epoch)
    if len(val_set) > 0:
        val_acc = checkpoint['val_acc']
        val_loss = checkpoint['val_loss']
        print('Resume from epoch {:03d} Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                n_epoch , train_acc, train_loss, val_acc, val_loss
            ))
    else:
        print('Resume from epoch {:03d} Train Acc: {:3.6f} Loss: {:3.6f}'.format(
                n_epoch, train_acc, train_loss
            ))

    
    # start training
    best_acc = 0.0
    epoch = 0
    num_epoch+=n_epoch
    for epoch in range(n_epoch, num_epoch):
        train_acc = 0.0
        train_loss = 0.0
        val_acc = 0.0
        val_loss = 0.0

        # training
        model.train() # set the model to training mode
        for i, data in enumerate(train_loader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad() 
            outputs = model(inputs) 
            batch_loss = criterion(outputs, labels)
            _, train_pred = torch.max(outputs, 1) # get the index of the class with the highest probability
            batch_loss.backward() 
            optimizer.step() 

            train_acc += (train_pred.cpu() == labels.cpu()).sum().item()
            train_loss += batch_loss.item()

        # validation
        if len(val_set) > 0:
            model.eval() # set the model to evaluation mode
            with torch.no_grad():
                for i, data in enumerate(val_loader):
                    inputs, labels = data
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = model(inputs)
                    batch_loss = criterion(outputs, labels) 
                    _, val_pred = torch.max(outputs, 1) 

                    val_acc += (val_pred.cpu() == labels.cpu()).sum().item() # get the index of the class with the highest probability
                    val_loss += batch_loss.item()

                print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                    epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader), val_acc/len(val_set), val_loss/len(val_loader)
                ))

                # if the model improves, save a checkpoint at this epoch
                if val_acc > best_acc:
                    best_acc = val_acc
                    torch.save({
                        'epoch': epoch,
                        'model_state_dict': model.state_dict(),
                        'optimizer_state_dict': optimizer.state_dict(),
                        'train_acc': train_acc/len(train_set),
                        'train_loss': train_loss/len(train_loader),
                        'val_acc': best_acc/len(val_set),
                        'val_loss': val_loss/len(val_loader),
                    }, model_path)
                    #torch.save(model.state_dict(), model_path)
                    print('saving model with acc {:.3f}'.format(best_acc/len(val_set)))

        else:
            print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
                epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader)
            ))
            epoch += 1

    # if not validating, save the last epoch
    if len(val_set) == 0:
        #torch.save(model.state_dict(), model_path)
        torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'train_acc': train_acc/len(train_set),
                    'train_loss': train_loss/len(train_loader),
                }, model_path)
        print('saving model at last epoch')

    print('Finished training after {} epochs'.format(epoch))

# %%
#retrain(model_path, num_epoch=40)

# %% [markdown]
# ## Testing

# %% [markdown]
# Create a testing dataset, and load model from the saved checkpoint.

# %%
# create testing dataset
test_set = TIMITDataset(test, None)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

# create model and load weights from checkpoint
model = Classifier().to(device)
#model.load_state_dict(torch.load(model_path))
model.load_state_dict(torch.load(model_path)['model_state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# Make prediction.

# %%
predict = []
model.eval() # set the model to evaluation mode
with torch.no_grad():
    for i, data in enumerate(test_loader):
        inputs = data
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

        for y in test_pred.cpu().numpy():
            predict.append(y)

# %% [markdown]
# Write prediction to a CSV file.
#
# After finish running this block, download the file `prediction.csv` from the files section on the left-hand side and submit it to Kaggle.

# %%
count = 0
for i in range(1, len(predict)-1):
    previous_ = predict[i-1]
    next_ = predict[i+1]
    current_ = predict[i]
    if (previous_ != current_) and (next_ != current_) and (previous_ == next_):
        print('idx',i,'correct', current_, 'to', previous_)
        predict[i] = previous_
        count +=1

print('total number of correction %d, correction percent %.2f'% (count, count/len(predict)))
# Out:
# idx 1031 correct 31 to 35
# idx 1057 correct 31 to 35
# idx 1074 correct 1 to 17
# idx 1171 correct 18 to 19
# idx 1247 correct 11 to 14
# idx 1323 correct 18 to 19
# idx 1419 correct 4 to 13
# idx 1451 correct 17 to 1
# idx 1618 correct 2 to 1
# idx 1700 correct 2 to 1
# idx 1781 correct 4 to 7
# idx 1933 correct 0 to 8
# idx 2363 correct 4 to 12
# idx 2367 correct 4 to 12
# idx 2369 correct 4 to 12
# idx 2715 correct 17 to 14
# idx 2825 correct 25 to 38
# idx 2841 correct 35 to 36
# idx 3234 correct 3 to 4
# idx 3272 correct 13 to 7
# idx 3471 correct 2 to 1
# idx 3473 correct 2 to 1
# idx 3486 correct 7 to 10
# idx 3872 correct 6 to 1
# idx 3881 correct 38 to 32
# idx 3917 correct 9 to 7
# idx 3966 correct 5 to 1
# idx 3998 correct 2 to 3
# idx 4131 correct 33 to 37
# idx 4307 correct 16 to 10
# idx 4432 correct 3 to 9
# idx 4441 correct 3 to 9
# idx 4810 correct 32 to 38
# idx 5041 correct 29 to 21
# idx 5049 correct 36 to 29
# idx 5208 correct 7 to 9
# idx 5260 correct 21 to 35
# idx 5556 correct 1 to 2
# idx 5729 correct 18 to 19
# idx 5774 correct 18 to 19
# idx 5811 correct 7 to 9
# idx 5840 correct 21 to 36
# idx 5940 correct 1 to 0
# idx 6245 correct 29 to 21
# idx 6268 correct 11 to 3
# idx 6400 correct 17 to 1
# idx 6441 correct 3 to 11
# idx 7385 correct 36 to 22
# idx 7502 correct 38 to 23
# idx 7678 correct 38 to 19
# idx 8110 correct 21 to 29
# idx 8571 correct 1 to 4
# idx 9002 correct 18 to 19
# idx 9006 correct 18 to 19
# idx 9042 correct 12 to 11
# idx 9179 correct 12 to 7
# idx 9548 correct 8 to 0
# idx 9879 correct 20 to 19
# idx 9912 correct 34 to 35
# idx 10081 correct 11 to 12
# idx 10730 correct 3 to 0
# idx 10776 correct 9 to 7
# idx 10790 correct 38 to 33
# idx 10799 correct 28 to 37
# idx 10836 correct 0 to 1
# idx 11111 correct 4 to 1
# idx 11121 correct 38 to 32
# idx 11201 correct 38 to 1
# idx 11261 correct 4 to 1
# idx 11294 correct 19 to 18
# idx 11327 correct 1 to 2
# idx 11487 correct 3 to 38
# idx 11687 correct 19 to 1
# idx 11699 correct 31 to 35
# idx 11702 correct 31 to 35
# idx 11728 correct 1 to 2
# idx 11845 correct 13 to 4
# idx 11883 correct 15 to 17
# idx 11950 correct 34 to 33
# idx 11958 correct 34 to 35
# idx 12095 correct 1 to 9
# idx 12102 correct 19 to 18
# idx 12529 correct 9 to 7
# idx 12540 correct 17 to 14
# idx 12604 correct 3 to 8
# idx 12826 correct 11 to 4
# idx 12854 correct 34 to 29
# idx 12893 correct 12 to 7
# idx 12901 correct 7 to 4
# idx 12954 correct 20 to 19
# idx 12987 correct 2 to 3
# idx 13579 correct 12 to 4
# idx 13630 correct 18 to 19
# idx 13690 correct 1 to 8
# idx 13962 correct 8 to 9
# idx 14021 correct 23 to 25
# idx 14271 correct 31 to 35
# idx 14431 correct 20 to 19
# idx 14555 correct 5 to 13
# idx 14776 correct 29 to 35
# idx 14819 correct 15 to 0
# idx 14932 correct 8 to 9
# idx 15068 correct 10 to 7
# idx 15096 correct 1 to 0
# idx 15098 correct 1 to 0
# idx 15184 correct 38 to 33
# idx 15195 correct 12 to 13
# idx 15201 correct 33 to 34
# idx 15204 correct 38 to 34
# idx 15206 correct 38 to 34
# idx 15612 correct 1 to 0
# idx 16069 correct 38 to 32
# idx 16220 correct 4 to 7
# idx 16289 correct 7 to 10
# idx 16415 correct 19 to 18
# idx 16576 correct 2 to 8
# idx 16594 correct 16 to 13
# idx 16660 correct 4 to 7
# idx 17048 correct 13 to 11
# idx 17349 correct 30 to 29
# idx 17369 correct 5 to 13
# idx 17722 correct 7 to 15
# idx 17737 correct 14 to 17
# idx 18383 correct 31 to 35
# idx 18684 correct 36 to 37
# idx 18812 correct 32 to 13
# idx 18883 correct 8 to 1
# idx 19494 correct 10 to 12
# idx 19727 correct 12 to 7
# idx 19822 correct 1 to 17
# idx 19853 correct 2 to 4
# idx 20117 correct 17 to 14
# idx 20300 correct 1 to 2
# idx 20330 correct 4 to 1
# idx 20541 correct 16 to 7
# idx 20543 correct 4 to 7
# idx 20858 correct 5 to 13
# idx 20876 correct 1 to 2
# idx 21579 correct 35 to 31
# idx 21596 correct 1 to 19
# idx 21721 correct 36 to 35
# idx 21819 correct 2 to 3
# idx 21875 correct 14 to 4
# idx 21894 correct 1 to 8
# idx 21966 correct 34 to 38
# idx 22205 correct 3 to 2
# idx 22282 correct 18 to 19
# idx 22475 correct 19 to 1
# idx 22508 correct 29 to 22
# idx 22664 correct 21 to 36
# idx 22670 correct 2 to 1
# idx 22888 correct 4 to 3
# idx 22997 correct 15 to 0
# idx 23142 correct 24 to 28
# idx 23196 correct 3 to 2
# idx 23227 correct 5 to 1
# idx 23469 correct 32 to 13
# idx 23491 correct 35 to 31
# idx 23670 correct 25 to 29
# idx 23695 correct 7 to 14
# idx 23706 correct 1 to 17
# idx 23750 correct 17 to 14
# idx 23796 correct 3 to 9
# idx 23804 correct 38 to 7
# idx 23806 correct 38 to 7
# idx 23911 correct 4 to 12
# idx 23919 correct 4 to 10
# idx 23927 correct 5 to 1
# idx 24077 correct 16 to 7
# idx 24168 correct 32 to 13
# idx 24186 correct 17 to 1
# idx 24229 correct 14 to 17
# idx 24329 correct 16 to 13
# idx 24402 correct 5 to 1
# idx 24494 correct 1 to 8
# idx 24522 correct 11 to 4
# idx 24588 correct 38 to 0
# idx 24904 correct 15 to 38
# idx 25182 correct 32 to 38
# idx 25438 correct 38 to 37
# idx 25602 correct 19 to 20
# idx 25618 correct 2 to 3
# idx 25627 correct 20 to 19
# idx 25919 correct 13 to 16
# idx 25988 correct 1 to 8
# idx 26091 correct 26 to 1
# idx 26201 correct 2 to 8
# idx 26238 correct 1 to 15
# idx 26571 correct 9 to 4
# idx 26591 correct 36 to 21
# idx 26824 correct 2 to 12
# idx 27141 correct 38 to 34
# idx 27885 correct 0 to 8
# idx 27942 correct 9 to 3
# idx 27979 correct 13 to 9
# idx 28513 correct 3 to 2
# idx 28549 correct 4 to 1
# idx 28692 correct 2 to 4
# idx 28843 correct 7 to 10
# idx 29059 correct 7 to 4
# idx 29143 correct 34 to 23
# idx 29154 correct 35 to 36
# idx 29469 correct 37 to 28
# idx 29568 correct 5 to 17
# idx 29654 correct 9 to 7
# idx 29777 correct 3 to 8
# idx 29932 correct 3 to 2
# idx 30379 correct 7 to 9
# idx 30486 correct 0 to 3
# idx 30639 correct 8 to 3
# idx 31102 correct 30 to 37
# idx 31180 correct 12 to 2
# idx 31335 correct 4 to 13
# idx 31424 correct 0 to 8
# idx 31556 correct 23 to 38
# idx 31732 correct 5 to 1
# idx 31770 correct 8 to 14
# idx 31981 correct 27 to 30
# idx 31986 correct 4 to 2
# idx 31988 correct 4 to 2
# idx 32092 correct 19 to 18
# idx 32227 correct 1 to 37
# idx 32424 correct 38 to 37
# idx 32476 correct 1 to 0
# idx 32664 correct 30 to 33
# idx 32756 correct 17 to 14
# idx 33286 correct 24 to 14
# idx 33521 correct 10 to 6
# idx 33573 correct 7 to 4
# idx 33676 correct 15 to 0
# idx 33948 correct 0 to 15
# idx 34018 correct 34 to 38
# idx 34024 correct 38 to 34
# idx 34247 correct 38 to 32
# idx 34310 correct 2 to 1
# idx 34461 correct 0 to 15
# idx 34523 correct 19 to 20
# idx 34767 correct 8 to 5
# idx 35018 correct 2 to 1
# idx 35146 correct 33 to 38
# idx 35274 correct 14 to 17
# idx 35743 correct 1 to 19
# idx 36168 correct 13 to 12
# idx 36171 correct 13 to 12
# idx 36304 correct 2 to 17
# idx 36478 correct 13 to 12
# idx 36672 correct 12 to 19
# idx 36774 correct 31 to 35
# idx 37204 correct 12 to 4
# idx 37320 correct 7 to 4
# idx 38004 correct 19 to 20
# idx 38564 correct 33 to 28
# idx 38578 correct 16 to 7
# idx 38867 correct 7 to 12
# idx 39270 correct 1 to 4
# idx 39473 correct 5 to 17
# idx 39527 correct 14 to 17
# idx 39593 correct 9 to 3
# idx 39668 correct 38 to 35
# idx 39784 correct 11 to 3
# idx 39813 correct 37 to 0
# idx 39981 correct 34 to 33
# idx 40003 correct 36 to 35
# idx 40078 correct 31 to 35
# idx 40083 correct 35 to 31
# idx 40167 correct 18 to 19
# idx 40208 correct 9 to 10
# idx 40237 correct 34 to 38
# idx 40310 correct 6 to 4
# idx 40624 correct 4 to 1
# idx 40632 correct 35 to 36
# idx 40830 correct 36 to 35
# idx 40942 correct 27 to 38
# idx 40974 correct 19 to 18
# idx 41013 correct 1 to 4
# idx 41148 correct 9 to 3
# idx 41962 correct 3 to 11
# idx 41977 correct 4 to 7
# idx 42757 correct 14 to 7
# idx 42807 correct 33 to 32
# idx 42842 correct 13 to 19
# idx 42911 correct 14 to 17
# idx 42991 correct 29 to 30
# idx 43051 correct 31 to 35
# idx 43529 correct 4 to 3
# idx 43659 correct 17 to 1
# idx 43770 correct 12 to 19
# idx 43774 correct 19 to 13
# idx 44133 correct 38 to 10
# idx 44301 correct 2 to 3
# idx 44425 correct 5 to 1
# idx 44428 correct 14 to 1
# idx 44506 correct 9 to 1
# idx 44771 correct 17 to 7
# idx 45018 correct 10 to 14
# idx 45219 correct 4 to 12
# idx 45301 correct 14 to 17
# idx 45335 correct 33 to 38
# idx 45602 correct 12 to 7
# idx 45686 correct 14 to 17
# idx 45920 correct 38 to 2
# idx 45937 correct 17 to 1
# idx 45955 correct 0 to 8
# idx 46756 correct 34 to 33
# idx 46989 correct 17 to 14
# idx 46996 correct 17 to 2
# idx 47006 correct 35 to 31
# idx 47236 correct 7 to 12
# idx 47298 correct 9 to 3
# idx 47311 correct 31 to 35
# idx 47390 correct 21 to 29
# idx 47503 correct 11 to 13
# idx 47559 correct 33 to 35
# idx 47648 correct 35 to 31
# idx 47740 correct 17 to 14
# idx 47802 correct 19 to 18
# idx 47846 correct 38 to 1
# idx 47855 correct 12 to 18
# idx 47878 correct 35 to 31
# idx 47893 correct 9 to 7
# idx 48147 correct 30 to 28
# idx 48247 correct 16 to 13
# idx 48357 correct 35 to 31
# idx 48517 correct 38 to 35
# idx 48559 correct 11 to 3
# idx 48589 correct 14 to 7
# idx 48638 correct 23 to 38
# idx 48805 correct 14 to 17
# idx 48869 correct 22 to 36
# idx 48875 correct 36 to 22
# idx 48919 correct 4 to 7
# idx 49102 correct 37 to 38
# idx 49261 correct 3 to 7
# idx 49438 correct 9 to 7
# idx 49497 correct 38 to 15
# idx 49889 correct 8 to 9
# idx 49918 correct 8 to 2
# idx 49923 correct 8 to 2
# idx 50269 correct 38 to 19
# idx 50293 correct 13 to 16
# idx 50629 correct 7 to 13
# idx 51164 correct 0 to 8
# idx 51238 correct 9 to 3
# idx 51296 correct 21 to 22
# idx 51307 correct 4 to 2
# idx 51508 correct 30 to 28
# idx 51609 correct 7 to 3
# idx 51707 correct 2 to 8
# idx 51775 correct 19 to 1
# idx 52405 correct 35 to 31
# idx 52458 correct 9 to 3
# idx 52588 correct 7 to 9
# idx 52626 correct 0 to 15
# idx 52672 correct 27 to 30
# idx 52677 correct 11 to 3
# idx 52712 correct 25 to 38
# idx 52791 correct 9 to 7
# idx 52927 correct 4 to 1
# idx 53137 correct 38 to 19
# idx 53217 correct 9 to 8
# idx 53313 correct 4 to 1
# idx 53700 correct 11 to 12
# idx 54676 correct 4 to 38
# idx 54885 correct 4 to 2
# idx 54956 correct 38 to 7
# idx 55062 correct 34 to 33
# idx 55132 correct 3 to 4
# idx 55202 correct 2 to 3
# idx 55614 correct 7 to 11
# idx 55618 correct 7 to 11
# idx 55667 correct 11 to 7
# idx 55685 correct 38 to 33
# idx 55930 correct 35 to 31
# idx 55989 correct 7 to 16
# idx 56050 correct 9 to 8
# idx 56241 correct 38 to 19
# idx 56451 correct 34 to 29
# idx 56898 correct 4 to 9
# idx 57348 correct 38 to 26
# idx 57764 correct 30 to 27
# idx 58072 correct 2 to 3
# idx 58074 correct 2 to 3
# idx 58222 correct 14 to 17
# idx 58225 correct 14 to 17
# idx 58477 correct 5 to 14
# idx 58597 correct 31 to 35
# idx 58762 correct 28 to 30
# idx 58862 correct 27 to 38
# idx 58883 correct 17 to 4
# idx 58885 correct 17 to 4
# idx 59274 correct 2 to 8
# idx 59312 correct 29 to 28
# idx 59354 correct 3 to 2
# idx 59581 correct 17 to 2
# idx 59633 correct 4 to 7
# idx 59666 correct 12 to 4
# idx 59700 correct 38 to 23
# idx 59937 correct 29 to 33
# idx 59972 correct 3 to 9
# idx 60101 correct 34 to 38
# idx 60552 correct 2 to 8
# idx 60669 correct 31 to 35
# idx 60709 correct 5 to 1
# idx 60864 correct 19 to 18
# idx 60947 correct 18 to 19
# idx 61078 correct 3 to 2
# idx 61300 correct 14 to 5
# idx 61488 correct 1 to 0
# idx 61490 correct 8 to 0
# idx 61500 correct 2 to 1
# idx 61510 correct 38 to 35
# idx 61561 correct 30 to 38
# idx 61684 correct 2 to 1
# idx 61762 correct 1 to 0
# idx 61938 correct 2 to 3
# idx 62402 correct 29 to 35
# idx 62534 correct 33 to 38
# idx 62677 correct 8 to 0
# idx 62689 correct 19 to 38
# idx 62699 correct 31 to 22
# idx 62717 correct 11 to 3
# idx 62923 correct 30 to 28
# idx 62967 correct 38 to 13
# idx 63153 correct 38 to 19
# idx 63213 correct 9 to 7
# idx 63531 correct 8 to 10
# idx 63660 correct 28 to 3
# idx 63693 correct 0 to 1
# idx 63710 correct 32 to 38
# idx 63896 correct 18 to 38
# idx 64189 correct 12 to 13
# idx 64381 correct 33 to 32
# idx 64711 correct 1 to 8
# idx 64786 correct 38 to 5
# idx 64846 correct 13 to 4
# idx 64923 correct 38 to 23
# idx 64968 correct 11 to 7
# idx 65008 correct 31 to 35
# idx 65222 correct 17 to 14
# idx 65602 correct 0 to 1
# idx 65613 correct 38 to 19
# idx 65622 correct 3 to 2
# idx 65974 correct 0 to 1
# idx 66885 correct 8 to 2
# idx 66984 correct 34 to 33
# idx 66987 correct 17 to 14
# idx 67523 correct 38 to 32
# idx 67608 correct 2 to 3
# idx 67681 correct 12 to 16
# idx 67788 correct 8 to 0
# idx 67961 correct 2 to 3
# idx 67968 correct 8 to 3
# idx 68208 correct 9 to 7
# idx 68216 correct 9 to 7
# idx 68405 correct 10 to 7
# idx 68552 correct 8 to 9
# idx 68560 correct 30 to 28
# idx 68827 correct 38 to 34
# idx 68955 correct 9 to 7
# idx 69406 correct 9 to 7
# idx 69778 correct 38 to 33
# idx 69781 correct 38 to 33
# idx 69784 correct 38 to 33
# idx 70103 correct 36 to 35
# idx 70228 correct 36 to 21
# idx 70246 correct 3 to 11
# idx 70311 correct 17 to 14
# idx 70319 correct 8 to 0
# idx 70379 correct 31 to 35
# idx 70486 correct 7 to 11
# idx 70641 correct 3 to 9
# idx 70848 correct 3 to 9
# idx 70853 correct 17 to 9
# idx 71407 correct 4 to 5
# idx 71428 correct 38 to 32
# idx 71470 correct 25 to 38
# idx 71498 correct 37 to 38
# idx 71500 correct 37 to 38
# idx 71867 correct 2 to 17
# idx 72245 correct 17 to 14
# idx 72297 correct 31 to 35
# idx 73324 correct 4 to 7
# idx 73645 correct 38 to 8
# idx 74130 correct 18 to 19
# idx 74324 correct 1 to 2
# idx 74424 correct 13 to 12
# idx 74616 correct 19 to 18
# idx 75233 correct 4 to 7
# idx 75235 correct 4 to 7
# idx 75306 correct 13 to 7
# idx 75355 correct 25 to 38
# idx 75702 correct 1 to 17
# idx 75948 correct 4 to 1
# idx 76097 correct 8 to 2
# idx 76140 correct 4 to 7
# idx 76173 correct 31 to 35
# idx 76179 correct 36 to 35
# idx 76611 correct 10 to 13
# idx 76616 correct 1 to 10
# idx 76633 correct 1 to 17
# idx 76690 correct 14 to 17
# idx 76768 correct 1 to 4
# idx 76975 correct 17 to 2
# idx 77418 correct 30 to 38
# idx 77664 correct 33 to 38
# idx 77800 correct 2 to 3
# idx 77831 correct 23 to 38
# idx 78132 correct 15 to 17
# idx 78330 correct 38 to 30
# idx 78503 correct 1 to 2
# idx 78532 correct 35 to 31
# idx 78545 correct 1 to 13
# idx 78683 correct 25 to 29
# idx 78697 correct 12 to 7
# idx 78970 correct 12 to 4
# idx 79015 correct 4 to 9
# idx 79108 correct 3 to 4
# idx 79258 correct 3 to 4
# idx 79320 correct 2 to 4
# idx 79450 correct 1 to 38
# idx 79708 correct 17 to 14
# idx 79868 correct 30 to 38
# idx 79963 correct 31 to 35
# idx 80239 correct 28 to 38
# idx 80308 correct 31 to 36
# idx 80388 correct 3 to 8
# idx 80429 correct 35 to 31
# idx 80470 correct 12 to 13
# idx 81034 correct 33 to 38
# idx 81181 correct 29 to 25
# idx 81278 correct 34 to 33
# idx 81492 correct 3 to 4
# idx 81607 correct 4 to 2
# idx 81625 correct 7 to 11
# idx 81745 correct 1 to 2
# idx 82012 correct 29 to 38
# idx 82554 correct 1 to 4
# idx 82773 correct 34 to 38
# idx 82775 correct 32 to 38
# idx 82782 correct 8 to 3
# idx 82817 correct 30 to 38
# idx 83204 correct 30 to 38
# idx 83208 correct 29 to 30
# idx 83451 correct 37 to 38
# idx 83527 correct 38 to 35
# idx 83657 correct 13 to 16
# idx 83663 correct 2 to 17
# idx 83826 correct 7 to 4
# idx 83858 correct 2 to 12
# idx 83861 correct 2 to 12
# idx 83886 correct 19 to 18
# idx 83896 correct 35 to 36
# idx 83969 correct 10 to 7
# idx 84085 correct 23 to 29
# idx 84206 correct 34 to 38
# idx 84367 correct 38 to 1
# idx 84420 correct 4 to 13
# idx 84567 correct 31 to 35
# idx 85342 correct 3 to 9
# idx 85421 correct 30 to 38
# idx 85545 correct 38 to 30
# idx 85613 correct 12 to 7
# idx 85770 correct 31 to 35
# idx 85924 correct 11 to 7
# idx 85944 correct 30 to 28
# idx 86527 correct 9 to 7
# idx 86545 correct 7 to 9
# idx 86600 correct 37 to 38
# idx 86863 correct 21 to 29
# idx 86877 correct 2 to 1
# idx 87041 correct 35 to 31
# idx 87093 correct 14 to 17
# idx 87180 correct 3 to 11
# idx 87182 correct 4 to 11
# idx 87554 correct 20 to 19
# idx 88272 correct 2 to 1
# idx 88458 correct 18 to 19
# idx 88471 correct 1 to 4
# idx 88523 correct 12 to 13
# idx 88534 correct 29 to 33
# idx 88643 correct 38 to 19
# idx 88796 correct 33 to 34
# idx 88884 correct 34 to 23
# idx 88928 correct 16 to 7
# idx 88970 correct 14 to 17
# idx 89096 correct 17 to 1
# idx 89201 correct 25 to 38
# idx 89298 correct 1 to 4
# idx 89386 correct 35 to 31
# idx 89473 correct 17 to 1
# idx 89787 correct 38 to 26
# idx 89848 correct 12 to 4
# idx 89886 correct 34 to 23
# idx 89888 correct 34 to 23
# idx 89931 correct 4 to 1
# idx 89948 correct 0 to 1
# idx 90545 correct 19 to 38
# idx 90757 correct 12 to 7
# idx 90940 correct 4 to 30
# idx 91076 correct 2 to 3
# idx 91149 correct 0 to 1
# idx 91265 correct 32 to 33
# idx 91870 correct 30 to 38
# idx 92652 correct 18 to 32
# idx 92793 correct 0 to 8
# idx 92945 correct 32 to 38
# idx 93287 correct 2 to 3
# idx 93346 correct 0 to 8
# idx 93901 correct 38 to 33
# idx 93931 correct 13 to 9
# idx 93961 correct 9 to 7
# idx 94038 correct 14 to 17
# idx 94255 correct 12 to 13
# idx 94427 correct 19 to 20
# idx 94891 correct 9 to 14
# idx 94942 correct 0 to 15
# idx 94961 correct 4 to 12
# idx 95464 correct 38 to 26
# idx 95472 correct 2 to 8
# idx 96322 correct 4 to 7
# idx 96440 correct 19 to 1
# idx 96677 correct 1 to 4
# idx 96713 correct 14 to 7
# idx 96883 correct 14 to 17
# idx 96935 correct 7 to 13
# idx 97393 correct 15 to 0
# idx 97701 correct 7 to 3
# idx 97746 correct 3 to 2
# idx 98032 correct 20 to 19
# idx 98466 correct 3 to 2
# idx 98484 correct 35 to 21
# idx 98512 correct 4 to 9
# idx 98931 correct 29 to 21
# idx 99168 correct 4 to 16
# idx 99601 correct 37 to 38
# idx 99812 correct 7 to 12
# idx 100298 correct 4 to 7
# idx 100429 correct 0 to 8
# idx 100922 correct 9 to 3
# idx 101220 correct 4 to 29
# idx 101300 correct 4 to 7
# idx 101305 correct 4 to 7
# idx 101622 correct 13 to 7
# idx 102014 correct 31 to 35
# idx 102037 correct 31 to 35
# idx 102296 correct 8 to 3
# idx 102453 correct 4 to 7
# idx 102805 correct 2 to 1
# idx 102852 correct 22 to 21
# idx 103656 correct 12 to 4
# idx 104092 correct 20 to 19
# idx 104147 correct 28 to 38
# idx 104319 correct 32 to 38
# idx 104322 correct 35 to 31
# idx 104480 correct 1 to 12
# idx 104580 correct 7 to 11
# idx 104655 correct 21 to 29
# idx 104826 correct 31 to 35
# idx 104883 correct 9 to 11
# idx 105048 correct 8 to 3
# idx 105197 correct 31 to 35
# idx 105202 correct 35 to 31
# idx 105745 correct 14 to 7
# idx 105806 correct 11 to 7
# idx 105864 correct 2 to 3
# idx 106912 correct 18 to 16
# idx 107073 correct 31 to 35
# idx 107111 correct 16 to 13
# idx 107161 correct 34 to 38
# idx 107164 correct 34 to 38
# idx 107323 correct 13 to 19
# idx 107416 correct 29 to 37
# idx 107421 correct 1 to 0
# idx 107606 correct 31 to 35
# idx 107658 correct 18 to 19
# idx 107664 correct 1 to 0
# idx 107915 correct 14 to 17
# idx 107931 correct 7 to 17
# idx 108177 correct 0 to 3
# idx 108338 correct 29 to 38
# idx 108579 correct 1 to 0
# idx 108583 correct 38 to 26
# idx 108999 correct 1 to 0
# idx 109075 correct 12 to 7
# idx 109266 correct 2 to 1
# idx 109268 correct 2 to 1
# idx 109290 correct 5 to 1
# idx 109339 correct 19 to 1
# idx 109650 correct 19 to 18
# idx 109838 correct 34 to 23
# idx 110012 correct 18 to 19
# idx 110066 correct 38 to 32
# idx 110263 correct 9 to 7
# idx 110273 correct 38 to 34
# idx 110275 correct 38 to 34
# idx 110424 correct 38 to 30
# idx 110472 correct 11 to 1
# idx 110509 correct 26 to 38
# idx 110589 correct 8 to 14
# idx 111368 correct 36 to 35
# idx 111390 correct 14 to 2
# idx 111627 correct 2 to 8
# idx 111776 correct 4 to 7
# idx 111968 correct 8 to 3
# idx 111971 correct 8 to 3
# idx 111975 correct 8 to 3
# idx 112087 correct 31 to 35
# idx 112218 correct 1 to 8
# idx 112222 correct 23 to 26
# idx 112360 correct 4 to 13
# idx 112414 correct 8 to 2
# idx 112450 correct 35 to 36
# idx 112505 correct 5 to 12
# idx 113722 correct 12 to 7
# idx 113831 correct 14 to 4
# idx 114027 correct 36 to 35
# idx 114033 correct 10 to 13
# idx 114133 correct 14 to 17
# idx 114412 correct 10 to 8
# idx 114963 correct 1 to 2
# idx 114966 correct 1 to 2
# idx 115022 correct 36 to 21
# idx 115060 correct 1 to 17
# idx 115364 correct 35 to 31
# idx 115799 correct 16 to 13
# idx 115868 correct 34 to 33
# idx 115891 correct 35 to 31
# idx 115925 correct 31 to 35
# idx 116477 correct 10 to 7
# idx 116536 correct 2 to 1
# idx 116675 correct 30 to 38
# idx 117010 correct 9 to 7
# idx 117031 correct 7 to 38
# idx 117035 correct 7 to 13
# idx 117135 correct 14 to 17
# idx 117153 correct 1 to 30
# idx 117213 correct 4 to 12
# idx 117515 correct 25 to 38
# idx 117554 correct 30 to 38
# idx 117556 correct 30 to 38
# idx 117616 correct 4 to 7
# idx 119106 correct 17 to 8
# idx 119284 correct 10 to 7
# idx 119483 correct 1 to 4
# idx 119568 correct 22 to 21
# idx 119591 correct 7 to 9
# idx 119674 correct 9 to 8
# idx 119683 correct 29 to 31
# idx 120077 correct 1 to 2
# idx 120196 correct 4 to 12
# idx 120349 correct 14 to 17
# idx 120532 correct 14 to 7
# idx 121429 correct 13 to 9
# idx 121601 correct 23 to 29
# idx 121764 correct 1 to 2
# idx 121857 correct 11 to 2
# idx 121870 correct 17 to 14
# idx 122045 correct 12 to 13
# idx 122262 correct 0 to 1
# idx 122341 correct 9 to 4
# idx 122348 correct 23 to 19
# idx 122723 correct 11 to 7
# idx 122834 correct 38 to 14
# idx 122864 correct 0 to 8
# idx 122947 correct 0 to 1
# idx 123332 correct 36 to 35
# idx 123552 correct 38 to 19
# idx 124102 correct 1 to 8
# idx 124106 correct 3 to 8
# idx 124249 correct 38 to 7
# idx 124256 correct 12 to 7
# idx 124409 correct 9 to 7
# idx 124801 correct 7 to 17
# idx 124810 correct 4 to 13
# idx 125049 correct 35 to 36
# idx 125112 correct 35 to 36
# idx 125133 correct 19 to 13
# idx 125139 correct 1 to 0
# idx 125141 correct 1 to 0
# idx 125220 correct 35 to 36
# idx 125360 correct 7 to 38
# idx 125418 correct 10 to 8
# idx 125501 correct 7 to 9
# idx 125749 correct 21 to 22
# idx 125760 correct 2 to 3
# idx 126236 correct 0 to 8
# idx 126264 correct 7 to 10
# idx 126608 correct 3 to 11
# idx 126994 correct 31 to 35
# idx 127061 correct 29 to 21
# idx 127292 correct 12 to 7
# idx 127409 correct 9 to 11
# idx 127588 correct 7 to 12
# idx 127678 correct 38 to 19
# idx 128287 correct 38 to 31
# idx 128389 correct 25 to 22
# idx 128462 correct 29 to 38
# idx 129041 correct 17 to 1
# idx 129377 correct 14 to 7
# idx 129387 correct 4 to 1
# idx 129389 correct 4 to 1
# idx 129856 correct 12 to 8
# idx 129952 correct 28 to 38
# idx 129972 correct 4 to 9
# idx 129974 correct 7 to 9
# idx 129981 correct 29 to 38
# idx 130070 correct 8 to 1
# idx 130083 correct 32 to 33
# idx 130233 correct 20 to 19
# idx 130249 correct 1 to 5
# idx 130579 correct 31 to 35
# idx 130696 correct 2 to 17
# idx 130826 correct 35 to 31
# idx 130914 correct 35 to 31
# idx 131249 correct 38 to 29
# idx 131805 correct 9 to 10
# idx 132068 correct 17 to 14
# idx 132088 correct 0 to 8
# idx 132462 correct 18 to 38
# idx 132627 correct 18 to 38
# idx 133431 correct 4 to 12
# idx 133477 correct 11 to 3
# idx 133482 correct 2 to 3
# idx 133960 correct 13 to 8
# idx 134043 correct 2 to 3
# idx 134471 correct 30 to 38
# idx 134838 correct 11 to 4
# idx 134989 correct 3 to 2
# idx 135042 correct 4 to 11
# idx 135061 correct 30 to 16
# idx 135439 correct 8 to 1
# idx 135636 correct 17 to 7
# idx 135668 correct 8 to 9
# idx 135670 correct 8 to 9
# idx 135835 correct 3 to 4
# idx 135869 correct 18 to 19
# idx 136034 correct 3 to 4
# idx 136102 correct 35 to 34
# idx 136274 correct 3 to 9
# idx 136288 correct 1 to 3
# idx 136365 correct 2 to 1
# idx 136433 correct 38 to 26
# idx 136568 correct 11 to 12
# idx 136590 correct 35 to 31
# idx 137171 correct 29 to 23
# idx 137207 correct 32 to 38
# idx 137384 correct 37 to 0
# idx 137470 correct 16 to 13
# idx 137472 correct 12 to 13
# idx 137516 correct 5 to 17
# idx 137521 correct 17 to 32
# idx 137577 correct 5 to 13
# idx 137598 correct 1 to 0
# idx 137698 correct 29 to 38
# idx 137809 correct 38 to 19
# idx 137828 correct 37 to 33
# idx 138016 correct 33 to 38
# idx 138112 correct 31 to 35
# idx 138154 correct 15 to 5
# idx 138290 correct 31 to 35
# idx 138514 correct 5 to 0
# idx 138565 correct 5 to 7
# idx 138567 correct 13 to 7
# idx 139110 correct 7 to 13
# idx 139289 correct 17 to 13
# idx 139316 correct 14 to 10
# idx 139874 correct 30 to 38
# idx 140010 correct 16 to 5
# idx 140071 correct 9 to 7
# idx 140102 correct 35 to 31
# idx 140124 correct 10 to 12
# idx 140283 correct 8 to 1
# idx 140322 correct 13 to 12
# idx 140387 correct 6 to 5
# idx 140578 correct 4 to 7
# idx 140724 correct 7 to 12
# idx 140737 correct 13 to 12
# idx 140836 correct 9 to 7
# idx 140847 correct 7 to 9
# idx 141085 correct 1 to 4
# idx 141376 correct 29 to 21
# idx 141446 correct 14 to 13
# idx 141699 correct 31 to 35
# idx 142254 correct 23 to 30
# idx 142278 correct 29 to 38
# idx 142614 correct 1 to 8
# idx 142654 correct 9 to 3
# idx 142673 correct 32 to 33
# idx 142677 correct 14 to 17
# idx 142926 correct 31 to 35
# idx 143094 correct 36 to 21
# idx 143096 correct 36 to 21
# idx 143154 correct 4 to 7
# idx 143171 correct 30 to 28
# idx 143273 correct 8 to 2
# idx 143490 correct 35 to 31
# idx 143582 correct 31 to 35
# idx 143757 correct 1 to 2
# idx 143899 correct 23 to 33
# idx 143930 correct 1 to 19
# idx 143936 correct 38 to 18
# idx 144137 correct 1 to 4
# idx 144224 correct 34 to 33
# idx 145101 correct 14 to 17
# idx 145148 correct 33 to 38
# idx 145178 correct 2 to 1
# idx 145182 correct 0 to 1
# idx 145214 correct 6 to 1
# idx 145421 correct 8 to 1
# idx 145622 correct 21 to 22
# idx 146288 correct 2 to 3
# idx 146292 correct 2 to 3
# idx 146294 correct 2 to 3
# idx 146336 correct 17 to 4
# idx 146588 correct 11 to 7
# idx 146603 correct 38 to 32
# idx 146754 correct 33 to 38
# idx 146815 correct 12 to 7
# idx 146958 correct 4 to 2
# idx 146979 correct 9 to 7
# idx 146984 correct 14 to 3
# idx 147093 correct 1 to 0
# idx 147154 correct 31 to 36
# idx 147423 correct 30 to 16
# idx 148164 correct 14 to 17
# idx 148196 correct 9 to 7
# idx 148248 correct 0 to 8
# idx 148445 correct 2 to 1
# idx 148547 correct 5 to 17
# idx 148578 correct 17 to 1
# idx 148589 correct 17 to 4
# idx 148636 correct 2 to 3
# idx 148813 correct 2 to 3
# idx 148817 correct 3 to 2
# idx 149039 correct 29 to 33
# idx 149122 correct 13 to 7
# idx 149145 correct 7 to 10
# idx 149159 correct 10 to 8
# idx 149273 correct 6 to 5
# idx 149336 correct 4 to 1
# idx 149424 correct 12 to 4
# idx 149534 correct 8 to 0
# idx 149673 correct 1 to 17
# idx 149699 correct 35 to 36
# idx 150394 correct 36 to 35
# idx 150655 correct 30 to 38
# idx 150672 correct 12 to 7
# idx 150787 correct 29 to 38
# idx 151045 correct 10 to 8
# idx 151251 correct 6 to 4
# idx 151353 correct 33 to 38
# idx 151424 correct 16 to 7
# idx 151569 correct 9 to 7
# idx 151753 correct 7 to 9
# idx 151805 correct 0 to 1
# idx 151908 correct 3 to 2
# idx 151972 correct 12 to 7
# idx 152040 correct 2 to 3
# idx 152165 correct 38 to 19
# idx 152202 correct 21 to 22
# idx 152213 correct 34 to 38
# idx 152264 correct 1 to 8
# idx 152449 correct 13 to 12
# idx 152670 correct 1 to 5
# idx 152877 correct 8 to 3
# idx 152989 correct 1 to 4
# idx 153070 correct 29 to 30
# idx 153168 correct 35 to 31
# idx 154055 correct 38 to 33
# idx 154064 correct 14 to 17
# idx 154125 correct 1 to 0
# idx 154165 correct 31 to 36
# idx 154176 correct 2 to 1
# idx 154476 correct 35 to 31
# idx 154837 correct 7 to 11
# idx 155049 correct 4 to 1
# idx 155280 correct 23 to 34
# idx 156348 correct 23 to 13
# idx 156488 correct 31 to 35
# idx 156498 correct 5 to 1
# idx 156500 correct 2 to 1
# idx 156816 correct 1 to 3
# idx 157115 correct 7 to 9
# idx 157279 correct 4 to 7
# idx 157323 correct 12 to 19
# idx 157327 correct 31 to 35
# idx 157541 correct 35 to 31
# idx 157712 correct 12 to 13
# idx 157917 correct 6 to 12
# idx 158066 correct 34 to 35
# idx 158098 correct 14 to 17
# idx 158126 correct 38 to 18
# idx 158287 correct 13 to 0
# idx 158300 correct 38 to 33
# idx 158323 correct 28 to 30
# idx 158325 correct 28 to 30
# idx 158339 correct 13 to 12
# idx 158343 correct 13 to 12
# idx 158817 correct 30 to 38
# idx 158852 correct 3 to 1
# idx 158854 correct 8 to 1
# idx 159317 correct 1 to 0
# idx 159789 correct 2 to 1
# idx 159935 correct 16 to 13
# idx 160220 correct 13 to 38
# idx 160227 correct 10 to 7
# idx 160368 correct 7 to 4
# idx 160394 correct 13 to 10
# idx 160605 correct 4 to 3
# idx 160640 correct 2 to 8
# idx 160829 correct 2 to 7
# idx 160870 correct 4 to 1
# idx 161084 correct 19 to 20
# idx 161092 correct 19 to 38
# idx 161387 correct 38 to 10
# idx 161389 correct 38 to 10
# idx 161450 correct 27 to 38
# idx 161542 correct 7 to 5
# idx 161676 correct 0 to 1
# idx 161833 correct 31 to 35
# idx 161849 correct 4 to 12
# idx 161870 correct 38 to 13
# idx 162095 correct 12 to 13
# idx 162222 correct 14 to 17
# idx 162497 correct 3 to 11
# idx 162504 correct 2 to 11
# idx 162670 correct 16 to 13
# idx 162702 correct 7 to 4
# idx 162907 correct 7 to 9
# idx 163038 correct 3 to 1
# idx 163126 correct 7 to 12
# idx 163129 correct 13 to 12
# idx 163521 correct 4 to 7
# idx 163603 correct 1 to 0
# idx 163618 correct 37 to 30
# idx 163676 correct 20 to 18
# idx 164217 correct 30 to 38
# idx 164479 correct 14 to 17
# idx 164621 correct 9 to 7
# idx 164904 correct 4 to 12
# idx 165188 correct 5 to 13
# idx 165196 correct 5 to 4
# idx 165420 correct 13 to 12
# idx 165426 correct 13 to 12
# idx 165774 correct 7 to 10
# idx 165925 correct 12 to 13
# idx 166368 correct 18 to 19
# idx 166397 correct 2 to 3
# idx 166802 correct 1 to 0
# idx 166954 correct 6 to 12
# idx 167090 correct 38 to 33
# idx 167138 correct 11 to 3
# idx 167207 correct 38 to 33
# idx 167502 correct 38 to 33
# idx 167523 correct 11 to 7
# idx 167527 correct 11 to 9
# idx 167803 correct 8 to 9
# idx 167841 correct 8 to 17
# idx 167864 correct 14 to 4
# idx 167913 correct 38 to 19
# idx 168066 correct 38 to 26
# idx 168086 correct 36 to 31
# idx 168239 correct 10 to 7
# idx 168332 correct 33 to 38
# idx 168670 correct 33 to 38
# idx 168714 correct 18 to 19
# idx 168759 correct 14 to 3
# idx 168792 correct 33 to 28
# idx 168837 correct 15 to 0
# idx 168867 correct 17 to 1
# idx 168913 correct 19 to 20
# idx 169327 correct 1 to 0
# idx 169531 correct 31 to 35
# idx 169734 correct 25 to 38
# idx 169795 correct 12 to 4
# idx 169850 correct 1 to 0
# idx 169980 correct 19 to 18
# idx 170418 correct 31 to 35
# idx 170437 correct 8 to 14
# idx 170618 correct 28 to 38
# idx 170671 correct 18 to 19
# idx 170947 correct 6 to 1
# idx 170987 correct 14 to 10
# idx 171118 correct 17 to 1
# idx 171181 correct 19 to 1
# idx 171208 correct 2 to 1
# idx 171350 correct 37 to 15
# idx 171806 correct 5 to 0
# idx 171989 correct 4 to 12
# idx 172036 correct 38 to 26
# idx 172166 correct 7 to 4
# idx 172196 correct 11 to 3
# idx 172312 correct 4 to 1
# idx 172377 correct 38 to 32
# idx 172544 correct 9 to 8
# idx 172731 correct 8 to 9
# idx 172910 correct 4 to 3
# idx 172962 correct 33 to 29
# idx 173049 correct 0 to 1
# idx 173308 correct 21 to 22
# idx 173495 correct 29 to 22
# idx 173528 correct 14 to 12
# idx 173530 correct 7 to 12
# idx 173601 correct 24 to 18
# idx 174007 correct 7 to 9
# idx 174050 correct 30 to 28
# idx 174191 correct 31 to 35
# idx 174468 correct 9 to 7
# idx 174735 correct 7 to 10
# idx 174884 correct 9 to 4
# idx 174913 correct 35 to 31
# idx 174960 correct 29 to 38
# idx 175015 correct 32 to 38
# idx 175143 correct 15 to 0
# idx 175210 correct 38 to 33
# idx 175218 correct 1 to 0
# idx 175220 correct 1 to 0
# idx 175578 correct 9 to 7
# idx 175657 correct 38 to 35
# idx 175984 correct 29 to 37
# idx 176125 correct 13 to 7
# idx 176142 correct 28 to 29
# idx 176191 correct 12 to 13
# idx 176194 correct 19 to 13
# idx 176311 correct 37 to 38
# idx 176423 correct 12 to 7
# idx 176878 correct 19 to 38
# idx 176935 correct 7 to 16
# idx 177040 correct 17 to 1
# idx 177618 correct 32 to 33
# idx 178056 correct 9 to 11
# idx 178142 correct 30 to 16
# idx 178217 correct 36 to 21
# idx 178249 correct 16 to 14
# idx 178376 correct 14 to 23
# idx 178397 correct 7 to 13
# idx 178561 correct 35 to 31
# idx 178738 correct 30 to 29
# idx 179238 correct 9 to 4
# idx 179422 correct 2 to 3
# idx 179424 correct 2 to 3
# idx 179609 correct 29 to 38
# idx 179701 correct 9 to 7
# idx 180026 correct 1 to 0
# idx 180215 correct 37 to 18
# idx 180287 correct 13 to 4
# idx 180399 correct 4 to 7
# idx 180873 correct 14 to 16
# idx 180916 correct 4 to 9
# idx 180942 correct 34 to 30
# idx 181062 correct 1 to 2
# idx 181118 correct 1 to 8
# idx 181377 correct 0 to 15
# idx 181458 correct 33 to 34
# idx 181788 correct 9 to 11
# idx 181818 correct 18 to 13
# idx 182156 correct 30 to 38
# idx 182376 correct 2 to 8
# idx 182756 correct 17 to 4
# idx 182761 correct 18 to 19
# idx 182765 correct 18 to 19
# idx 183499 correct 30 to 38
# idx 183503 correct 23 to 38
# idx 183642 correct 3 to 2
# idx 183755 correct 11 to 12
# idx 183807 correct 2 to 1
# idx 184357 correct 10 to 7
# idx 184457 correct 5 to 1
# idx 184463 correct 2 to 5
# idx 184534 correct 23 to 38
# idx 184566 correct 22 to 29
# idx 184590 correct 9 to 7
# idx 184685 correct 31 to 35
# idx 184858 correct 1 to 8
# idx 185220 correct 1 to 8
# idx 185280 correct 13 to 12
# idx 185315 correct 38 to 23
# idx 185464 correct 0 to 1
# idx 185508 correct 5 to 1
# idx 185604 correct 8 to 2
# idx 185608 correct 8 to 2
# idx 185696 correct 38 to 16
# idx 185761 correct 0 to 8
# idx 185866 correct 7 to 9
# idx 186012 correct 14 to 17
# idx 186201 correct 0 to 5
# idx 186584 correct 10 to 7
# idx 186726 correct 17 to 7
# idx 186896 correct 12 to 11
# idx 186939 correct 1 to 0
# idx 187060 correct 8 to 3
# idx 187107 correct 34 to 38
# idx 187199 correct 8 to 0
# idx 187220 correct 13 to 12
# idx 187254 correct 3 to 11
# idx 187277 correct 8 to 38
# idx 187312 correct 2 to 3
# idx 187445 correct 30 to 38
# idx 187496 correct 34 to 33
# idx 187518 correct 3 to 8
# idx 187619 correct 8 to 9
# idx 187732 correct 11 to 7
# idx 187923 correct 37 to 38
# idx 188111 correct 8 to 3
# idx 188178 correct 8 to 9
# idx 188243 correct 35 to 33
# idx 188257 correct 9 to 7
# idx 188360 correct 35 to 33
# idx 188740 correct 21 to 35
# idx 188810 correct 0 to 8
# idx 188820 correct 32 to 23
# idx 188860 correct 2 to 1
# idx 189058 correct 38 to 18
# idx 189068 correct 12 to 13
# idx 189310 correct 14 to 7
# idx 189463 correct 19 to 3
# idx 189519 correct 21 to 30
# idx 190116 correct 3 to 2
# idx 190368 correct 4 to 1
# idx 190637 correct 19 to 38
# idx 190720 correct 21 to 36
# idx 190752 correct 2 to 1
# idx 190836 correct 1 to 2
# idx 190855 correct 28 to 30
# idx 191004 correct 4 to 7
# idx 191042 correct 0 to 8
# idx 191233 correct 9 to 3
# idx 191258 correct 31 to 34
# idx 191305 correct 7 to 9
# idx 191411 correct 1 to 0
# idx 191512 correct 14 to 4
# idx 191598 correct 19 to 20
# idx 191630 correct 8 to 0
# idx 191634 correct 1 to 8
# idx 191703 correct 37 to 3
# idx 191806 correct 13 to 11
# idx 191894 correct 31 to 35
# idx 192279 correct 4 to 3
# idx 192359 correct 12 to 5
# idx 192990 correct 13 to 4
# idx 193016 correct 12 to 13
# idx 193227 correct 4 to 2
# idx 193231 correct 19 to 18
# idx 193284 correct 3 to 2
# idx 193337 correct 38 to 31
# idx 193493 correct 2 to 8
# idx 193628 correct 16 to 38
# idx 193654 correct 28 to 29
# idx 194182 correct 0 to 1
# idx 194236 correct 38 to 1
# idx 194282 correct 8 to 0
# idx 194376 correct 32 to 38
# idx 194434 correct 4 to 12
# idx 194570 correct 18 to 38
# idx 194577 correct 33 to 38
# idx 194626 correct 13 to 4
# idx 194639 correct 4 to 2
# idx 194982 correct 4 to 3
# idx 195245 correct 17 to 1
# idx 195295 correct 2 to 8
# idx 195385 correct 1 to 4
# idx 195387 correct 17 to 4
# idx 195399 correct 4 to 1
# idx 195441 correct 32 to 38
# idx 195460 correct 35 to 31
# idx 195506 correct 1 to 2
# idx 195558 correct 33 to 36
# idx 195586 correct 38 to 1
# idx 195597 correct 3 to 2
# idx 195606 correct 3 to 2
# idx 195618 correct 38 to 31
# idx 195852 correct 18 to 19
# idx 195898 correct 23 to 34
# idx 195951 correct 21 to 35
# idx 195977 correct 10 to 7
# idx 196120 correct 9 to 3
# idx 196156 correct 8 to 3
# idx 196168 correct 10 to 13
# idx 196273 correct 23 to 13
# idx 196332 correct 12 to 13
# idx 196436 correct 33 to 36
# idx 196442 correct 36 to 33
# idx 196743 correct 4 to 1
# idx 196774 correct 38 to 31
# idx 196825 correct 17 to 1
# idx 196950 correct 8 to 0
# idx 196965 correct 5 to 0
# idx 196980 correct 31 to 35
# idx 196993 correct 4 to 13
# idx 197018 correct 31 to 35
# idx 197097 correct 19 to 18
# idx 197249 correct 31 to 35
# idx 197278 correct 31 to 35
# idx 197839 correct 1 to 2
# idx 197966 correct 38 to 18
# idx 198239 correct 1 to 8
# idx 198290 correct 2 to 3
# idx 198542 correct 6 to 1
# idx 198593 correct 1 to 8
# idx 198622 correct 3 to 8
# idx 198624 correct 9 to 8
# idx 199001 correct 12 to 13
# idx 199062 correct 7 to 10
# idx 199286 correct 23 to 26
# idx 199316 correct 34 to 33
# idx 199390 correct 32 to 14
# idx 199599 correct 32 to 38
# idx 199651 correct 31 to 35
# idx 199699 correct 35 to 36
# idx 199765 correct 2 to 3
# idx 199869 correct 29 to 38
# idx 199878 correct 20 to 1
# idx 200467 correct 4 to 1
# idx 200648 correct 8 to 9
# idx 200992 correct 1 to 5
# idx 201000 correct 1 to 2
# idx 201050 correct 3 to 2
# idx 201052 correct 3 to 2
# idx 201098 correct 9 to 3
# idx 201194 correct 35 to 29
# idx 201196 correct 21 to 29
# idx 201308 correct 2 to 3
# idx 201395 correct 38 to 32
# idx 201656 correct 9 to 7
# idx 201796 correct 10 to 8
# idx 201908 correct 31 to 22
# idx 202024 correct 3 to 2
# idx 202167 correct 9 to 8
# idx 202201 correct 2 to 3
# idx 202281 correct 29 to 38
# idx 202560 correct 1 to 0
# idx 202723 correct 1 to 4
# idx 202803 correct 3 to 1
# idx 203128 correct 2 to 3
# idx 203311 correct 7 to 10
# idx 203313 correct 7 to 10
# idx 203358 correct 36 to 35
# idx 203360 correct 36 to 35
# idx 203424 correct 22 to 29
# idx 203821 correct 5 to 7
# idx 203915 correct 14 to 17
# idx 203962 correct 2 to 4
# idx 203981 correct 22 to 21
# idx 203984 correct 22 to 21
# idx 204124 correct 11 to 3
# idx 204168 correct 36 to 33
# idx 204220 correct 9 to 7
# idx 204463 correct 8 to 0
# idx 204915 correct 20 to 19
# idx 205370 correct 38 to 17
# idx 205383 correct 31 to 35
# idx 205447 correct 36 to 35
# idx 205503 correct 38 to 32
# idx 205526 correct 7 to 11
# idx 205529 correct 7 to 11
# idx 205595 correct 1 to 0
# idx 205851 correct 3 to 4
# idx 205853 correct 2 to 4
# idx 205856 correct 2 to 4
# idx 206100 correct 31 to 35
# idx 206102 correct 31 to 35
# idx 206185 correct 9 to 19
# idx 206236 correct 6 to 13
# idx 206448 correct 36 to 21
# idx 206759 correct 31 to 35
# idx 206774 correct 1 to 2
# idx 206789 correct 1 to 0
# idx 206849 correct 2 to 9
# idx 207003 correct 29 to 22
# idx 207204 correct 1 to 0
# idx 207375 correct 11 to 12
# idx 207441 correct 38 to 26
# idx 207936 correct 11 to 7
# idx 208341 correct 29 to 21
# idx 208399 correct 1 to 17
# idx 208749 correct 38 to 35
# idx 208758 correct 3 to 11
# idx 208873 correct 1 to 5
# idx 209116 correct 38 to 35
# idx 209299 correct 3 to 2
# idx 209307 correct 25 to 38
# idx 209446 correct 7 to 3
# idx 209654 correct 10 to 7
# idx 209677 correct 2 to 17
# idx 209759 correct 28 to 38
# idx 209761 correct 28 to 38
# idx 209784 correct 0 to 8
# idx 209795 correct 38 to 19
# idx 209936 correct 31 to 35
# idx 209948 correct 36 to 35
# idx 210057 correct 2 to 1
# idx 210122 correct 11 to 3
# idx 210124 correct 11 to 3
# idx 210664 correct 9 to 7
# idx 210718 correct 0 to 1
# idx 210935 correct 7 to 3
# idx 210940 correct 7 to 3
# idx 211170 correct 19 to 38
# idx 211183 correct 1 to 0
# idx 211252 correct 8 to 0
# idx 211290 correct 13 to 9
# idx 211443 correct 1 to 2
# idx 211650 correct 9 to 7
# idx 211672 correct 4 to 19
# idx 211708 correct 3 to 12
# idx 211830 correct 34 to 38
# idx 211917 correct 19 to 20
# idx 211931 correct 1 to 8
# idx 211940 correct 0 to 1
# idx 211983 correct 11 to 4
# idx 212109 correct 3 to 2
# idx 212136 correct 7 to 9
# idx 212229 correct 21 to 35
# idx 212372 correct 1 to 8
# idx 212409 correct 22 to 38
# idx 212455 correct 7 to 11
# idx 212567 correct 4 to 7
# idx 212610 correct 4 to 7
# idx 212646 correct 34 to 23
# idx 212835 correct 29 to 35
# idx 213005 correct 6 to 1
# idx 214044 correct 12 to 4
# idx 214046 correct 7 to 4
# idx 214179 correct 2 to 4
# idx 214483 correct 0 to 1
# idx 214657 correct 4 to 7
# idx 214659 correct 4 to 7
# idx 214689 correct 18 to 19
# idx 214836 correct 10 to 8
# idx 214958 correct 7 to 9
# idx 215008 correct 8 to 38
# idx 215053 correct 35 to 31
# idx 215074 correct 2 to 1
# idx 215083 correct 17 to 14
# idx 215157 correct 27 to 38
# idx 215171 correct 1 to 8
# idx 215228 correct 1 to 4
# idx 215285 correct 19 to 20
# idx 215785 correct 2 to 9
# idx 216281 correct 38 to 3
# idx 216316 correct 35 to 38
# idx 216365 correct 2 to 8
# idx 216405 correct 0 to 1
# idx 216413 correct 38 to 19
# idx 216441 correct 18 to 19
# idx 216488 correct 38 to 32
# idx 216688 correct 38 to 34
# idx 216735 correct 13 to 7
# idx 216826 correct 38 to 0
# idx 216968 correct 12 to 4
# idx 217055 correct 29 to 21
# idx 217062 correct 1 to 0
# idx 217237 correct 38 to 13
# idx 217522 correct 34 to 29
# idx 217728 correct 35 to 23
# idx 217766 correct 21 to 36
# idx 218439 correct 8 to 3
# idx 218557 correct 35 to 31
# idx 218814 correct 2 to 17
# idx 218923 correct 2 to 4
# idx 219104 correct 2 to 4
# idx 219262 correct 11 to 3
# idx 219361 correct 1 to 15
# idx 219411 correct 29 to 30
# idx 219647 correct 13 to 12
# idx 219897 correct 8 to 9
# idx 220120 correct 0 to 8
# idx 220267 correct 14 to 17
# idx 220457 correct 29 to 38
# idx 220856 correct 27 to 30
# idx 220920 correct 5 to 1
# idx 220996 correct 2 to 17
# idx 221081 correct 31 to 35
# idx 221167 correct 22 to 21
# idx 221541 correct 16 to 5
# idx 221601 correct 1 to 0
# idx 221723 correct 8 to 0
# idx 221888 correct 33 to 38
# idx 222025 correct 12 to 5
# idx 222241 correct 26 to 0
# idx 222475 correct 2 to 3
# idx 222981 correct 7 to 17
# idx 223252 correct 11 to 7
# idx 223288 correct 12 to 7
# idx 223308 correct 9 to 1
# idx 223556 correct 2 to 1
# idx 223698 correct 28 to 33
# idx 223743 correct 36 to 35
# idx 223822 correct 23 to 37
# idx 223903 correct 14 to 17
# idx 223940 correct 11 to 3
# idx 224058 correct 1 to 17
# idx 224070 correct 29 to 21
# idx 224103 correct 38 to 36
# idx 224350 correct 32 to 14
# idx 224366 correct 8 to 2
# idx 224608 correct 12 to 7
# idx 224822 correct 12 to 1
# idx 224832 correct 17 to 4
# idx 224920 correct 13 to 7
# idx 225119 correct 38 to 7
# idx 225394 correct 12 to 13
# idx 225839 correct 2 to 1
# idx 225845 correct 1 to 2
# idx 225978 correct 35 to 31
# idx 225980 correct 35 to 31
# idx 226084 correct 6 to 1
# idx 226312 correct 36 to 31
# idx 226387 correct 5 to 1
# idx 226406 correct 19 to 38
# idx 226426 correct 38 to 37
# idx 226746 correct 4 to 7
# idx 226783 correct 0 to 38
# idx 227180 correct 7 to 4
# idx 227293 correct 30 to 28
# idx 227440 correct 14 to 17
# idx 227507 correct 2 to 3
# idx 227590 correct 38 to 23
# idx 227698 correct 35 to 36
# idx 227700 correct 35 to 36
# idx 227714 correct 7 to 17
# idx 227731 correct 22 to 29
# idx 228340 correct 38 to 33
# idx 228478 correct 4 to 5
# idx 228592 correct 14 to 17
# idx 228823 correct 25 to 8
# idx 228886 correct 3 to 8
# idx 229296 correct 31 to 35
# idx 229369 correct 23 to 38
# idx 229432 correct 1 to 13
# idx 229482 correct 11 to 13
# idx 229791 correct 18 to 38
# idx 230004 correct 27 to 38
# idx 230823 correct 17 to 2
# idx 230973 correct 19 to 26
# idx 231078 correct 22 to 31
# idx 231210 correct 13 to 7
# idx 231240 correct 8 to 4
# idx 231364 correct 8 to 1
# idx 231401 correct 1 to 4
# idx 231403 correct 17 to 4
# idx 231501 correct 20 to 19
# idx 231701 correct 20 to 38
# idx 231737 correct 19 to 18
# idx 231826 correct 38 to 30
# idx 231937 correct 2 to 9
# idx 232057 correct 12 to 4
# idx 232082 correct 9 to 38
# idx 232411 correct 7 to 9
# idx 232455 correct 11 to 7
# idx 232539 correct 2 to 1
# idx 232579 correct 2 to 5
# idx 232612 correct 4 to 11
# idx 232635 correct 8 to 9
# idx 232858 correct 4 to 7
# idx 233091 correct 4 to 12
# idx 233166 correct 38 to 31
# idx 233252 correct 9 to 4
# idx 233304 correct 2 to 8
# idx 233315 correct 18 to 38
# idx 233853 correct 4 to 3
# idx 233998 correct 31 to 35
# idx 234074 correct 17 to 14
# idx 234178 correct 31 to 22
# idx 234209 correct 13 to 16
# idx 234312 correct 17 to 6
# idx 234508 correct 26 to 8
# idx 234618 correct 13 to 4
# idx 234921 correct 35 to 31
# idx 235238 correct 3 to 0
# idx 235332 correct 1 to 0
# idx 235391 correct 31 to 35
# idx 235729 correct 12 to 1
# idx 235732 correct 2 to 1
# idx 236540 correct 9 to 8
# idx 237166 correct 17 to 2
# idx 237370 correct 9 to 7
# idx 237605 correct 9 to 11
# idx 237630 correct 4 to 1
# idx 237945 correct 2 to 12
# idx 238134 correct 1 to 0
# idx 238157 correct 19 to 5
# idx 238196 correct 12 to 13
# idx 238293 correct 7 to 2
# idx 238298 correct 7 to 13
# idx 238341 correct 14 to 17
# idx 238396 correct 2 to 1
# idx 238521 correct 9 to 8
# idx 238626 correct 35 to 31
# idx 238629 correct 35 to 31
# idx 239072 correct 8 to 0
# idx 239518 correct 12 to 10
# idx 239750 correct 12 to 13
# idx 239821 correct 32 to 14
# idx 240025 correct 17 to 11
# idx 240053 correct 0 to 1
# idx 240087 correct 28 to 38
# idx 240102 correct 18 to 38
# idx 240221 correct 9 to 7
# idx 240249 correct 30 to 38
# idx 240964 correct 21 to 22
# idx 241013 correct 31 to 35
# idx 241051 correct 25 to 23
# idx 241456 correct 1 to 8
# idx 241568 correct 32 to 38
# idx 241617 correct 3 to 1
# idx 242850 correct 2 to 3
# idx 243037 correct 38 to 35
# idx 243125 correct 25 to 38
# idx 243328 correct 12 to 13
# idx 243412 correct 25 to 17
# idx 243530 correct 38 to 34
# idx 243764 correct 31 to 35
# idx 243784 correct 0 to 8
# idx 243786 correct 0 to 8
# idx 244074 correct 9 to 7
# idx 244862 correct 8 to 9
# idx 245175 correct 13 to 12
# idx 245749 correct 4 to 8
# idx 245767 correct 30 to 29
# idx 245773 correct 1 to 17
# idx 245954 correct 36 to 35
# idx 245968 correct 33 to 28
# idx 246097 correct 7 to 4
# idx 246163 correct 14 to 2
# idx 246481 correct 13 to 7
# idx 246508 correct 35 to 21
# idx 246626 correct 13 to 16
# idx 246637 correct 9 to 3
# idx 246978 correct 16 to 13
# idx 247517 correct 1 to 0
# idx 247718 correct 2 to 8
# idx 247914 correct 13 to 38
# idx 248073 correct 19 to 18
# idx 248180 correct 33 to 38
# idx 248567 correct 28 to 33
# idx 248704 correct 35 to 34
# idx 248707 correct 29 to 34
# idx 248882 correct 1 to 0
# idx 249034 correct 38 to 18
# idx 249278 correct 35 to 31
# idx 249488 correct 31 to 35
# idx 249531 correct 2 to 4
# idx 249698 correct 0 to 5
# idx 250017 correct 1 to 2
# idx 250412 correct 12 to 13
# idx 250440 correct 5 to 16
# idx 250846 correct 4 to 2
# idx 250865 correct 8 to 2
# idx 251006 correct 15 to 1
# idx 251165 correct 1 to 2
# idx 251227 correct 5 to 0
# idx 251389 correct 7 to 11
# idx 251393 correct 7 to 11
# idx 251509 correct 31 to 35
# idx 251536 correct 19 to 18
# idx 251682 correct 3 to 2
# idx 251692 correct 18 to 19
# idx 251782 correct 9 to 7
# idx 252144 correct 23 to 32
# idx 252242 correct 3 to 2
# idx 252349 correct 19 to 18
# idx 252372 correct 31 to 35
# idx 253045 correct 11 to 7
# idx 253141 correct 1 to 4
# idx 253285 correct 35 to 31
# idx 253288 correct 35 to 31
# idx 253479 correct 28 to 29
# idx 253514 correct 31 to 38
# idx 253551 correct 1 to 4
# idx 253553 correct 1 to 4
# idx 253563 correct 29 to 34
# idx 253606 correct 3 to 8
# idx 253678 correct 30 to 37
# idx 253700 correct 13 to 7
# idx 253712 correct 38 to 35
# idx 253737 correct 2 to 3
# idx 253773 correct 1 to 8
# idx 254001 correct 18 to 19
# idx 254003 correct 18 to 19
# idx 254100 correct 7 to 16
# idx 254202 correct 38 to 19
# idx 254279 correct 35 to 31
# idx 254575 correct 14 to 17
# idx 254688 correct 1 to 5
# idx 255081 correct 17 to 6
# idx 255179 correct 0 to 1
# idx 255193 correct 20 to 19
# idx 255917 correct 5 to 19
# idx 256325 correct 5 to 1
# idx 256331 correct 5 to 1
# idx 256391 correct 5 to 1
# idx 256394 correct 5 to 1
# idx 256397 correct 38 to 33
# idx 256459 correct 7 to 3
# idx 256826 correct 2 to 1
# idx 256877 correct 0 to 8
# idx 256924 correct 9 to 4
# idx 257089 correct 14 to 4
# idx 257172 correct 35 to 31
# idx 257389 correct 25 to 38
# idx 257416 correct 18 to 16
# idx 257418 correct 14 to 16
# idx 257565 correct 12 to 7
# idx 257626 correct 13 to 11
# idx 258127 correct 38 to 37
# idx 258163 correct 14 to 7
# idx 258202 correct 15 to 0
# idx 258377 correct 18 to 38
# idx 259098 correct 17 to 7
# idx 259344 correct 29 to 38
# idx 259505 correct 0 to 1
# idx 259576 correct 38 to 35
# idx 259739 correct 31 to 35
# idx 259798 correct 2 to 3
# idx 260288 correct 31 to 35
# idx 260346 correct 1 to 2
# idx 260628 correct 13 to 12
# idx 260657 correct 11 to 7
# idx 260760 correct 10 to 12
# idx 260763 correct 7 to 12
# idx 261019 correct 19 to 18
# idx 261089 correct 12 to 10
# idx 261579 correct 4 to 1
# idx 261780 correct 2 to 3
# idx 261964 correct 31 to 35
# idx 262135 correct 11 to 7
# idx 262362 correct 17 to 1
# idx 262402 correct 7 to 13
# idx 262481 correct 10 to 9
# idx 262687 correct 2 to 1
# idx 262797 correct 1 to 17
# idx 263049 correct 18 to 19
# idx 263173 correct 38 to 23
# idx 263206 correct 38 to 18
# idx 263321 correct 18 to 9
# idx 263375 correct 31 to 35
# idx 263454 correct 16 to 10
# idx 263538 correct 38 to 36
# idx 263540 correct 21 to 36
# idx 263814 correct 31 to 35
# idx 264217 correct 16 to 10
# idx 264399 correct 20 to 19
# idx 264423 correct 12 to 6
# idx 264456 correct 14 to 38
# idx 264489 correct 18 to 19
# idx 264735 correct 1 to 5
# idx 264774 correct 37 to 38
# idx 264831 correct 9 to 7
# idx 264959 correct 31 to 35
# idx 265068 correct 35 to 31
# idx 265155 correct 19 to 18
# idx 265223 correct 4 to 1
# idx 265231 correct 32 to 33
# idx 265333 correct 11 to 3
# idx 265338 correct 11 to 13
# idx 265340 correct 11 to 13
# idx 265492 correct 1 to 8
# idx 265752 correct 34 to 38
# idx 265788 correct 38 to 0
# idx 265798 correct 35 to 36
# idx 265934 correct 35 to 31
# idx 266180 correct 31 to 35
# idx 266182 correct 31 to 35
# idx 266318 correct 1 to 0
# idx 266320 correct 1 to 0
# idx 266892 correct 9 to 4
# idx 266894 correct 9 to 4
# idx 266992 correct 0 to 1
# idx 267135 correct 28 to 38
# idx 267174 correct 32 to 23
# idx 267266 correct 34 to 33
# idx 267349 correct 35 to 31
# idx 267353 correct 36 to 31
# idx 267401 correct 1 to 0
# idx 267499 correct 19 to 18
# idx 268147 correct 11 to 4
# idx 268316 correct 2 to 3
# idx 268377 correct 26 to 38
# idx 268560 correct 5 to 1
# idx 268719 correct 11 to 12
# idx 268774 correct 37 to 3
# idx 269191 correct 7 to 9
# idx 269474 correct 31 to 25
# idx 269500 correct 23 to 38
# idx 269618 correct 1 to 0
# idx 269635 correct 9 to 7
# idx 269679 correct 2 to 4
# idx 269691 correct 38 to 23
# idx 269719 correct 8 to 1
# idx 269781 correct 4 to 2
# idx 269844 correct 31 to 35
# idx 269846 correct 31 to 35
# idx 269928 correct 3 to 9
# idx 270114 correct 16 to 13
# ...
# idx 364022 correct 28 to 30
# idx 364137 correct 4 to 1
# idx 364147 correct 4 to 9
# idx 364150 correct 4 to 9
# idx 364171 correct 12 to 7
# idx 364266 correct 0 to 1
# idx 364932 correct 3 to 9
# idx 365066 correct 38 to 34
# idx 365217 correct 32 to 34
# idx 365515 correct 21 to 35
# idx 365555 correct 22 to 21
# idx 365721 correct 17 to 2
# idx 365848 correct 4 to 2
# idx 366348 correct 5 to 0
# idx 366372 correct 27 to 38
# idx 366412 correct 2 to 8
# idx 366450 correct 32 to 38
# idx 366652 correct 3 to 2
# idx 366835 correct 3 to 11
# idx 366958 correct 1 to 0
# idx 367177 correct 33 to 38
# idx 367740 correct 3 to 2
# idx 368150 correct 19 to 18
# idx 368369 correct 1 to 17
# idx 368422 correct 35 to 33
# idx 368466 correct 1 to 4
# idx 368528 correct 4 to 2
# idx 368672 correct 12 to 2
# idx 368678 correct 13 to 12
# idx 368936 correct 14 to 12
# idx 368941 correct 5 to 7
# idx 369010 correct 4 to 6
# idx 369147 correct 22 to 31
# idx 369244 correct 21 to 29
# idx 369412 correct 33 to 35
# idx 369531 correct 17 to 14
# idx 369609 correct 3 to 1
# idx 369641 correct 21 to 22
# idx 369847 correct 35 to 31
# idx 370123 correct 33 to 34
# idx 370141 correct 8 to 3
# idx 370230 correct 33 to 38
# idx 370232 correct 32 to 38
# idx 371064 correct 8 to 1
# idx 371558 correct 1 to 17
# idx 372052 correct 11 to 4
# idx 372057 correct 12 to 11
# idx 372101 correct 34 to 23
# idx 372204 correct 1 to 8
# idx 372293 correct 2 to 3
# idx 372747 correct 1 to 5
# idx 372803 correct 17 to 14
# idx 372829 correct 0 to 37
# idx 373265 correct 4 to 11
# idx 373596 correct 4 to 12
# idx 373670 correct 2 to 3
# idx 373796 correct 3 to 7
# idx 373840 correct 31 to 35
# idx 373996 correct 3 to 11
# idx 374332 correct 2 to 13
# idx 374433 correct 38 to 7
# idx 374564 correct 38 to 1
# idx 374590 correct 37 to 7
# idx 374624 correct 16 to 5
# idx 374628 correct 13 to 5
# idx 374703 correct 4 to 1
# idx 374761 correct 13 to 14
# idx 374866 correct 31 to 35
# idx 375275 correct 38 to 30
# idx 375335 correct 25 to 38
# idx 375472 correct 1 to 2
# idx 376376 correct 4 to 7
# idx 376487 correct 31 to 35
# idx 376653 correct 14 to 17
# idx 376821 correct 37 to 19
# idx 376828 correct 1 to 2
# idx 376921 correct 38 to 28
# idx 377302 correct 2 to 1
# idx 377481 correct 4 to 3
# idx 377947 correct 2 to 3
# idx 378030 correct 7 to 11
# idx 378220 correct 5 to 12
# idx 378248 correct 21 to 29
# idx 378365 correct 30 to 37
# idx 378471 correct 1 to 17
# idx 379306 correct 29 to 31
# idx 379607 correct 35 to 31
# idx 379704 correct 35 to 31
# idx 379826 correct 14 to 16
# idx 379850 correct 19 to 18
# idx 380163 correct 30 to 22
# idx 380171 correct 1 to 17
# idx 380244 correct 25 to 38
# idx 380288 correct 2 to 8
# idx 380367 correct 32 to 13
# idx 380397 correct 2 to 1
# idx 380520 correct 18 to 32
# idx 380658 correct 34 to 33
# idx 380719 correct 19 to 18
# idx 381042 correct 31 to 35
# idx 381259 correct 2 to 17
# idx 381509 correct 9 to 2
# idx 381547 correct 9 to 7
# idx 381606 correct 8 to 0
# idx 381812 correct 20 to 0
# idx 381941 correct 37 to 3
# idx 382132 correct 26 to 3
# idx 382138 correct 19 to 3
# idx 382187 correct 13 to 11
# idx 382351 correct 12 to 13
# idx 382386 correct 35 to 31
# idx 382441 correct 2 to 8
# idx 382450 correct 7 to 17
# idx 382455 correct 14 to 17
# idx 382556 correct 21 to 36
# idx 382733 correct 1 to 2
# idx 382843 correct 4 to 7
# idx 382915 correct 25 to 37
# idx 383369 correct 33 to 34
# idx 383445 correct 8 to 3
# idx 383477 correct 33 to 38
# idx 383619 correct 3 to 1
# idx 383658 correct 8 to 38
# idx 383762 correct 3 to 2
# idx 383777 correct 33 to 34
# idx 383909 correct 2 to 17
# idx 383922 correct 4 to 1
# idx 384026 correct 36 to 21
# idx 384048 correct 31 to 35
# idx 384068 correct 9 to 7
# idx 384110 correct 18 to 38
# idx 384203 correct 4 to 1
# idx 385102 correct 13 to 12
# idx 385854 correct 38 to 37
# idx 385856 correct 38 to 37
# idx 385869 correct 7 to 11
# idx 385890 correct 10 to 8
# idx 386016 correct 19 to 18
# idx 386025 correct 31 to 35
# idx 386029 correct 8 to 2
# idx 386105 correct 5 to 17
# idx 386192 correct 13 to 4
# idx 386471 correct 9 to 7
# idx 386518 correct 38 to 36
# idx 386772 correct 31 to 35
# idx 386776 correct 31 to 35
# idx 387636 correct 31 to 35
# idx 387976 correct 31 to 35
# idx 388071 correct 2 to 3
# idx 388622 correct 1 to 0
# idx 388686 correct 7 to 13
# idx 388881 correct 17 to 1
# idx 388921 correct 36 to 33
# idx 388964 correct 13 to 6
# idx 389033 correct 3 to 2
# idx 389048 correct 7 to 17
# idx 389298 correct 30 to 29
# idx 389385 correct 17 to 14
# idx 390922 correct 8 to 10
# idx 390946 correct 16 to 10
# idx 390951 correct 9 to 13
# idx 390963 correct 3 to 11
# idx 390984 correct 31 to 35
# idx 391426 correct 14 to 17
# idx 391581 correct 5 to 0
# idx 391645 correct 1 to 17
# idx 391809 correct 3 to 11
# idx 391812 correct 3 to 11
# idx 391861 correct 18 to 38
# idx 392055 correct 35 to 31
# idx 392533 correct 29 to 38
# idx 393421 correct 1 to 17
# idx 393448 correct 8 to 0
# idx 393726 correct 25 to 38
# idx 393817 correct 1 to 2
# idx 394234 correct 2 to 3
# idx 394248 correct 3 to 38
# idx 394301 correct 0 to 1
# idx 394431 correct 7 to 38
# idx 394450 correct 1 to 17
# idx 394541 correct 0 to 1
# idx 394647 correct 36 to 35
# idx 394651 correct 4 to 1
# idx 394654 correct 38 to 1
# idx 394944 correct 35 to 31
# idx 394986 correct 8 to 2
# idx 395052 correct 2 to 4
# idx 395079 correct 37 to 38
# idx 395357 correct 9 to 7
# idx 395370 correct 7 to 38
# idx 395424 correct 9 to 3
# idx 395478 correct 7 to 12
# idx 395489 correct 0 to 1
# idx 395647 correct 7 to 9
# idx 395720 correct 35 to 31
# idx 395731 correct 29 to 28
# idx 395755 correct 38 to 13
# idx 395797 correct 13 to 12
# idx 395942 correct 8 to 3
# idx 395956 correct 38 to 8
# idx 396397 correct 38 to 7
# idx 396741 correct 38 to 32
# idx 396865 correct 7 to 12
# idx 396888 correct 33 to 28
# idx 396910 correct 14 to 17
# idx 396941 correct 1 to 19
# idx 397002 correct 8 to 1
# idx 397452 correct 31 to 35
# idx 397457 correct 35 to 31
# idx 397488 correct 4 to 17
# idx 397506 correct 2 to 3
# idx 397557 correct 38 to 33
# idx 398114 correct 14 to 17
# idx 398255 correct 33 to 28
# idx 398274 correct 4 to 12
# idx 398280 correct 13 to 12
# idx 398315 correct 33 to 34
# idx 398417 correct 20 to 19
# idx 398618 correct 12 to 2
# idx 399184 correct 35 to 36
# idx 399187 correct 1 to 0
# idx 399382 correct 1 to 4
# idx 399770 correct 22 to 36
# idx 399961 correct 0 to 8
# idx 400343 correct 1 to 4
# idx 400412 correct 31 to 35
# idx 400689 correct 5 to 12
# idx 400827 correct 31 to 33
# idx 401146 correct 22 to 21
# idx 401644 correct 1 to 0
# idx 401938 correct 5 to 1
# idx 401983 correct 37 to 19
# idx 402144 correct 3 to 4
# idx 402221 correct 4 to 17
# idx 402269 correct 4 to 7
# idx 402970 correct 31 to 35
# idx 403167 correct 7 to 3
# idx 403700 correct 3 to 8
# idx 403731 correct 7 to 9
# idx 403795 correct 2 to 1
# idx 403940 correct 3 to 4
# idx 404279 correct 15 to 17
# idx 404605 correct 4 to 2
# idx 404614 correct 18 to 19
# idx 404862 correct 33 to 38
# idx 404975 correct 25 to 38
# idx 405010 correct 30 to 38
# idx 405084 correct 0 to 1
# idx 405243 correct 7 to 9
# idx 405295 correct 3 to 2
# idx 405305 correct 13 to 7
# idx 405501 correct 21 to 29
# idx 405618 correct 10 to 7
# idx 405834 correct 1 to 17
# idx 405929 correct 14 to 9
# idx 405939 correct 38 to 33
# idx 406178 correct 35 to 31
# idx 406205 correct 4 to 1
# idx 406226 correct 20 to 19
# idx 406293 correct 4 to 17
# idx 406906 correct 13 to 7
# idx 407140 correct 16 to 14
# idx 407412 correct 28 to 29
# idx 407661 correct 10 to 13
# idx 407672 correct 4 to 1
# idx 407750 correct 22 to 31
# idx 407988 correct 1 to 4
# idx 408223 correct 4 to 2
# idx 408420 correct 4 to 2
# idx 408440 correct 22 to 35
# idx 408451 correct 4 to 13
# idx 408513 correct 2 to 1
# idx 408852 correct 32 to 34
# idx 408854 correct 33 to 34
# idx 409048 correct 12 to 4
# idx 409217 correct 29 to 38
# idx 409412 correct 35 to 36
# idx 409625 correct 33 to 32
# idx 409719 correct 0 to 8
# idx 409742 correct 29 to 21
# idx 409837 correct 37 to 38
# idx 410003 correct 37 to 38
# idx 410066 correct 2 to 12
# idx 410820 correct 3 to 2
# idx 411093 correct 5 to 16
# idx 411351 correct 7 to 4
# idx 411364 correct 4 to 1
# idx 411375 correct 35 to 31
# idx 411972 correct 1 to 2
# idx 412043 correct 13 to 23
# idx 412121 correct 38 to 3
# idx 412147 correct 18 to 19
# idx 412273 correct 31 to 35
# idx 412472 correct 6 to 13
# idx 412487 correct 6 to 4
# idx 412875 correct 38 to 7
# idx 413028 correct 7 to 10
# idx 413207 correct 38 to 18
# idx 413242 correct 9 to 3
# idx 413250 correct 8 to 1
# idx 413372 correct 4 to 1
# idx 413488 correct 9 to 7
# idx 413757 correct 17 to 14
# idx 414013 correct 22 to 21
# idx 414031 correct 26 to 8
# idx 414033 correct 1 to 8
# idx 414277 correct 13 to 12
# idx 414303 correct 3 to 9
# idx 414414 correct 9 to 7
# idx 414494 correct 3 to 1
# idx 414496 correct 3 to 1
# idx 414640 correct 27 to 38
# idx 414686 correct 1 to 15
# idx 414691 correct 18 to 17
# idx 414718 correct 0 to 1
# idx 414807 correct 29 to 33
# idx 414823 correct 13 to 7
# idx 415341 correct 1 to 2
# idx 415487 correct 30 to 38
# idx 415663 correct 20 to 19
# idx 415669 correct 34 to 33
# idx 415746 correct 0 to 1
# idx 416330 correct 11 to 3
# idx 416332 correct 7 to 3
# idx 416602 correct 19 to 20
# idx 416634 correct 31 to 35
# idx 416783 correct 3 to 2
# idx 416991 correct 2 to 8
# idx 417054 correct 38 to 34
# idx 417067 correct 1 to 0
# idx 417071 correct 0 to 1
# idx 417211 correct 29 to 23
# idx 417565 correct 2 to 1
# idx 417578 correct 31 to 35
# idx 417716 correct 9 to 7
# idx 418564 correct 33 to 38
# idx 418627 correct 9 to 4
# idx 418879 correct 21 to 22
# idx 419083 correct 38 to 13
# idx 419091 correct 0 to 8
# idx 419169 correct 9 to 4
# idx 419248 correct 36 to 35
# idx 419488 correct 1 to 8
# idx 419549 correct 36 to 21
# idx 419566 correct 1 to 6
# idx 419673 correct 10 to 13
# idx 419705 correct 27 to 30
# idx 419960 correct 10 to 12
# idx 419971 correct 37 to 9
# idx 419974 correct 11 to 7
# idx 420133 correct 1 to 0
# idx 420171 correct 29 to 21
# idx 420218 correct 36 to 35
# idx 420253 correct 3 to 2
# idx 420323 correct 4 to 13
# idx 420450 correct 3 to 2
# idx 420456 correct 3 to 2
# idx 420520 correct 17 to 5
# idx 420533 correct 25 to 38
# idx 420988 correct 6 to 1
# idx 421274 correct 36 to 21
# idx 421445 correct 0 to 1
# idx 421656 correct 4 to 7
# idx 421694 correct 1 to 0
# idx 421833 correct 0 to 8
# idx 421868 correct 14 to 17
# idx 421989 correct 33 to 38
# idx 422039 correct 38 to 18
# idx 422235 correct 16 to 38
# idx 422303 correct 34 to 31
# idx 422418 correct 10 to 16
# idx 422500 correct 29 to 21
# idx 422526 correct 31 to 35
# idx 422635 correct 30 to 29
# idx 422734 correct 10 to 1
# idx 422751 correct 5 to 1
# idx 423042 correct 29 to 21
# idx 423088 correct 2 to 3
# idx 423638 correct 38 to 19
# idx 423645 correct 28 to 38
# idx 423690 correct 18 to 19
# idx 423824 correct 2 to 3
# idx 424009 correct 2 to 3
# idx 424050 correct 31 to 35
# idx 424165 correct 8 to 0
# idx 424219 correct 35 to 36
# idx 424331 correct 32 to 38
# idx 424354 correct 0 to 15
# idx 424357 correct 5 to 1
# idx 424393 correct 1 to 2
# idx 424423 correct 33 to 28
# idx 424553 correct 17 to 1
# idx 424647 correct 17 to 14
# idx 424696 correct 16 to 13
# idx 424771 correct 35 to 33
# idx 424805 correct 3 to 8
# idx 424894 correct 8 to 3
# idx 425234 correct 21 to 36
# idx 425380 correct 21 to 35
# idx 425624 correct 19 to 18
# idx 426215 correct 38 to 7
# idx 426476 correct 1 to 0
# idx 426490 correct 22 to 36
# idx 426545 correct 19 to 18
# idx 426830 correct 1 to 2
# idx 426895 correct 31 to 35
# idx 427019 correct 2 to 4
# idx 427266 correct 13 to 12
# idx 427347 correct 2 to 1
# idx 427349 correct 2 to 1
# idx 427411 correct 11 to 12
# idx 427556 correct 19 to 38
# idx 427750 correct 31 to 35
# idx 427752 correct 31 to 35
# idx 428036 correct 1 to 19
# idx 428485 correct 24 to 38
# idx 428502 correct 12 to 13
# idx 428572 correct 21 to 36
# idx 428590 correct 1 to 2
# idx 428627 correct 11 to 3
# idx 428679 correct 17 to 14
# idx 428689 correct 1 to 13
# idx 428862 correct 28 to 29
# idx 428871 correct 3 to 8
# idx 429155 correct 33 to 38
# idx 429377 correct 11 to 7
# idx 429588 correct 4 to 13
# idx 429786 correct 6 to 4
# idx 429874 correct 34 to 33
# idx 429931 correct 31 to 35
# idx 430044 correct 21 to 22
# idx 430098 correct 38 to 0
# idx 430173 correct 12 to 13
# idx 430279 correct 4 to 12
# idx 430950 correct 2 to 12
# idx 431217 correct 3 to 2
# idx 431247 correct 21 to 22
# idx 431263 correct 36 to 35
# idx 431273 correct 3 to 8
# idx 431382 correct 38 to 19
# idx 431384 correct 38 to 19
# idx 431559 correct 8 to 3
# idx 431582 correct 4 to 1
# idx 431643 correct 36 to 21
# idx 431800 correct 3 to 7
# idx 431813 correct 4 to 13
# idx 431907 correct 4 to 12
# idx 432074 correct 17 to 1
# idx 432312 correct 4 to 12
# idx 432357 correct 2 to 17
# idx 432581 correct 14 to 17
# idx 432611 correct 21 to 22
# idx 432801 correct 28 to 38
# idx 432880 correct 14 to 17
# idx 432943 correct 2 to 3
# idx 433385 correct 23 to 3
# idx 433457 correct 12 to 7
# idx 433705 correct 6 to 2
# idx 433763 correct 3 to 2
# idx 433930 correct 31 to 35
# idx 434079 correct 7 to 4
# idx 434248 correct 31 to 35
# idx 434329 correct 10 to 7
# idx 434388 correct 38 to 31
# idx 434407 correct 4 to 2
# idx 434435 correct 7 to 10
# idx 434497 correct 35 to 31
# idx 434596 correct 38 to 37
# idx 434770 correct 4 to 1
# idx 435079 correct 38 to 34
# idx 435177 correct 11 to 7
# idx 435181 correct 11 to 7
# idx 435375 correct 2 to 3
# idx 435990 correct 38 to 26
# idx 436128 correct 9 to 7
# idx 436133 correct 9 to 7
# idx 436213 correct 1 to 17
# idx 436227 correct 35 to 34
# idx 436286 correct 31 to 35
# idx 436300 correct 1 to 8
# idx 436409 correct 9 to 7
# idx 436691 correct 38 to 26
# idx 436773 correct 3 to 2
# idx 436794 correct 34 to 35
# idx 437035 correct 0 to 8
# idx 437185 correct 4 to 1
# idx 437216 correct 19 to 13
# idx 437445 correct 14 to 7
# idx 437630 correct 1 to 2
# idx 437650 correct 12 to 13
# idx 437669 correct 31 to 35
# idx 437944 correct 33 to 38
# idx 437964 correct 31 to 35
# idx 438117 correct 3 to 2
# idx 438121 correct 14 to 2
# idx 438514 correct 34 to 30
# idx 438751 correct 13 to 7
# idx 438773 correct 34 to 38
# idx 438779 correct 29 to 23
# idx 438879 correct 2 to 8
# idx 438884 correct 2 to 8
# idx 439003 correct 1 to 2
# idx 439089 correct 29 to 30
# idx 439305 correct 4 to 12
# idx 439380 correct 8 to 1
# idx 439549 correct 4 to 2
# idx 439551 correct 4 to 2
# idx 439694 correct 31 to 35
# idx 439893 correct 26 to 2
# idx 439994 correct 35 to 31
# idx 440058 correct 17 to 14
# idx 440207 correct 2 to 4
# idx 440377 correct 36 to 29
# idx 440470 correct 14 to 9
# idx 440775 correct 18 to 19
# idx 440824 correct 1 to 8
# idx 440917 correct 4 to 2
# idx 440993 correct 10 to 9
# idx 441009 correct 21 to 29
# idx 441117 correct 22 to 21
# idx 441308 correct 29 to 38
# idx 441692 correct 11 to 3
# idx 441735 correct 14 to 32
# idx 441862 correct 25 to 23
# idx 442072 correct 31 to 35
# idx 442214 correct 28 to 33
# idx 442403 correct 38 to 19
# idx 442475 correct 14 to 17
# idx 442564 correct 4 to 13
# idx 442639 correct 35 to 31
# idx 442662 correct 18 to 14
# idx 442807 correct 7 to 16
# idx 443042 correct 17 to 2
# idx 443045 correct 17 to 1
# idx 443357 correct 8 to 17
# idx 443513 correct 2 to 3
# idx 443958 correct 13 to 17
# idx 444242 correct 0 to 8
# idx 444283 correct 4 to 12
# idx 444351 correct 3 to 7
# idx 444357 correct 7 to 3
# idx 444512 correct 14 to 9
# idx 444740 correct 38 to 19
# idx 444846 correct 38 to 19
# idx 445333 correct 18 to 13
# idx 445433 correct 19 to 32
# idx 445641 correct 22 to 21
# idx 445665 correct 10 to 7
# idx 446051 correct 31 to 35
# idx 446403 correct 9 to 3
# idx 446406 correct 12 to 3
# idx 446814 correct 12 to 10
# idx 447264 correct 1 to 4
# idx 447373 correct 13 to 5
# idx 447532 correct 4 to 38
# idx 447730 correct 21 to 29
# idx 447779 correct 1 to 2
# idx 447860 correct 4 to 1
# idx 447928 correct 19 to 18
# idx 447930 correct 19 to 18
# idx 447940 correct 6 to 1
# idx 448038 correct 31 to 35
# idx 448442 correct 21 to 36
# idx 448458 correct 5 to 1
# idx 448617 correct 14 to 17
# idx 448659 correct 38 to 0
# idx 448838 correct 1 to 8
# idx 449080 correct 4 to 7
# idx 449214 correct 4 to 9
# idx 449232 correct 19 to 17
# idx 449235 correct 5 to 17
# idx 449413 correct 5 to 0
# idx 449750 correct 29 to 38
# idx 449887 correct 18 to 19
# idx 449919 correct 1 to 4
# idx 450068 correct 33 to 32
# idx 450277 correct 38 to 32
# idx 450378 correct 19 to 20
# idx 450381 correct 19 to 16
# idx 450574 correct 4 to 1
# idx 450595 correct 1 to 6
# idx 450787 correct 30 to 29
# idx 450814 correct 34 to 38
# idx 450866 correct 2 to 4
# idx 451112 correct 34 to 23
# idx 451219 correct 34 to 38
# idx 451265 correct 1 to 0
# total number of correction 3042, correction percent 0.01

# %%
with open('prediction_dnn3.csv', 'w') as f:
    f.write('Id,Class\n')
    for i, y in enumerate(predict):
        f.write('{},{}\n'.format(i, y))

# %% [markdown]
# # Reference
# The code is modified from TA's sample code
